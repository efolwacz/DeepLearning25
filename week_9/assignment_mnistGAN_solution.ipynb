# %% [markdown]
# # Asignemnt: MNIST GAN
# ## Load the Data
#
# We begin by downloading and importing the data as a PyTorch dataset using the `MNIST` helper class from `torchvision.datasets`.

# %%
import torch
import torchvision
from torchvision.transforms import ToTensor, Normalize, Compose
from torchvision.datasets import MNIST

mnist = MNIST(root='data', 
              train=True, 
              download=True,
              transform=Compose([ToTensor(), Normalize(mean=(0.5,), std=(0.5,))]))
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to data/MNIST/raw/train-images-idx3-ubyte.gz
#   0%|          | 0/9912422 [00:00<?, ?it/s]
# Extracting data/MNIST/raw/train-images-idx3-ubyte.gz to data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to data/MNIST/raw/train-labels-idx1-ubyte.gz
#   0%|          | 0/28881 [00:00<?, ?it/s]
# Extracting data/MNIST/raw/train-labels-idx1-ubyte.gz to data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to data/MNIST/raw/t10k-images-idx3-ubyte.gz
#   0%|          | 0/1648877 [00:00<?, ?it/s]
# Extracting data/MNIST/raw/t10k-images-idx3-ubyte.gz to data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to data/MNIST/raw/t10k-labels-idx1-ubyte.gz
#   0%|          | 0/4542 [00:00<?, ?it/s]
# Extracting data/MNIST/raw/t10k-labels-idx1-ubyte.gz to data/MNIST/raw

# %% [markdown]
# Note that we are are transforming the pixel values from the range `[0, 1]` to the range `[-1, 1]`. Makes generation easier...

# %%
img, label = mnist[0]
print('Label: ', label)
print(img[:,10:15,10:15])
torch.min(img), torch.max(img)
# Out:
# Label:  5
# tensor([[[-0.9922,  0.2078,  0.9843, -0.2941, -1.0000],
#          [-1.0000,  0.0902,  0.9843,  0.4902, -0.9843],
#          [-1.0000, -0.9137,  0.4902,  0.9843, -0.4510],
#          [-1.0000, -1.0000, -0.7255,  0.8902,  0.7647],
#          [-1.0000, -1.0000, -1.0000, -0.3647,  0.8824]]])
# (tensor(-1.), tensor(1.))

# %% [markdown]
# As expected, the pixel values range from -1 to 1. Let's define a helper to denormalize and view the images. This function will also be useful for viewing the generated images.

# %%
def denorm(x):
    out = (x + 1) / 2
    return out.clamp(0, 1)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

img_norm = denorm(img)
plt.imshow(img_norm[0], cmap='gray')
print('Label:', label)
# Out:
# Label: 5

# %% [markdown]
# Finally, let's create a dataloader to load the images in batches.

# %%
from torch.utils.data import DataLoader

batch_size = 100
data_loader = DataLoader(mnist, batch_size, shuffle=True)

# %%
for img_batch, label_batch in data_loader:
    print('first batch')
    print(img_batch.shape)
    plt.imshow(img_batch[0][0], cmap='gray')
    print(label_batch)
    break
# Out:
# first batch
# torch.Size([100, 1, 28, 28])
# tensor([5, 3, 6, 5, 4, 4, 4, 4, 0, 5, 6, 8, 5, 1, 8, 0, 6, 9, 9, 0, 1, 9, 3, 9,
#         8, 2, 7, 9, 0, 1, 6, 1, 9, 1, 6, 2, 7, 4, 7, 7, 1, 9, 0, 4, 6, 4, 2, 2,
#         0, 6, 7, 4, 1, 2, 5, 4, 7, 6, 1, 3, 4, 1, 3, 9, 7, 0, 5, 3, 9, 5, 1, 8,
#         9, 4, 2, 9, 3, 0, 1, 1, 5, 9, 2, 6, 6, 7, 3, 4, 9, 3, 1, 1, 9, 9, 6, 8,
#         8, 8, 7, 2])

# %%
# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
device
# Out:
# device(type='cuda')

# %% [markdown]
# ## Discriminator Network
#
# The discriminator takes an image as input, and tries to classify it as "real" or "generated". In this sense, it's like any other neural network. While we can use a CNN for the discriminator, we'll use a simple feedforward network with 3 linear layers to keep things since. We'll treat each 28x28 image as a vector of size 784.

# %%
image_size = 784
hidden_size = 256

# %%
import torch.nn as nn

D = nn.Sequential(
    nn.Linear(image_size, hidden_size),
    nn.LeakyReLU(0.2),
    nn.Linear(hidden_size, hidden_size),
    nn.LeakyReLU(0.2),
    nn.Linear(hidden_size, 1),
    nn.Sigmoid())

# %%
D.to(device);

# %% [markdown]
# ## Generator Network
#
# The input to the generator is typically a vector or a matrix which is used as a seed for generating an image. Once again, to keep things simple, we'll use a feedfoward neural network with 3 layers, and the output will be a vector of size 784, which can be transformed to a 28x28 px image.

# %% [markdown]
# We use the TanH activation function for the output layer of the generator.
#
# <img src="https://nic.schraudolph.org/teach/NNcourse/figs/tanh.gif" width="420" >
#
# > "The ReLU activation (Nair & Hinton, 2010) is used in the generator with the exception of the output layer which uses the Tanh function. We observed that using a bounded activation allowed the model to learn more quickly to saturate and cover the color space of the training distribution. Within the discriminator we found the leaky rectified activation (Maas et al., 2013) (Xu et al., 2015) to work well, especially for higher resolution modeling." - [Source](https://stackoverflow.com/questions/41489907/generative-adversarial-networks-tanh)
#
#
# Note that since the outputs of the TanH activation lie in the range `[-1,1]`, we have applied the same transformation to the images in the training dataset. Let's generate an output vector using the generator and view it as an image by transforming and denormalizing the output.

# %%
latent_size = 64

# %%
G = nn.Sequential(
    nn.Linear(latent_size, hidden_size),
    nn.ReLU(),
    nn.Linear(hidden_size, hidden_size),
    nn.ReLU(),
    nn.Linear(hidden_size, image_size),
    nn.Tanh())

# %%
y = G(torch.randn(2, latent_size))
gen_imgs = denorm(y.reshape((-1, 28,28)).detach())

# %%
plt.imshow(gen_imgs[0], cmap='gray');

# %%
plt.imshow(gen_imgs[1], cmap='gray');

# %% [markdown]
# As one might expect, the output from the generator is basically random noise. Let's define a helper function which can save a batch of outputs from the generator to a file.
#
# Let's move the generator to the chosen device.

# %%
G.to(device);

# %% [markdown]
# ## Discriminator Training
#
# Since the discriminator is a binary classification model, we can use the binary cross entropy loss function to quantify how well it is able to differentiate between real and generated images.

# %%
criterion = nn.BCELoss()
d_optimizer = torch.optim.Adam(D.parameters(), lr=0.0002)

# %% [markdown]
# Let's define helper functions to reset gradients and  train the discriminator.

# %%
def reset_grad():
    d_optimizer.zero_grad()
    g_optimizer.zero_grad()

def train_discriminator(images):
    # Create the labels which are later used as input for the BCE loss
    real_labels = torch.ones(batch_size, 1).to(device)
    fake_labels = torch.zeros(batch_size, 1).to(device)
        
    # Loss for real images
    outputs = D(images)
    d_loss_real = criterion(outputs, real_labels)
    real_score = outputs

    # Loss for fake images
    z = torch.randn(batch_size, latent_size).to(device)
    fake_images = G(z)
    outputs = D(fake_images)
    d_loss_fake = criterion(outputs, fake_labels)
    fake_score = outputs

    # Combine losses
    d_loss = d_loss_real + d_loss_fake
    # Reset gradients
    reset_grad()
    # Compute gradients
    d_loss.backward()
    # Adjust the parameters using backprop
    d_optimizer.step()
    
    return d_loss, real_score, fake_score

# %% [markdown]
# Here are the steps involved in training the discriminator.
#
# - We expect the discriminator to output 1 if the image was picked from the real MNIST dataset, and 0 if it was generated.
#
# - We first pass a batch of real images, and compute the loss, setting the target labels to 1.
#
# - Then, we generate a batch of fake images using the generator, pass them into the discriminator, and compute the loss, setting the target labels to 0.
#
# - Finally we add the two losses and use the overall loss to perform gradient descent to adjust the weights of the discriminator.
#
# It's important to note that we don't change the weights of the generator model while training the discriminator (`d_optimizer` only affects the `D.parameters()`)

# %% [markdown]
# ## Generator Training
#
# Since the outputs of the generator are images, it's not obvious how we can train the generator. This is where we employ a rather elegant trick, which is to use the discriminator as a part of the loss function. Here's how it works:
#
# - We generate a batch of images using the generator, pass the into the discriminator.
#
# - We calculate the loss by setting the target labels to 1 i.e. real. We do this because the generator's objective is to "fool" the discriminator.
#
# - We use the loss to perform gradient descent i.e. change the weights of the generator, so it gets better at generating real-like images.
#
# Here's what this looks like in code.

# %%
g_optimizer = torch.optim.Adam(G.parameters(), lr=0.0002)

# %%
def train_generator():
    # Generate fake images and calculate loss
    z = torch.randn(batch_size, latent_size).to(device)
    fake_images = G(z)
    labels = torch.ones(batch_size, 1).to(device)
    g_loss = criterion(D(fake_images), labels)

    # Backprop and optimize
    reset_grad()
    g_loss.backward()
    g_optimizer.step()
    return g_loss, fake_images

# %% [markdown]
# ## Training the Model
#
# Let's create a directory where we can save intermediate outputs from the generator to visually inspect the progress of the model

# %%
import os

sample_dir = 'samples'
if not os.path.exists(sample_dir):
    os.makedirs(sample_dir)

# %% [markdown]
# Let's save a batch of real images that we can use for visual comparision while looking at the generated images.

# %%
from IPython.display import Image
from torchvision.utils import save_image

# Save some real images
for images, _ in data_loader:
    images = images.reshape(images.size(0), 1, 28, 28)
    save_image(denorm(images), os.path.join(sample_dir, 'real_images.png'), nrow=10)
    break
   
Image(os.path.join(sample_dir, 'real_images.png'))

# %% [markdown]
# We'll also define a helper function to save a batch of generated images to disk at the end of every epoch. We'll use a fixed set of input vectors to the generator to see how the individual generated images evolve over time as we train the model.

# %%
sample_vectors = torch.randn(batch_size, latent_size).to(device)

def save_fake_images(index):
    fake_images = G(sample_vectors)
    fake_images = fake_images.reshape(fake_images.size(0), 1, 28, 28)
    fake_fname = 'fake_images-{0:0=4d}.png'.format(index)
    print('Saving', fake_fname)
    save_image(denorm(fake_images), os.path.join(sample_dir, fake_fname), nrow=10)
    
# Before training
save_fake_images(0)
Image(os.path.join(sample_dir, 'fake_images-0000.png'))
# Out:
# Saving fake_images-0000.png

# %% [markdown]
# We are now ready to train the model. In each epoch, we train the discriminator first, and then the generator. The training might take a while if you're not using a GPU.

# %%
# %%time

num_epochs = 300
total_step = len(data_loader)
d_losses, g_losses, real_scores, fake_scores = [], [], [], []

for epoch in range(num_epochs):
    for i, (images, _) in enumerate(data_loader):
        # Load a batch & transform to vectors
        images = images.reshape(batch_size, -1).to(device)
        
        # Train the discriminator and generator
        d_loss, real_score, fake_score = train_discriminator(images)
        g_loss, fake_images = train_generator()
        
        # Inspect the losses
        if (i+1) % 200 == 0:
            d_losses.append(d_loss.item())
            g_losses.append(g_loss.item())
            real_scores.append(real_score.mean().item())
            fake_scores.append(fake_score.mean().item())
            print('Epoch [{}/{}], Step [{}/{}], d_loss: {:.4f}, g_loss: {:.4f}, D(x): {:.2f}, D(G(z)): {:.2f}' 
                  .format(epoch, num_epochs, i+1, total_step, d_loss.item(), g_loss.item(), 
                          real_score.mean().item(), fake_score.mean().item()))
        
    # Sample and save images
    save_fake_images(epoch+1)
# Out:
# Epoch [0/300], Step [200/600], d_loss: 0.0725, g_loss: 3.6185, D(x): 0.99, D(G(z)): 0.06
# Epoch [0/300], Step [400/600], d_loss: 0.0661, g_loss: 5.7706, D(x): 0.98, D(G(z)): 0.04
# Epoch [0/300], Step [600/600], d_loss: 0.2160, g_loss: 3.9595, D(x): 0.91, D(G(z)): 0.09
# Saving fake_images-0001.png
# Epoch [1/300], Step [200/600], d_loss: 0.0641, g_loss: 5.1160, D(x): 0.98, D(G(z)): 0.05
# Epoch [1/300], Step [400/600], d_loss: 0.8465, g_loss: 2.0051, D(x): 0.70, D(G(z)): 0.16
# Epoch [1/300], Step [600/600], d_loss: 0.0429, g_loss: 5.2221, D(x): 0.99, D(G(z)): 0.03
# Saving fake_images-0002.png
# Epoch [2/300], Step [200/600], d_loss: 0.3786, g_loss: 3.4403, D(x): 0.85, D(G(z)): 0.09
# Epoch [2/300], Step [400/600], d_loss: 0.2905, g_loss: 3.7574, D(x): 0.91, D(G(z)): 0.14
# Epoch [2/300], Step [600/600], d_loss: 0.9081, g_loss: 2.2103, D(x): 0.83, D(G(z)): 0.36
# Saving fake_images-0003.png
# Epoch [3/300], Step [200/600], d_loss: 1.4649, g_loss: 2.8660, D(x): 0.72, D(G(z)): 0.46
# Epoch [3/300], Step [400/600], d_loss: 0.3303, g_loss: 5.0789, D(x): 0.84, D(G(z)): 0.03
# Epoch [3/300], Step [600/600], d_loss: 0.4447, g_loss: 3.3373, D(x): 0.82, D(G(z)): 0.13
# Saving fake_images-0004.png
# Epoch [4/300], Step [200/600], d_loss: 0.4293, g_loss: 2.6747, D(x): 0.88, D(G(z)): 0.16
# Epoch [4/300], Step [400/600], d_loss: 0.9362, g_loss: 2.4738, D(x): 0.77, D(G(z)): 0.29
# Epoch [4/300], Step [600/600], d_loss: 0.4406, g_loss: 2.9008, D(x): 0.82, D(G(z)): 0.11
# Saving fake_images-0005.png
# Epoch [5/300], Step [200/600], d_loss: 0.1122, g_loss: 5.2957, D(x): 0.94, D(G(z)): 0.03
# Epoch [5/300], Step [400/600], d_loss: 0.1218, g_loss: 3.9385, D(x): 0.94, D(G(z)): 0.04
# Epoch [5/300], Step [600/600], d_loss: 0.2579, g_loss: 3.2640, D(x): 0.92, D(G(z)): 0.10
# Saving fake_images-0006.png
# Epoch [6/300], Step [200/600], d_loss: 0.1126, g_loss: 4.1385, D(x): 0.97, D(G(z)): 0.06
# Epoch [6/300], Step [400/600], d_loss: 0.1409, g_loss: 5.0393, D(x): 0.92, D(G(z)): 0.03
# Epoch [6/300], Step [600/600], d_loss: 0.2102, g_loss: 4.6220, D(x): 0.91, D(G(z)): 0.05
# Saving fake_images-0007.png
# Epoch [7/300], Step [200/600], d_loss: 0.2145, g_loss: 4.2218, D(x): 0.94, D(G(z)): 0.05
# Epoch [7/300], Step [400/600], d_loss: 0.0745, g_loss: 4.0400, D(x): 0.98, D(G(z)): 0.03
# Epoch [7/300], Step [600/600], d_loss: 0.1734, g_loss: 4.5759, D(x): 0.98, D(G(z)): 0.10
# Saving fake_images-0008.png
# Epoch [8/300], Step [200/600], d_loss: 0.0665, g_loss: 4.7513, D(x): 0.98, D(G(z)): 0.04
# Epoch [8/300], Step [400/600], d_loss: 0.1392, g_loss: 4.8923, D(x): 0.95, D(G(z)): 0.01
# Epoch [8/300], Step [600/600], d_loss: 0.1108, g_loss: 6.9919, D(x): 0.97, D(G(z)): 0.03
# Saving fake_images-0009.png
# Epoch [9/300], Step [200/600], d_loss: 0.0931, g_loss: 6.6768, D(x): 0.99, D(G(z)): 0.05
# Epoch [9/300], Step [400/600], d_loss: 0.0906, g_loss: 7.2382, D(x): 0.96, D(G(z)): 0.00
# Epoch [9/300], Step [600/600], d_loss: 0.0381, g_loss: 4.8931, D(x): 0.99, D(G(z)): 0.03
# Saving fake_images-0010.png
# Epoch [10/300], Step [200/600], d_loss: 0.1970, g_loss: 5.9195, D(x): 0.94, D(G(z)): 0.05
# Epoch [10/300], Step [400/600], d_loss: 0.1023, g_loss: 5.2461, D(x): 0.96, D(G(z)): 0.03
# Epoch [10/300], Step [600/600], d_loss: 0.2263, g_loss: 5.6958, D(x): 0.92, D(G(z)): 0.01
# Saving fake_images-0011.png
# Epoch [11/300], Step [200/600], d_loss: 0.0975, g_loss: 5.4482, D(x): 0.98, D(G(z)): 0.05
# Epoch [11/300], Step [400/600], d_loss: 0.0809, g_loss: 5.0704, D(x): 0.98, D(G(z)): 0.02
# Epoch [11/300], Step [600/600], d_loss: 0.1470, g_loss: 6.5072, D(x): 0.94, D(G(z)): 0.03
# Saving fake_images-0012.png
# Epoch [12/300], Step [200/600], d_loss: 0.0354, g_loss: 4.9625, D(x): 0.99, D(G(z)): 0.02
# Epoch [12/300], Step [400/600], d_loss: 0.0618, g_loss: 5.0980, D(x): 0.98, D(G(z)): 0.03
# Epoch [12/300], Step [600/600], d_loss: 0.1012, g_loss: 6.0356, D(x): 0.97, D(G(z)): 0.03
# Saving fake_images-0013.png
# Epoch [13/300], Step [200/600], d_loss: 0.0521, g_loss: 5.8161, D(x): 1.00, D(G(z)): 0.04
# Epoch [13/300], Step [400/600], d_loss: 0.1896, g_loss: 4.4176, D(x): 0.96, D(G(z)): 0.06
# Epoch [13/300], Step [600/600], d_loss: 0.2058, g_loss: 7.3756, D(x): 0.98, D(G(z)): 0.11
# Saving fake_images-0014.png
# Epoch [14/300], Step [200/600], d_loss: 0.1748, g_loss: 6.7580, D(x): 0.93, D(G(z)): 0.01
# Epoch [14/300], Step [400/600], d_loss: 0.1067, g_loss: 6.2927, D(x): 0.95, D(G(z)): 0.03
# Epoch [14/300], Step [600/600], d_loss: 0.1181, g_loss: 5.0759, D(x): 0.96, D(G(z)): 0.04
# Saving fake_images-0015.png
# Epoch [15/300], Step [200/600], d_loss: 0.3649, g_loss: 5.5130, D(x): 0.94, D(G(z)): 0.14
# Epoch [15/300], Step [400/600], d_loss: 0.1536, g_loss: 5.4742, D(x): 0.96, D(G(z)): 0.05
# Epoch [15/300], Step [600/600], d_loss: 0.1886, g_loss: 4.6993, D(x): 0.97, D(G(z)): 0.11
# Saving fake_images-0016.png
# Epoch [16/300], Step [200/600], d_loss: 0.1272, g_loss: 4.1991, D(x): 0.97, D(G(z)): 0.07
# Epoch [16/300], Step [400/600], d_loss: 0.3307, g_loss: 5.0944, D(x): 0.90, D(G(z)): 0.06
# Epoch [16/300], Step [600/600], d_loss: 0.1733, g_loss: 5.0553, D(x): 0.94, D(G(z)): 0.04
# Saving fake_images-0017.png
# Epoch [17/300], Step [200/600], d_loss: 0.4915, g_loss: 3.3200, D(x): 0.84, D(G(z)): 0.07
# Epoch [17/300], Step [400/600], d_loss: 0.1646, g_loss: 5.8733, D(x): 0.93, D(G(z)): 0.02
# Epoch [17/300], Step [600/600], d_loss: 0.2140, g_loss: 3.6665, D(x): 0.93, D(G(z)): 0.07
# Saving fake_images-0018.png
# Epoch [18/300], Step [200/600], d_loss: 0.2726, g_loss: 5.7139, D(x): 0.90, D(G(z)): 0.04
# Epoch [18/300], Step [400/600], d_loss: 0.1917, g_loss: 4.1880, D(x): 0.96, D(G(z)): 0.08
# Epoch [18/300], Step [600/600], d_loss: 0.3576, g_loss: 3.9462, D(x): 0.87, D(G(z)): 0.06
# Saving fake_images-0019.png
# Epoch [19/300], Step [200/600], d_loss: 0.2590, g_loss: 4.2751, D(x): 0.91, D(G(z)): 0.07
# Epoch [19/300], Step [400/600], d_loss: 0.2434, g_loss: 4.4556, D(x): 0.94, D(G(z)): 0.08
# Epoch [19/300], Step [600/600], d_loss: 0.4494, g_loss: 5.1036, D(x): 0.86, D(G(z)): 0.02
# Saving fake_images-0020.png
# Epoch [20/300], Step [200/600], d_loss: 0.2515, g_loss: 3.7796, D(x): 0.93, D(G(z)): 0.10
# Epoch [20/300], Step [400/600], d_loss: 0.1129, g_loss: 3.9271, D(x): 0.97, D(G(z)): 0.06
# Epoch [20/300], Step [600/600], d_loss: 0.3337, g_loss: 3.7112, D(x): 0.89, D(G(z)): 0.06
# Saving fake_images-0021.png
# Epoch [21/300], Step [200/600], d_loss: 0.4721, g_loss: 4.8932, D(x): 0.86, D(G(z)): 0.04
# Epoch [21/300], Step [400/600], d_loss: 0.3434, g_loss: 4.4269, D(x): 0.91, D(G(z)): 0.10
# Epoch [21/300], Step [600/600], d_loss: 0.3645, g_loss: 4.0156, D(x): 0.92, D(G(z)): 0.13
# Saving fake_images-0022.png
# Epoch [22/300], Step [200/600], d_loss: 0.4802, g_loss: 4.2029, D(x): 0.85, D(G(z)): 0.09
# Epoch [22/300], Step [400/600], d_loss: 0.1500, g_loss: 5.9999, D(x): 0.95, D(G(z)): 0.04
# Epoch [22/300], Step [600/600], d_loss: 0.1164, g_loss: 5.4443, D(x): 0.97, D(G(z)): 0.06
# Saving fake_images-0023.png
# Epoch [23/300], Step [200/600], d_loss: 0.1616, g_loss: 4.7719, D(x): 0.97, D(G(z)): 0.09
# Epoch [23/300], Step [400/600], d_loss: 0.2454, g_loss: 5.2546, D(x): 0.89, D(G(z)): 0.04
# Epoch [23/300], Step [600/600], d_loss: 0.1846, g_loss: 5.8948, D(x): 0.93, D(G(z)): 0.03
# Saving fake_images-0024.png
# Epoch [24/300], Step [200/600], d_loss: 0.3045, g_loss: 4.9228, D(x): 0.91, D(G(z)): 0.09
# Epoch [24/300], Step [400/600], d_loss: 0.2711, g_loss: 4.4609, D(x): 0.90, D(G(z)): 0.04
# Epoch [24/300], Step [600/600], d_loss: 0.4055, g_loss: 4.2622, D(x): 0.90, D(G(z)): 0.09
# Saving fake_images-0025.png
# Epoch [25/300], Step [200/600], d_loss: 0.2643, g_loss: 4.7988, D(x): 0.91, D(G(z)): 0.09
# Epoch [25/300], Step [400/600], d_loss: 0.2981, g_loss: 5.4760, D(x): 0.89, D(G(z)): 0.05
# Epoch [25/300], Step [600/600], d_loss: 0.3613, g_loss: 3.5694, D(x): 0.91, D(G(z)): 0.07
# Saving fake_images-0026.png
# Epoch [26/300], Step [200/600], d_loss: 0.3298, g_loss: 3.9051, D(x): 0.88, D(G(z)): 0.03
# Epoch [26/300], Step [400/600], d_loss: 0.4759, g_loss: 3.3807, D(x): 0.89, D(G(z)): 0.13
# Epoch [26/300], Step [600/600], d_loss: 0.3282, g_loss: 4.8857, D(x): 0.90, D(G(z)): 0.08
# Saving fake_images-0027.png
# Epoch [27/300], Step [200/600], d_loss: 0.3758, g_loss: 4.4564, D(x): 0.91, D(G(z)): 0.12
# Epoch [27/300], Step [400/600], d_loss: 0.3548, g_loss: 2.7349, D(x): 0.92, D(G(z)): 0.11
# Epoch [27/300], Step [600/600], d_loss: 0.3339, g_loss: 3.1836, D(x): 0.92, D(G(z)): 0.14
# Saving fake_images-0028.png
# Epoch [28/300], Step [200/600], d_loss: 0.2581, g_loss: 3.4112, D(x): 0.91, D(G(z)): 0.09
# Epoch [28/300], Step [400/600], d_loss: 0.3466, g_loss: 3.4004, D(x): 0.93, D(G(z)): 0.15
# Epoch [28/300], Step [600/600], d_loss: 0.2421, g_loss: 4.4042, D(x): 0.88, D(G(z)): 0.04
# Saving fake_images-0029.png
# Epoch [29/300], Step [200/600], d_loss: 0.3411, g_loss: 5.0534, D(x): 0.88, D(G(z)): 0.08
# Epoch [29/300], Step [400/600], d_loss: 0.2609, g_loss: 4.0425, D(x): 0.92, D(G(z)): 0.10
# Epoch [29/300], Step [600/600], d_loss: 0.3553, g_loss: 3.1272, D(x): 0.88, D(G(z)): 0.10
# Saving fake_images-0030.png
# Epoch [30/300], Step [200/600], d_loss: 0.4673, g_loss: 3.6656, D(x): 0.85, D(G(z)): 0.10
# Epoch [30/300], Step [400/600], d_loss: 0.6792, g_loss: 3.7116, D(x): 0.79, D(G(z)): 0.06
# Epoch [30/300], Step [600/600], d_loss: 0.4042, g_loss: 2.7944, D(x): 0.85, D(G(z)): 0.10
# Saving fake_images-0031.png
# Epoch [31/300], Step [200/600], d_loss: 0.4172, g_loss: 2.7960, D(x): 0.89, D(G(z)): 0.13
# Epoch [31/300], Step [400/600], d_loss: 0.5527, g_loss: 3.0643, D(x): 0.82, D(G(z)): 0.11
# Epoch [31/300], Step [600/600], d_loss: 0.3556, g_loss: 3.2010, D(x): 0.89, D(G(z)): 0.10
# Saving fake_images-0032.png
# Epoch [32/300], Step [200/600], d_loss: 0.2432, g_loss: 3.6295, D(x): 0.89, D(G(z)): 0.05
# Epoch [32/300], Step [400/600], d_loss: 0.6031, g_loss: 2.1019, D(x): 0.88, D(G(z)): 0.21
# Epoch [32/300], Step [600/600], d_loss: 0.4201, g_loss: 4.2195, D(x): 0.84, D(G(z)): 0.04
# Saving fake_images-0033.png
# Epoch [33/300], Step [200/600], d_loss: 0.3024, g_loss: 3.8776, D(x): 0.91, D(G(z)): 0.12
# Epoch [33/300], Step [400/600], d_loss: 0.5592, g_loss: 3.8500, D(x): 0.85, D(G(z)): 0.11
# Epoch [33/300], Step [600/600], d_loss: 0.3650, g_loss: 3.7348, D(x): 0.87, D(G(z)): 0.08
# Saving fake_images-0034.png
# Epoch [34/300], Step [200/600], d_loss: 0.3389, g_loss: 4.3599, D(x): 0.90, D(G(z)): 0.10
# Epoch [34/300], Step [400/600], d_loss: 0.5217, g_loss: 3.9432, D(x): 0.84, D(G(z)): 0.09
# Epoch [34/300], Step [600/600], d_loss: 0.4191, g_loss: 2.7196, D(x): 0.87, D(G(z)): 0.13
# Saving fake_images-0035.png
# Epoch [35/300], Step [200/600], d_loss: 0.4578, g_loss: 3.5977, D(x): 0.86, D(G(z)): 0.12
# Epoch [35/300], Step [400/600], d_loss: 0.6555, g_loss: 3.3580, D(x): 0.74, D(G(z)): 0.06
# Epoch [35/300], Step [600/600], d_loss: 0.5553, g_loss: 2.9802, D(x): 0.82, D(G(z)): 0.11
# Saving fake_images-0036.png
# Epoch [36/300], Step [200/600], d_loss: 0.4999, g_loss: 3.2939, D(x): 0.87, D(G(z)): 0.18
# Epoch [36/300], Step [400/600], d_loss: 0.5459, g_loss: 2.6687, D(x): 0.93, D(G(z)): 0.27
# Epoch [36/300], Step [600/600], d_loss: 0.5249, g_loss: 2.7349, D(x): 0.92, D(G(z)): 0.26
# Saving fake_images-0037.png
# Epoch [37/300], Step [200/600], d_loss: 0.5018, g_loss: 3.3219, D(x): 0.84, D(G(z)): 0.06
# Epoch [37/300], Step [400/600], d_loss: 0.6888, g_loss: 3.1942, D(x): 0.79, D(G(z)): 0.15
# Epoch [37/300], Step [600/600], d_loss: 0.5060, g_loss: 2.4343, D(x): 0.84, D(G(z)): 0.16
# Saving fake_images-0038.png
# Epoch [38/300], Step [200/600], d_loss: 0.6378, g_loss: 2.5631, D(x): 0.80, D(G(z)): 0.10
# Epoch [38/300], Step [400/600], d_loss: 0.5812, g_loss: 3.0019, D(x): 0.82, D(G(z)): 0.13
# Epoch [38/300], Step [600/600], d_loss: 0.5331, g_loss: 2.9674, D(x): 0.83, D(G(z)): 0.14
# Saving fake_images-0039.png
# Epoch [39/300], Step [200/600], d_loss: 0.7363, g_loss: 2.0276, D(x): 0.88, D(G(z)): 0.31
# Epoch [39/300], Step [400/600], d_loss: 0.4607, g_loss: 3.6868, D(x): 0.83, D(G(z)): 0.10
# Epoch [39/300], Step [600/600], d_loss: 0.5275, g_loss: 2.9907, D(x): 0.92, D(G(z)): 0.26
# Saving fake_images-0040.png
# Epoch [40/300], Step [200/600], d_loss: 0.5135, g_loss: 2.8583, D(x): 0.78, D(G(z)): 0.07
# Epoch [40/300], Step [400/600], d_loss: 0.6728, g_loss: 2.8092, D(x): 0.89, D(G(z)): 0.29
# Epoch [40/300], Step [600/600], d_loss: 0.3361, g_loss: 4.3012, D(x): 0.85, D(G(z)): 0.05
# Saving fake_images-0041.png
# Epoch [41/300], Step [200/600], d_loss: 0.4532, g_loss: 3.4352, D(x): 0.84, D(G(z)): 0.14
# Epoch [41/300], Step [400/600], d_loss: 0.4421, g_loss: 3.4799, D(x): 0.82, D(G(z)): 0.07
# Epoch [41/300], Step [600/600], d_loss: 0.5811, g_loss: 2.1321, D(x): 0.83, D(G(z)): 0.20
# Saving fake_images-0042.png
# Epoch [42/300], Step [200/600], d_loss: 0.5908, g_loss: 3.8187, D(x): 0.76, D(G(z)): 0.08
# Epoch [42/300], Step [400/600], d_loss: 0.4504, g_loss: 3.5804, D(x): 0.90, D(G(z)): 0.20
# Epoch [42/300], Step [600/600], d_loss: 0.4841, g_loss: 3.3859, D(x): 0.88, D(G(z)): 0.21
# Saving fake_images-0043.png
# Epoch [43/300], Step [200/600], d_loss: 0.4619, g_loss: 2.8507, D(x): 0.88, D(G(z)): 0.17
# Epoch [43/300], Step [400/600], d_loss: 0.7220, g_loss: 2.2293, D(x): 0.76, D(G(z)): 0.13
# Epoch [43/300], Step [600/600], d_loss: 0.4283, g_loss: 3.8162, D(x): 0.84, D(G(z)): 0.09
# Saving fake_images-0044.png
# Epoch [44/300], Step [200/600], d_loss: 0.6542, g_loss: 3.0862, D(x): 0.71, D(G(z)): 0.06
# Epoch [44/300], Step [400/600], d_loss: 0.4799, g_loss: 2.9930, D(x): 0.85, D(G(z)): 0.15
# Epoch [44/300], Step [600/600], d_loss: 0.3603, g_loss: 4.0512, D(x): 0.88, D(G(z)): 0.13
# Saving fake_images-0045.png
# Epoch [45/300], Step [200/600], d_loss: 0.5021, g_loss: 2.4879, D(x): 0.82, D(G(z)): 0.13
# Epoch [45/300], Step [400/600], d_loss: 0.5580, g_loss: 3.8780, D(x): 0.76, D(G(z)): 0.06
# Epoch [45/300], Step [600/600], d_loss: 0.7658, g_loss: 3.1907, D(x): 0.79, D(G(z)): 0.17
# Saving fake_images-0046.png
# Epoch [46/300], Step [200/600], d_loss: 0.5745, g_loss: 3.2294, D(x): 0.87, D(G(z)): 0.22
# Epoch [46/300], Step [400/600], d_loss: 0.4350, g_loss: 3.1942, D(x): 0.88, D(G(z)): 0.17
# Epoch [46/300], Step [600/600], d_loss: 0.4741, g_loss: 3.3958, D(x): 0.84, D(G(z)): 0.14
# Saving fake_images-0047.png
# Epoch [47/300], Step [200/600], d_loss: 0.5510, g_loss: 2.7693, D(x): 0.86, D(G(z)): 0.23
# Epoch [47/300], Step [400/600], d_loss: 0.4662, g_loss: 3.9643, D(x): 0.88, D(G(z)): 0.17
# Epoch [47/300], Step [600/600], d_loss: 0.4462, g_loss: 2.9394, D(x): 0.82, D(G(z)): 0.12
# Saving fake_images-0048.png
# Epoch [48/300], Step [200/600], d_loss: 0.5262, g_loss: 1.9580, D(x): 0.91, D(G(z)): 0.27
# Epoch [48/300], Step [400/600], d_loss: 0.6809, g_loss: 3.0502, D(x): 0.86, D(G(z)): 0.26
# Epoch [48/300], Step [600/600], d_loss: 0.5990, g_loss: 3.2029, D(x): 0.79, D(G(z)): 0.13
# Saving fake_images-0049.png
# Epoch [49/300], Step [200/600], d_loss: 0.4847, g_loss: 2.6953, D(x): 0.83, D(G(z)): 0.14
# Epoch [49/300], Step [400/600], d_loss: 0.5363, g_loss: 2.3090, D(x): 0.91, D(G(z)): 0.25
# Epoch [49/300], Step [600/600], d_loss: 0.5681, g_loss: 2.2994, D(x): 0.83, D(G(z)): 0.21
# Saving fake_images-0050.png
# Epoch [50/300], Step [200/600], d_loss: 0.5210, g_loss: 2.4957, D(x): 0.84, D(G(z)): 0.16
# Epoch [50/300], Step [400/600], d_loss: 0.5142, g_loss: 2.9510, D(x): 0.85, D(G(z)): 0.17
# Epoch [50/300], Step [600/600], d_loss: 0.6435, g_loss: 2.1308, D(x): 0.87, D(G(z)): 0.28
# Saving fake_images-0051.png
# Epoch [51/300], Step [200/600], d_loss: 0.5209, g_loss: 2.4975, D(x): 0.90, D(G(z)): 0.26
# Epoch [51/300], Step [400/600], d_loss: 0.4156, g_loss: 3.0015, D(x): 0.85, D(G(z)): 0.13
# Epoch [51/300], Step [600/600], d_loss: 0.6144, g_loss: 2.8157, D(x): 0.77, D(G(z)): 0.15
# Saving fake_images-0052.png
# Epoch [52/300], Step [200/600], d_loss: 0.4393, g_loss: 2.8066, D(x): 0.88, D(G(z)): 0.18
# Epoch [52/300], Step [400/600], d_loss: 0.5175, g_loss: 2.8744, D(x): 0.80, D(G(z)): 0.13
# Epoch [52/300], Step [600/600], d_loss: 0.3646, g_loss: 2.9234, D(x): 0.90, D(G(z)): 0.14
# Saving fake_images-0053.png
# Epoch [53/300], Step [200/600], d_loss: 0.4745, g_loss: 2.8633, D(x): 0.85, D(G(z)): 0.15
# Epoch [53/300], Step [400/600], d_loss: 0.4220, g_loss: 2.6951, D(x): 0.83, D(G(z)): 0.12
# Epoch [53/300], Step [600/600], d_loss: 0.4040, g_loss: 2.6134, D(x): 0.85, D(G(z)): 0.12
# Saving fake_images-0054.png
# Epoch [54/300], Step [200/600], d_loss: 0.3773, g_loss: 2.5600, D(x): 0.85, D(G(z)): 0.12
# Epoch [54/300], Step [400/600], d_loss: 0.5497, g_loss: 3.1164, D(x): 0.86, D(G(z)): 0.21
# Epoch [54/300], Step [600/600], d_loss: 0.5354, g_loss: 2.5284, D(x): 0.84, D(G(z)): 0.17
# Saving fake_images-0055.png
# Epoch [55/300], Step [200/600], d_loss: 0.5129, g_loss: 2.2831, D(x): 0.91, D(G(z)): 0.25
# Epoch [55/300], Step [400/600], d_loss: 0.5158, g_loss: 2.7801, D(x): 0.80, D(G(z)): 0.14
# Epoch [55/300], Step [600/600], d_loss: 0.6037, g_loss: 3.2676, D(x): 0.79, D(G(z)): 0.13
# Saving fake_images-0056.png
# Epoch [56/300], Step [200/600], d_loss: 0.8982, g_loss: 1.9387, D(x): 0.69, D(G(z)): 0.18
# Epoch [56/300], Step [400/600], d_loss: 0.5813, g_loss: 2.8766, D(x): 0.83, D(G(z)): 0.22
# Epoch [56/300], Step [600/600], d_loss: 0.7823, g_loss: 2.3574, D(x): 0.84, D(G(z)): 0.30
# Saving fake_images-0057.png
# Epoch [57/300], Step [200/600], d_loss: 0.6802, g_loss: 2.6372, D(x): 0.90, D(G(z)): 0.33
# Epoch [57/300], Step [400/600], d_loss: 0.5481, g_loss: 2.5205, D(x): 0.80, D(G(z)): 0.16
# Epoch [57/300], Step [600/600], d_loss: 0.7874, g_loss: 3.3015, D(x): 0.81, D(G(z)): 0.20
# Saving fake_images-0058.png
# Epoch [58/300], Step [200/600], d_loss: 0.5506, g_loss: 2.8687, D(x): 0.77, D(G(z)): 0.13
# Epoch [58/300], Step [400/600], d_loss: 0.5810, g_loss: 2.9076, D(x): 0.82, D(G(z)): 0.20
# Epoch [58/300], Step [600/600], d_loss: 0.7218, g_loss: 1.6938, D(x): 0.82, D(G(z)): 0.23
# Saving fake_images-0059.png
# Epoch [59/300], Step [200/600], d_loss: 0.6678, g_loss: 2.2761, D(x): 0.74, D(G(z)): 0.16
# Epoch [59/300], Step [400/600], d_loss: 0.6594, g_loss: 2.4892, D(x): 0.81, D(G(z)): 0.25
# Epoch [59/300], Step [600/600], d_loss: 0.8644, g_loss: 2.0298, D(x): 0.69, D(G(z)): 0.16
# Saving fake_images-0060.png
# Epoch [60/300], Step [200/600], d_loss: 0.8003, g_loss: 2.9229, D(x): 0.80, D(G(z)): 0.26
# Epoch [60/300], Step [400/600], d_loss: 0.6282, g_loss: 2.3667, D(x): 0.79, D(G(z)): 0.17
# Epoch [60/300], Step [600/600], d_loss: 0.9494, g_loss: 1.8408, D(x): 0.72, D(G(z)): 0.27
# Saving fake_images-0061.png
# Epoch [61/300], Step [200/600], d_loss: 0.6392, g_loss: 2.4434, D(x): 0.80, D(G(z)): 0.21
# Epoch [61/300], Step [400/600], d_loss: 0.7721, g_loss: 2.0300, D(x): 0.76, D(G(z)): 0.23
# Epoch [61/300], Step [600/600], d_loss: 0.8506, g_loss: 2.1021, D(x): 0.71, D(G(z)): 0.23
# Saving fake_images-0062.png
# Epoch [62/300], Step [200/600], d_loss: 0.7645, g_loss: 2.2990, D(x): 0.74, D(G(z)): 0.24
# Epoch [62/300], Step [400/600], d_loss: 0.8031, g_loss: 2.0112, D(x): 0.70, D(G(z)): 0.14
# Epoch [62/300], Step [600/600], d_loss: 0.6643, g_loss: 2.7536, D(x): 0.84, D(G(z)): 0.24
# Saving fake_images-0063.png
# Epoch [63/300], Step [200/600], d_loss: 0.6305, g_loss: 1.8513, D(x): 0.80, D(G(z)): 0.22
# Epoch [63/300], Step [400/600], d_loss: 0.8038, g_loss: 1.5471, D(x): 0.80, D(G(z)): 0.30
# Epoch [63/300], Step [600/600], d_loss: 0.6013, g_loss: 1.9789, D(x): 0.80, D(G(z)): 0.22
# Saving fake_images-0064.png
# Epoch [64/300], Step [200/600], d_loss: 0.6184, g_loss: 1.4189, D(x): 0.86, D(G(z)): 0.26
# Epoch [64/300], Step [400/600], d_loss: 0.7036, g_loss: 2.5899, D(x): 0.74, D(G(z)): 0.17
# Epoch [64/300], Step [600/600], d_loss: 0.5775, g_loss: 2.3846, D(x): 0.86, D(G(z)): 0.24
# Saving fake_images-0065.png
# Epoch [65/300], Step [200/600], d_loss: 0.7920, g_loss: 2.0690, D(x): 0.74, D(G(z)): 0.18
# Epoch [65/300], Step [400/600], d_loss: 0.6077, g_loss: 2.3857, D(x): 0.86, D(G(z)): 0.27
# Epoch [65/300], Step [600/600], d_loss: 0.4776, g_loss: 2.6723, D(x): 0.83, D(G(z)): 0.15
# Saving fake_images-0066.png
# Epoch [66/300], Step [200/600], d_loss: 0.6931, g_loss: 2.0940, D(x): 0.83, D(G(z)): 0.30
# Epoch [66/300], Step [400/600], d_loss: 0.8864, g_loss: 2.7521, D(x): 0.64, D(G(z)): 0.10
# Epoch [66/300], Step [600/600], d_loss: 0.5147, g_loss: 2.4451, D(x): 0.82, D(G(z)): 0.16
# Saving fake_images-0067.png
# Epoch [67/300], Step [200/600], d_loss: 0.6034, g_loss: 2.5775, D(x): 0.81, D(G(z)): 0.21
# Epoch [67/300], Step [400/600], d_loss: 0.6674, g_loss: 2.6453, D(x): 0.88, D(G(z)): 0.29
# Epoch [67/300], Step [600/600], d_loss: 0.6582, g_loss: 2.4874, D(x): 0.78, D(G(z)): 0.18
# Saving fake_images-0068.png
# Epoch [68/300], Step [200/600], d_loss: 0.7999, g_loss: 2.4608, D(x): 0.77, D(G(z)): 0.27
# Epoch [68/300], Step [400/600], d_loss: 0.5227, g_loss: 2.1049, D(x): 0.83, D(G(z)): 0.18
# Epoch [68/300], Step [600/600], d_loss: 0.6749, g_loss: 1.9148, D(x): 0.77, D(G(z)): 0.22
# Saving fake_images-0069.png
# Epoch [69/300], Step [200/600], d_loss: 0.6755, g_loss: 2.0440, D(x): 0.81, D(G(z)): 0.27
# Epoch [69/300], Step [400/600], d_loss: 0.8426, g_loss: 2.1295, D(x): 0.70, D(G(z)): 0.18
# Epoch [69/300], Step [600/600], d_loss: 0.7803, g_loss: 2.4639, D(x): 0.69, D(G(z)): 0.13
# Saving fake_images-0070.png
# Epoch [70/300], Step [200/600], d_loss: 0.5421, g_loss: 2.4317, D(x): 0.80, D(G(z)): 0.15
# Epoch [70/300], Step [400/600], d_loss: 0.9653, g_loss: 2.3887, D(x): 0.66, D(G(z)): 0.17
# Epoch [70/300], Step [600/600], d_loss: 0.6615, g_loss: 2.7692, D(x): 0.77, D(G(z)): 0.16
# Saving fake_images-0071.png
# Epoch [71/300], Step [200/600], d_loss: 0.6751, g_loss: 2.2722, D(x): 0.71, D(G(z)): 0.14
# Epoch [71/300], Step [400/600], d_loss: 0.4977, g_loss: 2.2726, D(x): 0.85, D(G(z)): 0.18
# Epoch [71/300], Step [600/600], d_loss: 0.6024, g_loss: 2.3657, D(x): 0.81, D(G(z)): 0.19
# Saving fake_images-0072.png
# Epoch [72/300], Step [200/600], d_loss: 0.5586, g_loss: 2.6737, D(x): 0.84, D(G(z)): 0.22
# Epoch [72/300], Step [400/600], d_loss: 0.6000, g_loss: 2.4968, D(x): 0.79, D(G(z)): 0.16
# Epoch [72/300], Step [600/600], d_loss: 0.7591, g_loss: 2.1377, D(x): 0.70, D(G(z)): 0.15
# Saving fake_images-0073.png
# Epoch [73/300], Step [200/600], d_loss: 0.6383, g_loss: 2.5403, D(x): 0.80, D(G(z)): 0.23
# Epoch [73/300], Step [400/600], d_loss: 0.5595, g_loss: 2.4135, D(x): 0.86, D(G(z)): 0.26
# Epoch [73/300], Step [600/600], d_loss: 0.6922, g_loss: 2.1688, D(x): 0.80, D(G(z)): 0.21
# Saving fake_images-0074.png
# Epoch [74/300], Step [200/600], d_loss: 0.6223, g_loss: 2.0535, D(x): 0.80, D(G(z)): 0.22
# Epoch [74/300], Step [400/600], d_loss: 0.6812, g_loss: 2.4437, D(x): 0.84, D(G(z)): 0.27
# Epoch [74/300], Step [600/600], d_loss: 0.8329, g_loss: 1.8462, D(x): 0.75, D(G(z)): 0.23
# Saving fake_images-0075.png
# Epoch [75/300], Step [200/600], d_loss: 0.7323, g_loss: 2.0767, D(x): 0.74, D(G(z)): 0.22
# Epoch [75/300], Step [400/600], d_loss: 0.6943, g_loss: 2.2010, D(x): 0.74, D(G(z)): 0.20
# Epoch [75/300], Step [600/600], d_loss: 0.6180, g_loss: 2.5768, D(x): 0.78, D(G(z)): 0.18
# Saving fake_images-0076.png
# Epoch [76/300], Step [200/600], d_loss: 0.8369, g_loss: 1.5566, D(x): 0.76, D(G(z)): 0.29
# Epoch [76/300], Step [400/600], d_loss: 0.7199, g_loss: 2.0370, D(x): 0.76, D(G(z)): 0.22
# Epoch [76/300], Step [600/600], d_loss: 0.8172, g_loss: 1.6588, D(x): 0.69, D(G(z)): 0.21
# Saving fake_images-0077.png
# Epoch [77/300], Step [200/600], d_loss: 0.7634, g_loss: 1.8229, D(x): 0.71, D(G(z)): 0.18
# Epoch [77/300], Step [400/600], d_loss: 0.6895, g_loss: 2.5447, D(x): 0.72, D(G(z)): 0.15
# Epoch [77/300], Step [600/600], d_loss: 0.5652, g_loss: 2.0465, D(x): 0.81, D(G(z)): 0.20
# Saving fake_images-0078.png
# Epoch [78/300], Step [200/600], d_loss: 0.7902, g_loss: 1.0581, D(x): 0.76, D(G(z)): 0.27
# Epoch [78/300], Step [400/600], d_loss: 0.6592, g_loss: 2.7901, D(x): 0.76, D(G(z)): 0.20
# Epoch [78/300], Step [600/600], d_loss: 0.5937, g_loss: 2.9402, D(x): 0.78, D(G(z)): 0.19
# Saving fake_images-0079.png
# Epoch [79/300], Step [200/600], d_loss: 0.6244, g_loss: 1.7999, D(x): 0.82, D(G(z)): 0.24
# Epoch [79/300], Step [400/600], d_loss: 0.6375, g_loss: 1.8760, D(x): 0.77, D(G(z)): 0.20
# Epoch [79/300], Step [600/600], d_loss: 0.7215, g_loss: 2.1770, D(x): 0.74, D(G(z)): 0.22
# Saving fake_images-0080.png
# Epoch [80/300], Step [200/600], d_loss: 0.9441, g_loss: 1.6499, D(x): 0.71, D(G(z)): 0.28
# Epoch [80/300], Step [400/600], d_loss: 0.8993, g_loss: 1.7183, D(x): 0.74, D(G(z)): 0.31
# Epoch [80/300], Step [600/600], d_loss: 1.0259, g_loss: 2.2038, D(x): 0.69, D(G(z)): 0.32
# Saving fake_images-0081.png
# Epoch [81/300], Step [200/600], d_loss: 0.7532, g_loss: 2.3875, D(x): 0.76, D(G(z)): 0.26
# Epoch [81/300], Step [400/600], d_loss: 0.6796, g_loss: 2.4498, D(x): 0.72, D(G(z)): 0.14
# Epoch [81/300], Step [600/600], d_loss: 0.8512, g_loss: 1.7085, D(x): 0.74, D(G(z)): 0.31
# Saving fake_images-0082.png
# Epoch [82/300], Step [200/600], d_loss: 1.0198, g_loss: 1.9317, D(x): 0.73, D(G(z)): 0.35
# Epoch [82/300], Step [400/600], d_loss: 0.5014, g_loss: 2.8688, D(x): 0.78, D(G(z)): 0.10
# Epoch [82/300], Step [600/600], d_loss: 0.7781, g_loss: 1.8416, D(x): 0.71, D(G(z)): 0.22
# Saving fake_images-0083.png
# Epoch [83/300], Step [200/600], d_loss: 0.8961, g_loss: 1.4566, D(x): 0.68, D(G(z)): 0.23
# Epoch [83/300], Step [400/600], d_loss: 0.6446, g_loss: 2.2872, D(x): 0.79, D(G(z)): 0.21
# Epoch [83/300], Step [600/600], d_loss: 0.5015, g_loss: 2.5793, D(x): 0.84, D(G(z)): 0.21
# Saving fake_images-0084.png
# Epoch [84/300], Step [200/600], d_loss: 0.9031, g_loss: 2.1374, D(x): 0.65, D(G(z)): 0.20
# Epoch [84/300], Step [400/600], d_loss: 0.7680, g_loss: 2.1680, D(x): 0.77, D(G(z)): 0.26
# Epoch [84/300], Step [600/600], d_loss: 0.8937, g_loss: 1.6267, D(x): 0.74, D(G(z)): 0.33
# Saving fake_images-0085.png
# Epoch [85/300], Step [200/600], d_loss: 0.6635, g_loss: 2.5065, D(x): 0.72, D(G(z)): 0.15
# Epoch [85/300], Step [400/600], d_loss: 0.7490, g_loss: 1.7726, D(x): 0.80, D(G(z)): 0.31
# Epoch [85/300], Step [600/600], d_loss: 0.7957, g_loss: 1.7509, D(x): 0.82, D(G(z)): 0.32
# Saving fake_images-0086.png
# Epoch [86/300], Step [200/600], d_loss: 0.6666, g_loss: 1.8349, D(x): 0.75, D(G(z)): 0.19
# Epoch [86/300], Step [400/600], d_loss: 0.7305, g_loss: 2.4651, D(x): 0.75, D(G(z)): 0.24
# Epoch [86/300], Step [600/600], d_loss: 0.7627, g_loss: 1.3476, D(x): 0.73, D(G(z)): 0.25
# Saving fake_images-0087.png
# Epoch [87/300], Step [200/600], d_loss: 0.7157, g_loss: 1.7288, D(x): 0.75, D(G(z)): 0.24
# Epoch [87/300], Step [400/600], d_loss: 0.7586, g_loss: 1.8794, D(x): 0.76, D(G(z)): 0.28
# Epoch [87/300], Step [600/600], d_loss: 0.9814, g_loss: 2.3470, D(x): 0.57, D(G(z)): 0.15
# Saving fake_images-0088.png
# Epoch [88/300], Step [200/600], d_loss: 0.7351, g_loss: 1.8765, D(x): 0.77, D(G(z)): 0.28
# Epoch [88/300], Step [400/600], d_loss: 0.5672, g_loss: 2.2543, D(x): 0.75, D(G(z)): 0.16
# Epoch [88/300], Step [600/600], d_loss: 0.6289, g_loss: 1.5602, D(x): 0.77, D(G(z)): 0.20
# Saving fake_images-0089.png
# Epoch [89/300], Step [200/600], d_loss: 0.5348, g_loss: 2.1807, D(x): 0.84, D(G(z)): 0.23
# Epoch [89/300], Step [400/600], d_loss: 0.8385, g_loss: 1.7725, D(x): 0.75, D(G(z)): 0.30
# Epoch [89/300], Step [600/600], d_loss: 0.7171, g_loss: 1.8746, D(x): 0.76, D(G(z)): 0.25
# Saving fake_images-0090.png
# Epoch [90/300], Step [200/600], d_loss: 0.6893, g_loss: 2.6251, D(x): 0.82, D(G(z)): 0.29
# Epoch [90/300], Step [400/600], d_loss: 0.6623, g_loss: 2.0503, D(x): 0.77, D(G(z)): 0.21
# Epoch [90/300], Step [600/600], d_loss: 0.8519, g_loss: 1.9509, D(x): 0.88, D(G(z)): 0.40
# Saving fake_images-0091.png
# Epoch [91/300], Step [200/600], d_loss: 0.8646, g_loss: 2.0584, D(x): 0.70, D(G(z)): 0.25
# Epoch [91/300], Step [400/600], d_loss: 0.9453, g_loss: 1.8244, D(x): 0.79, D(G(z)): 0.36
# Epoch [91/300], Step [600/600], d_loss: 0.7076, g_loss: 2.3169, D(x): 0.76, D(G(z)): 0.19
# Saving fake_images-0092.png
# Epoch [92/300], Step [200/600], d_loss: 0.6829, g_loss: 2.1372, D(x): 0.77, D(G(z)): 0.23
# Epoch [92/300], Step [400/600], d_loss: 0.8138, g_loss: 2.0074, D(x): 0.75, D(G(z)): 0.29
# Epoch [92/300], Step [600/600], d_loss: 0.8063, g_loss: 1.5814, D(x): 0.76, D(G(z)): 0.27
# Saving fake_images-0093.png
# Epoch [93/300], Step [200/600], d_loss: 0.6967, g_loss: 2.0067, D(x): 0.78, D(G(z)): 0.26
# Epoch [93/300], Step [400/600], d_loss: 0.8784, g_loss: 1.9357, D(x): 0.81, D(G(z)): 0.35
# Epoch [93/300], Step [600/600], d_loss: 0.9899, g_loss: 2.0163, D(x): 0.72, D(G(z)): 0.32
# Saving fake_images-0094.png
# Epoch [94/300], Step [200/600], d_loss: 0.6805, g_loss: 2.0865, D(x): 0.82, D(G(z)): 0.28
# Epoch [94/300], Step [400/600], d_loss: 0.8160, g_loss: 1.8826, D(x): 0.77, D(G(z)): 0.31
# Epoch [94/300], Step [600/600], d_loss: 0.7292, g_loss: 1.4162, D(x): 0.81, D(G(z)): 0.31
# Saving fake_images-0095.png
# Epoch [95/300], Step [200/600], d_loss: 0.8647, g_loss: 1.6518, D(x): 0.70, D(G(z)): 0.25
# Epoch [95/300], Step [400/600], d_loss: 0.8823, g_loss: 2.1177, D(x): 0.69, D(G(z)): 0.24
# Epoch [95/300], Step [600/600], d_loss: 0.7707, g_loss: 2.3620, D(x): 0.71, D(G(z)): 0.20
# Saving fake_images-0096.png
# Epoch [96/300], Step [200/600], d_loss: 0.7583, g_loss: 2.2729, D(x): 0.75, D(G(z)): 0.25
# Epoch [96/300], Step [400/600], d_loss: 0.8642, g_loss: 1.9316, D(x): 0.79, D(G(z)): 0.36
# Epoch [96/300], Step [600/600], d_loss: 0.7183, g_loss: 2.0320, D(x): 0.79, D(G(z)): 0.26
# Saving fake_images-0097.png
# Epoch [97/300], Step [200/600], d_loss: 0.6626, g_loss: 2.5341, D(x): 0.75, D(G(z)): 0.20
# Epoch [97/300], Step [400/600], d_loss: 0.5442, g_loss: 2.1842, D(x): 0.82, D(G(z)): 0.21
# Epoch [97/300], Step [600/600], d_loss: 0.7694, g_loss: 1.6914, D(x): 0.78, D(G(z)): 0.28
# Saving fake_images-0098.png
# Epoch [98/300], Step [200/600], d_loss: 0.7930, g_loss: 1.9716, D(x): 0.75, D(G(z)): 0.29
# Epoch [98/300], Step [400/600], d_loss: 0.7458, g_loss: 1.8185, D(x): 0.77, D(G(z)): 0.26
# Epoch [98/300], Step [600/600], d_loss: 0.9846, g_loss: 1.8306, D(x): 0.65, D(G(z)): 0.24
# Saving fake_images-0099.png
# Epoch [99/300], Step [200/600], d_loss: 0.6692, g_loss: 1.6656, D(x): 0.77, D(G(z)): 0.23
# Epoch [99/300], Step [400/600], d_loss: 0.7255, g_loss: 1.9703, D(x): 0.72, D(G(z)): 0.19
# Epoch [99/300], Step [600/600], d_loss: 0.8421, g_loss: 1.9770, D(x): 0.80, D(G(z)): 0.34
# Saving fake_images-0100.png
# Epoch [100/300], Step [200/600], d_loss: 0.7620, g_loss: 2.2447, D(x): 0.77, D(G(z)): 0.29
# Epoch [100/300], Step [400/600], d_loss: 1.0808, g_loss: 1.3294, D(x): 0.78, D(G(z)): 0.45
# Epoch [100/300], Step [600/600], d_loss: 0.8897, g_loss: 2.1396, D(x): 0.75, D(G(z)): 0.31
# Saving fake_images-0101.png
# Epoch [101/300], Step [200/600], d_loss: 0.9941, g_loss: 1.3264, D(x): 0.73, D(G(z)): 0.35
# Epoch [101/300], Step [400/600], d_loss: 0.6935, g_loss: 2.1927, D(x): 0.83, D(G(z)): 0.30
# Epoch [101/300], Step [600/600], d_loss: 0.7340, g_loss: 2.1049, D(x): 0.80, D(G(z)): 0.26
# Saving fake_images-0102.png
# Epoch [102/300], Step [200/600], d_loss: 0.8287, g_loss: 1.2818, D(x): 0.84, D(G(z)): 0.38
# Epoch [102/300], Step [400/600], d_loss: 0.9219, g_loss: 1.5259, D(x): 0.76, D(G(z)): 0.33
# Epoch [102/300], Step [600/600], d_loss: 0.7337, g_loss: 2.0987, D(x): 0.73, D(G(z)): 0.20
# Saving fake_images-0103.png
# Epoch [103/300], Step [200/600], d_loss: 0.9212, g_loss: 1.5339, D(x): 0.75, D(G(z)): 0.35
# Epoch [103/300], Step [400/600], d_loss: 0.7656, g_loss: 1.8411, D(x): 0.70, D(G(z)): 0.19
# Epoch [103/300], Step [600/600], d_loss: 0.6997, g_loss: 2.2492, D(x): 0.85, D(G(z)): 0.32
# Saving fake_images-0104.png
# Epoch [104/300], Step [200/600], d_loss: 0.9407, g_loss: 1.1144, D(x): 0.71, D(G(z)): 0.34
# Epoch [104/300], Step [400/600], d_loss: 0.6279, g_loss: 1.7372, D(x): 0.86, D(G(z)): 0.29
# Epoch [104/300], Step [600/600], d_loss: 0.9900, g_loss: 1.7653, D(x): 0.72, D(G(z)): 0.36
# Saving fake_images-0105.png
# Epoch [105/300], Step [200/600], d_loss: 0.7996, g_loss: 1.8414, D(x): 0.75, D(G(z)): 0.26
# Epoch [105/300], Step [400/600], d_loss: 0.6989, g_loss: 1.8099, D(x): 0.76, D(G(z)): 0.24
# Epoch [105/300], Step [600/600], d_loss: 0.8200, g_loss: 1.9494, D(x): 0.78, D(G(z)): 0.31
# Saving fake_images-0106.png
# Epoch [106/300], Step [200/600], d_loss: 0.8749, g_loss: 1.4764, D(x): 0.73, D(G(z)): 0.29
# Epoch [106/300], Step [400/600], d_loss: 0.7976, g_loss: 1.4482, D(x): 0.80, D(G(z)): 0.35
# Epoch [106/300], Step [600/600], d_loss: 0.8139, g_loss: 2.1224, D(x): 0.76, D(G(z)): 0.29
# Saving fake_images-0107.png
# Epoch [107/300], Step [200/600], d_loss: 1.0462, g_loss: 1.9381, D(x): 0.61, D(G(z)): 0.22
# Epoch [107/300], Step [400/600], d_loss: 0.9439, g_loss: 1.7555, D(x): 0.69, D(G(z)): 0.27
# Epoch [107/300], Step [600/600], d_loss: 0.5919, g_loss: 1.6281, D(x): 0.84, D(G(z)): 0.27
# Saving fake_images-0108.png
# Epoch [108/300], Step [200/600], d_loss: 0.7484, g_loss: 1.8337, D(x): 0.76, D(G(z)): 0.27
# Epoch [108/300], Step [400/600], d_loss: 0.8418, g_loss: 2.0263, D(x): 0.76, D(G(z)): 0.30
# Epoch [108/300], Step [600/600], d_loss: 0.8254, g_loss: 2.1951, D(x): 0.73, D(G(z)): 0.29
# Saving fake_images-0109.png
# Epoch [109/300], Step [200/600], d_loss: 0.7989, g_loss: 2.0355, D(x): 0.73, D(G(z)): 0.26
# Epoch [109/300], Step [400/600], d_loss: 0.8954, g_loss: 1.6478, D(x): 0.73, D(G(z)): 0.27
# Epoch [109/300], Step [600/600], d_loss: 0.8348, g_loss: 1.9923, D(x): 0.73, D(G(z)): 0.29
# Saving fake_images-0110.png
# Epoch [110/300], Step [200/600], d_loss: 0.9521, g_loss: 1.8241, D(x): 0.66, D(G(z)): 0.25
# Epoch [110/300], Step [400/600], d_loss: 0.9569, g_loss: 1.6815, D(x): 0.66, D(G(z)): 0.22
# Epoch [110/300], Step [600/600], d_loss: 0.8757, g_loss: 1.9070, D(x): 0.69, D(G(z)): 0.25
# Saving fake_images-0111.png
# Epoch [111/300], Step [200/600], d_loss: 0.7649, g_loss: 1.7570, D(x): 0.76, D(G(z)): 0.28
# Epoch [111/300], Step [400/600], d_loss: 0.8400, g_loss: 1.5256, D(x): 0.72, D(G(z)): 0.26
# Epoch [111/300], Step [600/600], d_loss: 0.7916, g_loss: 2.3563, D(x): 0.76, D(G(z)): 0.28
# Saving fake_images-0112.png
# Epoch [112/300], Step [200/600], d_loss: 0.7212, g_loss: 1.8159, D(x): 0.79, D(G(z)): 0.28
# Epoch [112/300], Step [400/600], d_loss: 0.7946, g_loss: 1.9146, D(x): 0.73, D(G(z)): 0.24
# Epoch [112/300], Step [600/600], d_loss: 0.8563, g_loss: 1.4179, D(x): 0.76, D(G(z)): 0.32
# Saving fake_images-0113.png
# Epoch [113/300], Step [200/600], d_loss: 0.8287, g_loss: 1.7285, D(x): 0.71, D(G(z)): 0.27
# Epoch [113/300], Step [400/600], d_loss: 0.7794, g_loss: 1.8049, D(x): 0.76, D(G(z)): 0.28
# Epoch [113/300], Step [600/600], d_loss: 0.8254, g_loss: 1.5496, D(x): 0.82, D(G(z)): 0.33
# Saving fake_images-0114.png
# Epoch [114/300], Step [200/600], d_loss: 1.0134, g_loss: 1.9609, D(x): 0.67, D(G(z)): 0.30
# Epoch [114/300], Step [400/600], d_loss: 1.0119, g_loss: 1.3773, D(x): 0.77, D(G(z)): 0.39
# Epoch [114/300], Step [600/600], d_loss: 0.8480, g_loss: 1.9047, D(x): 0.69, D(G(z)): 0.27
# Saving fake_images-0115.png
# Epoch [115/300], Step [200/600], d_loss: 0.8423, g_loss: 1.2525, D(x): 0.69, D(G(z)): 0.26
# Epoch [115/300], Step [400/600], d_loss: 0.8787, g_loss: 2.3294, D(x): 0.71, D(G(z)): 0.23
# Epoch [115/300], Step [600/600], d_loss: 0.7369, g_loss: 1.8181, D(x): 0.75, D(G(z)): 0.27
# Saving fake_images-0116.png
# Epoch [116/300], Step [200/600], d_loss: 0.9777, g_loss: 1.4403, D(x): 0.79, D(G(z)): 0.39
# Epoch [116/300], Step [400/600], d_loss: 1.0371, g_loss: 1.6913, D(x): 0.71, D(G(z)): 0.38
# Epoch [116/300], Step [600/600], d_loss: 0.6240, g_loss: 2.4240, D(x): 0.78, D(G(z)): 0.22
# Saving fake_images-0117.png
# Epoch [117/300], Step [200/600], d_loss: 0.6843, g_loss: 1.9520, D(x): 0.74, D(G(z)): 0.22
# Epoch [117/300], Step [400/600], d_loss: 0.8918, g_loss: 2.0321, D(x): 0.73, D(G(z)): 0.27
# Epoch [117/300], Step [600/600], d_loss: 0.8479, g_loss: 1.6759, D(x): 0.67, D(G(z)): 0.20
# Saving fake_images-0118.png
# Epoch [118/300], Step [200/600], d_loss: 0.9890, g_loss: 1.4684, D(x): 0.66, D(G(z)): 0.27
# Epoch [118/300], Step [400/600], d_loss: 0.9000, g_loss: 1.5484, D(x): 0.74, D(G(z)): 0.33
# Epoch [118/300], Step [600/600], d_loss: 0.8612, g_loss: 1.9287, D(x): 0.65, D(G(z)): 0.20
# Saving fake_images-0119.png
# Epoch [119/300], Step [200/600], d_loss: 0.7239, g_loss: 1.7009, D(x): 0.75, D(G(z)): 0.26
# Epoch [119/300], Step [400/600], d_loss: 0.7624, g_loss: 1.3910, D(x): 0.80, D(G(z)): 0.31
# Epoch [119/300], Step [600/600], d_loss: 0.6839, g_loss: 1.8308, D(x): 0.83, D(G(z)): 0.31
# Saving fake_images-0120.png
# Epoch [120/300], Step [200/600], d_loss: 0.7648, g_loss: 1.8417, D(x): 0.78, D(G(z)): 0.31
# Epoch [120/300], Step [400/600], d_loss: 0.8147, g_loss: 1.6247, D(x): 0.72, D(G(z)): 0.25
# Epoch [120/300], Step [600/600], d_loss: 0.8756, g_loss: 1.5452, D(x): 0.67, D(G(z)): 0.24
# Saving fake_images-0121.png
# Epoch [121/300], Step [200/600], d_loss: 0.7673, g_loss: 1.9393, D(x): 0.70, D(G(z)): 0.22
# Epoch [121/300], Step [400/600], d_loss: 0.8717, g_loss: 2.0285, D(x): 0.65, D(G(z)): 0.22
# Epoch [121/300], Step [600/600], d_loss: 0.8216, g_loss: 1.6770, D(x): 0.73, D(G(z)): 0.27
# Saving fake_images-0122.png
# Epoch [122/300], Step [200/600], d_loss: 0.8067, g_loss: 1.5551, D(x): 0.67, D(G(z)): 0.21
# Epoch [122/300], Step [400/600], d_loss: 0.7940, g_loss: 1.5823, D(x): 0.73, D(G(z)): 0.29
# Epoch [122/300], Step [600/600], d_loss: 1.0644, g_loss: 1.4094, D(x): 0.78, D(G(z)): 0.43
# Saving fake_images-0123.png
# Epoch [123/300], Step [200/600], d_loss: 1.1464, g_loss: 1.7923, D(x): 0.65, D(G(z)): 0.34
# Epoch [123/300], Step [400/600], d_loss: 0.7743, g_loss: 1.9601, D(x): 0.77, D(G(z)): 0.32
# Epoch [123/300], Step [600/600], d_loss: 0.8941, g_loss: 1.4651, D(x): 0.77, D(G(z)): 0.36
# Saving fake_images-0124.png
# Epoch [124/300], Step [200/600], d_loss: 0.7431, g_loss: 1.0794, D(x): 0.85, D(G(z)): 0.33
# Epoch [124/300], Step [400/600], d_loss: 0.9121, g_loss: 1.7828, D(x): 0.73, D(G(z)): 0.32
# Epoch [124/300], Step [600/600], d_loss: 0.8718, g_loss: 1.3787, D(x): 0.71, D(G(z)): 0.28
# Saving fake_images-0125.png
# Epoch [125/300], Step [200/600], d_loss: 0.9640, g_loss: 1.6413, D(x): 0.64, D(G(z)): 0.22
# Epoch [125/300], Step [400/600], d_loss: 1.2943, g_loss: 1.2208, D(x): 0.74, D(G(z)): 0.50
# Epoch [125/300], Step [600/600], d_loss: 0.8654, g_loss: 1.8650, D(x): 0.71, D(G(z)): 0.24
# Saving fake_images-0126.png
# Epoch [126/300], Step [200/600], d_loss: 0.9025, g_loss: 1.8870, D(x): 0.69, D(G(z)): 0.28
# Epoch [126/300], Step [400/600], d_loss: 0.6517, g_loss: 1.7157, D(x): 0.82, D(G(z)): 0.28
# Epoch [126/300], Step [600/600], d_loss: 1.0157, g_loss: 1.6336, D(x): 0.60, D(G(z)): 0.24
# Saving fake_images-0127.png
# Epoch [127/300], Step [200/600], d_loss: 0.8406, g_loss: 1.6135, D(x): 0.74, D(G(z)): 0.32
# Epoch [127/300], Step [400/600], d_loss: 0.7303, g_loss: 1.3741, D(x): 0.77, D(G(z)): 0.28
# Epoch [127/300], Step [600/600], d_loss: 1.0163, g_loss: 1.5443, D(x): 0.79, D(G(z)): 0.43
# Saving fake_images-0128.png
# Epoch [128/300], Step [200/600], d_loss: 0.9467, g_loss: 1.4818, D(x): 0.77, D(G(z)): 0.34
# Epoch [128/300], Step [400/600], d_loss: 0.9909, g_loss: 2.0764, D(x): 0.72, D(G(z)): 0.32
# Epoch [128/300], Step [600/600], d_loss: 0.8878, g_loss: 1.7012, D(x): 0.76, D(G(z)): 0.34
# Saving fake_images-0129.png
# Epoch [129/300], Step [200/600], d_loss: 0.9640, g_loss: 1.8409, D(x): 0.65, D(G(z)): 0.26
# Epoch [129/300], Step [400/600], d_loss: 0.9011, g_loss: 1.9539, D(x): 0.66, D(G(z)): 0.22
# Epoch [129/300], Step [600/600], d_loss: 0.8015, g_loss: 1.8551, D(x): 0.77, D(G(z)): 0.29
# Saving fake_images-0130.png
# Epoch [130/300], Step [200/600], d_loss: 0.8588, g_loss: 1.6313, D(x): 0.76, D(G(z)): 0.31
# Epoch [130/300], Step [400/600], d_loss: 0.7606, g_loss: 1.6016, D(x): 0.73, D(G(z)): 0.25
# Epoch [130/300], Step [600/600], d_loss: 1.0312, g_loss: 1.8882, D(x): 0.67, D(G(z)): 0.28
# Saving fake_images-0131.png
# Epoch [131/300], Step [200/600], d_loss: 0.8293, g_loss: 1.8634, D(x): 0.72, D(G(z)): 0.28
# Epoch [131/300], Step [400/600], d_loss: 0.8434, g_loss: 1.4724, D(x): 0.71, D(G(z)): 0.27
# Epoch [131/300], Step [600/600], d_loss: 0.9271, g_loss: 1.9215, D(x): 0.71, D(G(z)): 0.28
# Saving fake_images-0132.png
# Epoch [132/300], Step [200/600], d_loss: 0.7466, g_loss: 1.9637, D(x): 0.78, D(G(z)): 0.29
# Epoch [132/300], Step [400/600], d_loss: 0.9193, g_loss: 1.6937, D(x): 0.64, D(G(z)): 0.20
# Epoch [132/300], Step [600/600], d_loss: 0.8042, g_loss: 1.3066, D(x): 0.77, D(G(z)): 0.32
# Saving fake_images-0133.png
# Epoch [133/300], Step [200/600], d_loss: 0.6841, g_loss: 1.7830, D(x): 0.77, D(G(z)): 0.27
# Epoch [133/300], Step [400/600], d_loss: 1.1466, g_loss: 1.2535, D(x): 0.68, D(G(z)): 0.37
# Epoch [133/300], Step [600/600], d_loss: 0.8212, g_loss: 1.9663, D(x): 0.70, D(G(z)): 0.26
# Saving fake_images-0134.png
# Epoch [134/300], Step [200/600], d_loss: 0.7762, g_loss: 1.6124, D(x): 0.74, D(G(z)): 0.25
# Epoch [134/300], Step [400/600], d_loss: 0.6983, g_loss: 2.3772, D(x): 0.76, D(G(z)): 0.23
# Epoch [134/300], Step [600/600], d_loss: 0.8694, g_loss: 1.9265, D(x): 0.66, D(G(z)): 0.21
# Saving fake_images-0135.png
# Epoch [135/300], Step [200/600], d_loss: 0.6619, g_loss: 2.1052, D(x): 0.76, D(G(z)): 0.24
# Epoch [135/300], Step [400/600], d_loss: 0.7007, g_loss: 1.4355, D(x): 0.74, D(G(z)): 0.24
# Epoch [135/300], Step [600/600], d_loss: 0.8085, g_loss: 2.0431, D(x): 0.71, D(G(z)): 0.26
# Saving fake_images-0136.png
# Epoch [136/300], Step [200/600], d_loss: 0.8943, g_loss: 1.8982, D(x): 0.72, D(G(z)): 0.31
# Epoch [136/300], Step [400/600], d_loss: 1.2709, g_loss: 1.3791, D(x): 0.64, D(G(z)): 0.36
# Epoch [136/300], Step [600/600], d_loss: 0.9064, g_loss: 1.7532, D(x): 0.67, D(G(z)): 0.27
# Saving fake_images-0137.png
# Epoch [137/300], Step [200/600], d_loss: 0.8278, g_loss: 1.5192, D(x): 0.70, D(G(z)): 0.24
# Epoch [137/300], Step [400/600], d_loss: 0.9272, g_loss: 1.6255, D(x): 0.78, D(G(z)): 0.38
# Epoch [137/300], Step [600/600], d_loss: 0.7666, g_loss: 1.7541, D(x): 0.72, D(G(z)): 0.24
# Saving fake_images-0138.png
# Epoch [138/300], Step [200/600], d_loss: 0.8956, g_loss: 1.6143, D(x): 0.78, D(G(z)): 0.34
# Epoch [138/300], Step [400/600], d_loss: 0.7479, g_loss: 1.9879, D(x): 0.75, D(G(z)): 0.27
# Epoch [138/300], Step [600/600], d_loss: 1.0264, g_loss: 1.5240, D(x): 0.70, D(G(z)): 0.35
# Saving fake_images-0139.png
# Epoch [139/300], Step [200/600], d_loss: 0.9826, g_loss: 1.8766, D(x): 0.60, D(G(z)): 0.20
# Epoch [139/300], Step [400/600], d_loss: 0.9623, g_loss: 1.7265, D(x): 0.78, D(G(z)): 0.39
# Epoch [139/300], Step [600/600], d_loss: 0.8782, g_loss: 1.6508, D(x): 0.70, D(G(z)): 0.29
# Saving fake_images-0140.png
# Epoch [140/300], Step [200/600], d_loss: 0.8326, g_loss: 1.7833, D(x): 0.67, D(G(z)): 0.21
# Epoch [140/300], Step [400/600], d_loss: 0.8013, g_loss: 1.8836, D(x): 0.76, D(G(z)): 0.32
# Epoch [140/300], Step [600/600], d_loss: 0.7478, g_loss: 1.6165, D(x): 0.76, D(G(z)): 0.28
# Saving fake_images-0141.png
# Epoch [141/300], Step [200/600], d_loss: 0.9175, g_loss: 1.7362, D(x): 0.72, D(G(z)): 0.30
# Epoch [141/300], Step [400/600], d_loss: 0.6806, g_loss: 1.3943, D(x): 0.73, D(G(z)): 0.20
# Epoch [141/300], Step [600/600], d_loss: 0.9203, g_loss: 1.4947, D(x): 0.70, D(G(z)): 0.30
# Saving fake_images-0142.png
# Epoch [142/300], Step [200/600], d_loss: 0.9393, g_loss: 1.4165, D(x): 0.72, D(G(z)): 0.32
# Epoch [142/300], Step [400/600], d_loss: 0.9976, g_loss: 1.3209, D(x): 0.72, D(G(z)): 0.37
# Epoch [142/300], Step [600/600], d_loss: 0.7578, g_loss: 1.6183, D(x): 0.73, D(G(z)): 0.25
# Saving fake_images-0143.png
# Epoch [143/300], Step [200/600], d_loss: 0.7986, g_loss: 1.8606, D(x): 0.76, D(G(z)): 0.28
# Epoch [143/300], Step [400/600], d_loss: 0.8239, g_loss: 1.9794, D(x): 0.71, D(G(z)): 0.27
# Epoch [143/300], Step [600/600], d_loss: 0.9647, g_loss: 1.7223, D(x): 0.73, D(G(z)): 0.35
# Saving fake_images-0144.png
# Epoch [144/300], Step [200/600], d_loss: 0.8429, g_loss: 1.9800, D(x): 0.73, D(G(z)): 0.29
# Epoch [144/300], Step [400/600], d_loss: 0.8184, g_loss: 1.4942, D(x): 0.77, D(G(z)): 0.30
# Epoch [144/300], Step [600/600], d_loss: 0.9612, g_loss: 1.6157, D(x): 0.72, D(G(z)): 0.34
# Saving fake_images-0145.png
# Epoch [145/300], Step [200/600], d_loss: 0.9830, g_loss: 1.0332, D(x): 0.75, D(G(z)): 0.37
# Epoch [145/300], Step [400/600], d_loss: 1.0335, g_loss: 1.5464, D(x): 0.66, D(G(z)): 0.34
# Epoch [145/300], Step [600/600], d_loss: 0.9090, g_loss: 1.8967, D(x): 0.64, D(G(z)): 0.22
# Saving fake_images-0146.png
# Epoch [146/300], Step [200/600], d_loss: 0.7927, g_loss: 1.8757, D(x): 0.69, D(G(z)): 0.24
# Epoch [146/300], Step [400/600], d_loss: 0.7987, g_loss: 1.6509, D(x): 0.71, D(G(z)): 0.25
# Epoch [146/300], Step [600/600], d_loss: 0.8119, g_loss: 1.8058, D(x): 0.70, D(G(z)): 0.24
# Saving fake_images-0147.png
# Epoch [147/300], Step [200/600], d_loss: 0.8060, g_loss: 2.0585, D(x): 0.67, D(G(z)): 0.23
# Epoch [147/300], Step [400/600], d_loss: 1.0017, g_loss: 1.5994, D(x): 0.64, D(G(z)): 0.29
# Epoch [147/300], Step [600/600], d_loss: 0.9291, g_loss: 1.9099, D(x): 0.68, D(G(z)): 0.25
# Saving fake_images-0148.png
# Epoch [148/300], Step [200/600], d_loss: 0.9267, g_loss: 1.6758, D(x): 0.70, D(G(z)): 0.33
# Epoch [148/300], Step [400/600], d_loss: 0.7878, g_loss: 2.0374, D(x): 0.72, D(G(z)): 0.25
# Epoch [148/300], Step [600/600], d_loss: 1.2594, g_loss: 1.7436, D(x): 0.56, D(G(z)): 0.25
# Saving fake_images-0149.png
# Epoch [149/300], Step [200/600], d_loss: 1.1208, g_loss: 1.4406, D(x): 0.68, D(G(z)): 0.38
# Epoch [149/300], Step [400/600], d_loss: 0.8260, g_loss: 1.5721, D(x): 0.68, D(G(z)): 0.24
# Epoch [149/300], Step [600/600], d_loss: 1.0035, g_loss: 1.6312, D(x): 0.67, D(G(z)): 0.33
# Saving fake_images-0150.png
# Epoch [150/300], Step [200/600], d_loss: 0.8916, g_loss: 1.7107, D(x): 0.67, D(G(z)): 0.28
# Epoch [150/300], Step [400/600], d_loss: 0.8612, g_loss: 1.6213, D(x): 0.71, D(G(z)): 0.29
# Epoch [150/300], Step [600/600], d_loss: 0.8866, g_loss: 1.7964, D(x): 0.79, D(G(z)): 0.33
# Saving fake_images-0151.png
# Epoch [151/300], Step [200/600], d_loss: 0.8541, g_loss: 1.3691, D(x): 0.72, D(G(z)): 0.31
# Epoch [151/300], Step [400/600], d_loss: 0.9255, g_loss: 1.6391, D(x): 0.67, D(G(z)): 0.28
# Epoch [151/300], Step [600/600], d_loss: 0.7151, g_loss: 2.1216, D(x): 0.79, D(G(z)): 0.26
# Saving fake_images-0152.png
# Epoch [152/300], Step [200/600], d_loss: 0.8269, g_loss: 1.6792, D(x): 0.73, D(G(z)): 0.28
# Epoch [152/300], Step [400/600], d_loss: 0.7395, g_loss: 1.7922, D(x): 0.75, D(G(z)): 0.24
# Epoch [152/300], Step [600/600], d_loss: 0.8561, g_loss: 2.1113, D(x): 0.75, D(G(z)): 0.30
# Saving fake_images-0153.png
# Epoch [153/300], Step [200/600], d_loss: 1.0542, g_loss: 1.1167, D(x): 0.72, D(G(z)): 0.39
# Epoch [153/300], Step [400/600], d_loss: 0.8084, g_loss: 1.8037, D(x): 0.77, D(G(z)): 0.32
# Epoch [153/300], Step [600/600], d_loss: 0.8976, g_loss: 1.6882, D(x): 0.69, D(G(z)): 0.27
# Saving fake_images-0154.png
# Epoch [154/300], Step [200/600], d_loss: 0.7711, g_loss: 2.0511, D(x): 0.72, D(G(z)): 0.26
# Epoch [154/300], Step [400/600], d_loss: 0.7430, g_loss: 2.3257, D(x): 0.74, D(G(z)): 0.25
# Epoch [154/300], Step [600/600], d_loss: 0.9340, g_loss: 1.5454, D(x): 0.71, D(G(z)): 0.32
# Saving fake_images-0155.png
# Epoch [155/300], Step [200/600], d_loss: 1.1992, g_loss: 1.2102, D(x): 0.65, D(G(z)): 0.39
# Epoch [155/300], Step [400/600], d_loss: 0.9735, g_loss: 1.4864, D(x): 0.69, D(G(z)): 0.32
# Epoch [155/300], Step [600/600], d_loss: 0.8790, g_loss: 1.3534, D(x): 0.73, D(G(z)): 0.31
# Saving fake_images-0156.png
# Epoch [156/300], Step [200/600], d_loss: 0.9551, g_loss: 1.7827, D(x): 0.68, D(G(z)): 0.30
# Epoch [156/300], Step [400/600], d_loss: 0.8148, g_loss: 1.9866, D(x): 0.77, D(G(z)): 0.33
# Epoch [156/300], Step [600/600], d_loss: 1.0984, g_loss: 1.1366, D(x): 0.66, D(G(z)): 0.36
# Saving fake_images-0157.png
# Epoch [157/300], Step [200/600], d_loss: 0.9466, g_loss: 1.5666, D(x): 0.62, D(G(z)): 0.23
# Epoch [157/300], Step [400/600], d_loss: 1.0490, g_loss: 1.9274, D(x): 0.77, D(G(z)): 0.43
# Epoch [157/300], Step [600/600], d_loss: 0.8470, g_loss: 1.5291, D(x): 0.71, D(G(z)): 0.29
# Saving fake_images-0158.png
# Epoch [158/300], Step [200/600], d_loss: 0.8960, g_loss: 1.8930, D(x): 0.72, D(G(z)): 0.31
# Epoch [158/300], Step [400/600], d_loss: 0.9355, g_loss: 1.8362, D(x): 0.77, D(G(z)): 0.34
# Epoch [158/300], Step [600/600], d_loss: 0.8316, g_loss: 1.7529, D(x): 0.71, D(G(z)): 0.28
# Saving fake_images-0159.png
# Epoch [159/300], Step [200/600], d_loss: 0.8460, g_loss: 1.3640, D(x): 0.68, D(G(z)): 0.23
# Epoch [159/300], Step [400/600], d_loss: 0.7358, g_loss: 1.9776, D(x): 0.70, D(G(z)): 0.22
# Epoch [159/300], Step [600/600], d_loss: 0.8884, g_loss: 1.4691, D(x): 0.61, D(G(z)): 0.18
# Saving fake_images-0160.png
# Epoch [160/300], Step [200/600], d_loss: 0.7994, g_loss: 1.4733, D(x): 0.81, D(G(z)): 0.34
# ...
# Epoch [247/300], Step [400/600], d_loss: 0.9285, g_loss: 1.5063, D(x): 0.72, D(G(z)): 0.31
# Epoch [247/300], Step [600/600], d_loss: 0.9446, g_loss: 2.0839, D(x): 0.68, D(G(z)): 0.30
# Saving fake_images-0248.png
# Epoch [248/300], Step [200/600], d_loss: 0.9496, g_loss: 1.5739, D(x): 0.68, D(G(z)): 0.33
# Epoch [248/300], Step [400/600], d_loss: 0.7211, g_loss: 1.7008, D(x): 0.79, D(G(z)): 0.31
# Epoch [248/300], Step [600/600], d_loss: 0.8390, g_loss: 1.3042, D(x): 0.79, D(G(z)): 0.35
# Saving fake_images-0249.png
# Epoch [249/300], Step [200/600], d_loss: 0.9770, g_loss: 1.3990, D(x): 0.68, D(G(z)): 0.32
# Epoch [249/300], Step [400/600], d_loss: 1.1228, g_loss: 1.3546, D(x): 0.58, D(G(z)): 0.28
# Epoch [249/300], Step [600/600], d_loss: 0.8119, g_loss: 1.5784, D(x): 0.68, D(G(z)): 0.26
# Saving fake_images-0250.png
# Epoch [250/300], Step [200/600], d_loss: 0.8309, g_loss: 1.3447, D(x): 0.67, D(G(z)): 0.24
# Epoch [250/300], Step [400/600], d_loss: 0.8724, g_loss: 1.7702, D(x): 0.71, D(G(z)): 0.28
# Epoch [250/300], Step [600/600], d_loss: 0.9360, g_loss: 1.3242, D(x): 0.72, D(G(z)): 0.33
# Saving fake_images-0251.png
# Epoch [251/300], Step [200/600], d_loss: 0.8876, g_loss: 1.2859, D(x): 0.76, D(G(z)): 0.36
# Epoch [251/300], Step [400/600], d_loss: 0.9161, g_loss: 1.5021, D(x): 0.69, D(G(z)): 0.30
# Epoch [251/300], Step [600/600], d_loss: 1.0251, g_loss: 1.4305, D(x): 0.75, D(G(z)): 0.40
# Saving fake_images-0252.png
# Epoch [252/300], Step [200/600], d_loss: 0.8738, g_loss: 1.3734, D(x): 0.74, D(G(z)): 0.33
# Epoch [252/300], Step [400/600], d_loss: 0.8956, g_loss: 1.4939, D(x): 0.73, D(G(z)): 0.31
# Epoch [252/300], Step [600/600], d_loss: 0.8447, g_loss: 1.4685, D(x): 0.77, D(G(z)): 0.33
# Saving fake_images-0253.png
# Epoch [253/300], Step [200/600], d_loss: 1.0122, g_loss: 1.2091, D(x): 0.67, D(G(z)): 0.35
# Epoch [253/300], Step [400/600], d_loss: 0.8952, g_loss: 1.7503, D(x): 0.66, D(G(z)): 0.24
# Epoch [253/300], Step [600/600], d_loss: 0.8070, g_loss: 1.3301, D(x): 0.74, D(G(z)): 0.30
# Saving fake_images-0254.png
# Epoch [254/300], Step [200/600], d_loss: 0.8594, g_loss: 2.0361, D(x): 0.71, D(G(z)): 0.27
# Epoch [254/300], Step [400/600], d_loss: 1.1387, g_loss: 1.6480, D(x): 0.57, D(G(z)): 0.25
# Epoch [254/300], Step [600/600], d_loss: 0.8675, g_loss: 1.4057, D(x): 0.72, D(G(z)): 0.32
# Saving fake_images-0255.png
# Epoch [255/300], Step [200/600], d_loss: 0.8486, g_loss: 1.3138, D(x): 0.68, D(G(z)): 0.24
# Epoch [255/300], Step [400/600], d_loss: 1.0159, g_loss: 1.3214, D(x): 0.70, D(G(z)): 0.37
# Epoch [255/300], Step [600/600], d_loss: 0.8050, g_loss: 1.3824, D(x): 0.78, D(G(z)): 0.33
# Saving fake_images-0256.png
# Epoch [256/300], Step [200/600], d_loss: 0.9739, g_loss: 1.5980, D(x): 0.63, D(G(z)): 0.26
# Epoch [256/300], Step [400/600], d_loss: 0.8056, g_loss: 1.3777, D(x): 0.75, D(G(z)): 0.32
# Epoch [256/300], Step [600/600], d_loss: 0.8264, g_loss: 1.8684, D(x): 0.69, D(G(z)): 0.21
# Saving fake_images-0257.png
# Epoch [257/300], Step [200/600], d_loss: 0.8449, g_loss: 1.5683, D(x): 0.66, D(G(z)): 0.21
# Epoch [257/300], Step [400/600], d_loss: 0.9009, g_loss: 1.6529, D(x): 0.64, D(G(z)): 0.24
# Epoch [257/300], Step [600/600], d_loss: 1.0380, g_loss: 1.5810, D(x): 0.65, D(G(z)): 0.34
# Saving fake_images-0258.png
# Epoch [258/300], Step [200/600], d_loss: 0.8244, g_loss: 1.5697, D(x): 0.80, D(G(z)): 0.35
# Epoch [258/300], Step [400/600], d_loss: 0.9283, g_loss: 1.6424, D(x): 0.72, D(G(z)): 0.34
# Epoch [258/300], Step [600/600], d_loss: 1.0702, g_loss: 1.5777, D(x): 0.61, D(G(z)): 0.34
# Saving fake_images-0259.png
# Epoch [259/300], Step [200/600], d_loss: 0.9713, g_loss: 1.4442, D(x): 0.62, D(G(z)): 0.23
# Epoch [259/300], Step [400/600], d_loss: 0.9748, g_loss: 1.5131, D(x): 0.65, D(G(z)): 0.29
# Epoch [259/300], Step [600/600], d_loss: 0.9185, g_loss: 1.6797, D(x): 0.67, D(G(z)): 0.27
# Saving fake_images-0260.png
# Epoch [260/300], Step [200/600], d_loss: 0.9330, g_loss: 1.3108, D(x): 0.63, D(G(z)): 0.27
# Epoch [260/300], Step [400/600], d_loss: 1.1381, g_loss: 1.2304, D(x): 0.73, D(G(z)): 0.42
# Epoch [260/300], Step [600/600], d_loss: 1.0471, g_loss: 1.4514, D(x): 0.72, D(G(z)): 0.39
# Saving fake_images-0261.png
# Epoch [261/300], Step [200/600], d_loss: 0.9400, g_loss: 1.1861, D(x): 0.72, D(G(z)): 0.32
# Epoch [261/300], Step [400/600], d_loss: 1.0027, g_loss: 1.4548, D(x): 0.73, D(G(z)): 0.37
# Epoch [261/300], Step [600/600], d_loss: 0.8486, g_loss: 1.4275, D(x): 0.76, D(G(z)): 0.33
# Saving fake_images-0262.png
# Epoch [262/300], Step [200/600], d_loss: 0.9907, g_loss: 1.4744, D(x): 0.66, D(G(z)): 0.31
# Epoch [262/300], Step [400/600], d_loss: 0.9149, g_loss: 1.5083, D(x): 0.70, D(G(z)): 0.31
# Epoch [262/300], Step [600/600], d_loss: 0.8659, g_loss: 1.1963, D(x): 0.73, D(G(z)): 0.33
# Saving fake_images-0263.png
# Epoch [263/300], Step [200/600], d_loss: 0.9648, g_loss: 1.6459, D(x): 0.69, D(G(z)): 0.32
# Epoch [263/300], Step [400/600], d_loss: 0.9260, g_loss: 1.3875, D(x): 0.68, D(G(z)): 0.30
# Epoch [263/300], Step [600/600], d_loss: 0.8476, g_loss: 1.4105, D(x): 0.72, D(G(z)): 0.29
# Saving fake_images-0264.png
# Epoch [264/300], Step [200/600], d_loss: 0.8245, g_loss: 1.5508, D(x): 0.74, D(G(z)): 0.30
# Epoch [264/300], Step [400/600], d_loss: 0.9103, g_loss: 1.2536, D(x): 0.72, D(G(z)): 0.34
# Epoch [264/300], Step [600/600], d_loss: 1.0067, g_loss: 1.3464, D(x): 0.64, D(G(z)): 0.31
# Saving fake_images-0265.png
# Epoch [265/300], Step [200/600], d_loss: 1.1110, g_loss: 1.9220, D(x): 0.58, D(G(z)): 0.25
# Epoch [265/300], Step [400/600], d_loss: 0.8176, g_loss: 1.5483, D(x): 0.70, D(G(z)): 0.27
# Epoch [265/300], Step [600/600], d_loss: 1.1425, g_loss: 1.4423, D(x): 0.58, D(G(z)): 0.30
# Saving fake_images-0266.png
# Epoch [266/300], Step [200/600], d_loss: 1.0187, g_loss: 1.3692, D(x): 0.69, D(G(z)): 0.37
# Epoch [266/300], Step [400/600], d_loss: 0.8865, g_loss: 1.4961, D(x): 0.72, D(G(z)): 0.31
# Epoch [266/300], Step [600/600], d_loss: 0.9213, g_loss: 1.4497, D(x): 0.76, D(G(z)): 0.39
# Saving fake_images-0267.png
# Epoch [267/300], Step [200/600], d_loss: 0.9367, g_loss: 1.3390, D(x): 0.72, D(G(z)): 0.32
# Epoch [267/300], Step [400/600], d_loss: 0.8612, g_loss: 1.7076, D(x): 0.67, D(G(z)): 0.26
# Epoch [267/300], Step [600/600], d_loss: 0.8879, g_loss: 1.6732, D(x): 0.77, D(G(z)): 0.34
# Saving fake_images-0268.png
# Epoch [268/300], Step [200/600], d_loss: 1.0516, g_loss: 1.6418, D(x): 0.75, D(G(z)): 0.41
# Epoch [268/300], Step [400/600], d_loss: 1.1046, g_loss: 1.3161, D(x): 0.58, D(G(z)): 0.27
# Epoch [268/300], Step [600/600], d_loss: 0.7634, g_loss: 1.5896, D(x): 0.77, D(G(z)): 0.31
# Saving fake_images-0269.png
# Epoch [269/300], Step [200/600], d_loss: 0.7805, g_loss: 1.4008, D(x): 0.80, D(G(z)): 0.34
# Epoch [269/300], Step [400/600], d_loss: 0.9350, g_loss: 1.5283, D(x): 0.68, D(G(z)): 0.27
# Epoch [269/300], Step [600/600], d_loss: 1.0383, g_loss: 1.5715, D(x): 0.72, D(G(z)): 0.39
# Saving fake_images-0270.png
# Epoch [270/300], Step [200/600], d_loss: 0.9913, g_loss: 1.7601, D(x): 0.68, D(G(z)): 0.32
# Epoch [270/300], Step [400/600], d_loss: 1.0610, g_loss: 1.4887, D(x): 0.61, D(G(z)): 0.31
# Epoch [270/300], Step [600/600], d_loss: 1.0282, g_loss: 1.6535, D(x): 0.68, D(G(z)): 0.35
# Saving fake_images-0271.png
# Epoch [271/300], Step [200/600], d_loss: 1.0284, g_loss: 1.7224, D(x): 0.70, D(G(z)): 0.37
# Epoch [271/300], Step [400/600], d_loss: 0.9162, g_loss: 1.8922, D(x): 0.69, D(G(z)): 0.31
# Epoch [271/300], Step [600/600], d_loss: 1.0401, g_loss: 1.4387, D(x): 0.73, D(G(z)): 0.40
# Saving fake_images-0272.png
# Epoch [272/300], Step [200/600], d_loss: 0.9629, g_loss: 1.1312, D(x): 0.74, D(G(z)): 0.36
# Epoch [272/300], Step [400/600], d_loss: 0.7902, g_loss: 1.4016, D(x): 0.71, D(G(z)): 0.27
# Epoch [272/300], Step [600/600], d_loss: 1.0288, g_loss: 1.2752, D(x): 0.75, D(G(z)): 0.39
# Saving fake_images-0273.png
# Epoch [273/300], Step [200/600], d_loss: 0.9177, g_loss: 1.7533, D(x): 0.69, D(G(z)): 0.29
# Epoch [273/300], Step [400/600], d_loss: 0.9909, g_loss: 1.5825, D(x): 0.69, D(G(z)): 0.33
# Epoch [273/300], Step [600/600], d_loss: 0.8341, g_loss: 1.3509, D(x): 0.72, D(G(z)): 0.30
# Saving fake_images-0274.png
# Epoch [274/300], Step [200/600], d_loss: 0.8965, g_loss: 1.3755, D(x): 0.74, D(G(z)): 0.35
# Epoch [274/300], Step [400/600], d_loss: 0.9889, g_loss: 1.5189, D(x): 0.63, D(G(z)): 0.30
# Epoch [274/300], Step [600/600], d_loss: 0.8567, g_loss: 1.7084, D(x): 0.71, D(G(z)): 0.28
# Saving fake_images-0275.png
# Epoch [275/300], Step [200/600], d_loss: 0.9179, g_loss: 1.2954, D(x): 0.74, D(G(z)): 0.35
# Epoch [275/300], Step [400/600], d_loss: 0.7670, g_loss: 1.3197, D(x): 0.78, D(G(z)): 0.32
# Epoch [275/300], Step [600/600], d_loss: 1.0267, g_loss: 1.4366, D(x): 0.64, D(G(z)): 0.30
# Saving fake_images-0276.png
# Epoch [276/300], Step [200/600], d_loss: 0.8656, g_loss: 1.4381, D(x): 0.68, D(G(z)): 0.27
# Epoch [276/300], Step [400/600], d_loss: 0.8253, g_loss: 1.2296, D(x): 0.68, D(G(z)): 0.26
# Epoch [276/300], Step [600/600], d_loss: 0.9815, g_loss: 1.5537, D(x): 0.65, D(G(z)): 0.29
# Saving fake_images-0277.png
# Epoch [277/300], Step [200/600], d_loss: 0.9434, g_loss: 1.4035, D(x): 0.64, D(G(z)): 0.26
# Epoch [277/300], Step [400/600], d_loss: 0.7058, g_loss: 1.3112, D(x): 0.76, D(G(z)): 0.26
# Epoch [277/300], Step [600/600], d_loss: 0.9374, g_loss: 1.1869, D(x): 0.69, D(G(z)): 0.30
# Saving fake_images-0278.png
# Epoch [278/300], Step [200/600], d_loss: 0.9946, g_loss: 1.4388, D(x): 0.74, D(G(z)): 0.39
# Epoch [278/300], Step [400/600], d_loss: 1.0818, g_loss: 2.0085, D(x): 0.61, D(G(z)): 0.29
# Epoch [278/300], Step [600/600], d_loss: 0.8694, g_loss: 1.6442, D(x): 0.70, D(G(z)): 0.29
# Saving fake_images-0279.png
# Epoch [279/300], Step [200/600], d_loss: 0.7929, g_loss: 1.2829, D(x): 0.70, D(G(z)): 0.26
# Epoch [279/300], Step [400/600], d_loss: 0.9081, g_loss: 1.4021, D(x): 0.68, D(G(z)): 0.30
# Epoch [279/300], Step [600/600], d_loss: 1.0152, g_loss: 1.3388, D(x): 0.68, D(G(z)): 0.34
# Saving fake_images-0280.png
# Epoch [280/300], Step [200/600], d_loss: 0.9896, g_loss: 1.7947, D(x): 0.69, D(G(z)): 0.32
# Epoch [280/300], Step [400/600], d_loss: 0.8410, g_loss: 1.4491, D(x): 0.68, D(G(z)): 0.26
# Epoch [280/300], Step [600/600], d_loss: 0.9981, g_loss: 1.5274, D(x): 0.61, D(G(z)): 0.24
# Saving fake_images-0281.png
# Epoch [281/300], Step [200/600], d_loss: 0.8858, g_loss: 1.3497, D(x): 0.66, D(G(z)): 0.24
# Epoch [281/300], Step [400/600], d_loss: 0.9272, g_loss: 1.2800, D(x): 0.69, D(G(z)): 0.31
# Epoch [281/300], Step [600/600], d_loss: 1.0414, g_loss: 1.2850, D(x): 0.77, D(G(z)): 0.42
# Saving fake_images-0282.png
# Epoch [282/300], Step [200/600], d_loss: 0.8101, g_loss: 1.9201, D(x): 0.69, D(G(z)): 0.24
# Epoch [282/300], Step [400/600], d_loss: 0.9239, g_loss: 1.8016, D(x): 0.73, D(G(z)): 0.35
# Epoch [282/300], Step [600/600], d_loss: 1.0568, g_loss: 1.7991, D(x): 0.61, D(G(z)): 0.24
# Saving fake_images-0283.png
# Epoch [283/300], Step [200/600], d_loss: 1.0699, g_loss: 1.1794, D(x): 0.68, D(G(z)): 0.36
# Epoch [283/300], Step [400/600], d_loss: 1.0122, g_loss: 1.3523, D(x): 0.69, D(G(z)): 0.34
# Epoch [283/300], Step [600/600], d_loss: 0.9943, g_loss: 1.7553, D(x): 0.73, D(G(z)): 0.33
# Saving fake_images-0284.png
# Epoch [284/300], Step [200/600], d_loss: 0.9782, g_loss: 1.7966, D(x): 0.67, D(G(z)): 0.28
# Epoch [284/300], Step [400/600], d_loss: 0.9851, g_loss: 1.5009, D(x): 0.62, D(G(z)): 0.26
# Epoch [284/300], Step [600/600], d_loss: 0.9579, g_loss: 1.5647, D(x): 0.66, D(G(z)): 0.30
# Saving fake_images-0285.png
# Epoch [285/300], Step [200/600], d_loss: 0.9719, g_loss: 1.5983, D(x): 0.65, D(G(z)): 0.28
# Epoch [285/300], Step [400/600], d_loss: 1.0849, g_loss: 1.4809, D(x): 0.59, D(G(z)): 0.28
# Epoch [285/300], Step [600/600], d_loss: 0.7554, g_loss: 1.7618, D(x): 0.77, D(G(z)): 0.30
# Saving fake_images-0286.png
# Epoch [286/300], Step [200/600], d_loss: 0.8833, g_loss: 1.5487, D(x): 0.70, D(G(z)): 0.28
# Epoch [286/300], Step [400/600], d_loss: 0.8981, g_loss: 1.3074, D(x): 0.74, D(G(z)): 0.35
# Epoch [286/300], Step [600/600], d_loss: 0.7942, g_loss: 1.6506, D(x): 0.73, D(G(z)): 0.28
# Saving fake_images-0287.png
# Epoch [287/300], Step [200/600], d_loss: 0.8755, g_loss: 1.5092, D(x): 0.68, D(G(z)): 0.28
# Epoch [287/300], Step [400/600], d_loss: 0.8025, g_loss: 1.6983, D(x): 0.72, D(G(z)): 0.27
# Epoch [287/300], Step [600/600], d_loss: 0.8783, g_loss: 1.7157, D(x): 0.65, D(G(z)): 0.20
# Saving fake_images-0288.png
# Epoch [288/300], Step [200/600], d_loss: 1.1885, g_loss: 1.3378, D(x): 0.67, D(G(z)): 0.38
# Epoch [288/300], Step [400/600], d_loss: 0.9470, g_loss: 1.7080, D(x): 0.66, D(G(z)): 0.28
# Epoch [288/300], Step [600/600], d_loss: 1.0297, g_loss: 1.5610, D(x): 0.67, D(G(z)): 0.33
# Saving fake_images-0289.png
# Epoch [289/300], Step [200/600], d_loss: 0.8128, g_loss: 1.4768, D(x): 0.68, D(G(z)): 0.23
# Epoch [289/300], Step [400/600], d_loss: 0.8402, g_loss: 1.4950, D(x): 0.72, D(G(z)): 0.31
# Epoch [289/300], Step [600/600], d_loss: 0.8814, g_loss: 1.4358, D(x): 0.73, D(G(z)): 0.33
# Saving fake_images-0290.png
# Epoch [290/300], Step [200/600], d_loss: 0.9556, g_loss: 1.7650, D(x): 0.66, D(G(z)): 0.31
# Epoch [290/300], Step [400/600], d_loss: 0.8818, g_loss: 1.6017, D(x): 0.70, D(G(z)): 0.30
# Epoch [290/300], Step [600/600], d_loss: 0.9987, g_loss: 1.4797, D(x): 0.64, D(G(z)): 0.30
# Saving fake_images-0291.png
# Epoch [291/300], Step [200/600], d_loss: 0.8540, g_loss: 1.3569, D(x): 0.73, D(G(z)): 0.32
# Epoch [291/300], Step [400/600], d_loss: 1.0484, g_loss: 1.6447, D(x): 0.67, D(G(z)): 0.36
# Epoch [291/300], Step [600/600], d_loss: 0.9022, g_loss: 1.2780, D(x): 0.76, D(G(z)): 0.35
# Saving fake_images-0292.png
# Epoch [292/300], Step [200/600], d_loss: 0.8348, g_loss: 1.4256, D(x): 0.71, D(G(z)): 0.28
# Epoch [292/300], Step [400/600], d_loss: 0.8949, g_loss: 1.4108, D(x): 0.78, D(G(z)): 0.37
# Epoch [292/300], Step [600/600], d_loss: 0.8761, g_loss: 1.7726, D(x): 0.70, D(G(z)): 0.28
# Saving fake_images-0293.png
# Epoch [293/300], Step [200/600], d_loss: 0.9257, g_loss: 1.4434, D(x): 0.68, D(G(z)): 0.30
# Epoch [293/300], Step [400/600], d_loss: 0.8868, g_loss: 1.9089, D(x): 0.63, D(G(z)): 0.21
# Epoch [293/300], Step [600/600], d_loss: 0.8137, g_loss: 1.6332, D(x): 0.70, D(G(z)): 0.24
# Saving fake_images-0294.png
# Epoch [294/300], Step [200/600], d_loss: 0.9011, g_loss: 1.2828, D(x): 0.69, D(G(z)): 0.29
# Epoch [294/300], Step [400/600], d_loss: 0.8645, g_loss: 1.5515, D(x): 0.73, D(G(z)): 0.31
# Epoch [294/300], Step [600/600], d_loss: 0.8290, g_loss: 1.5950, D(x): 0.69, D(G(z)): 0.24
# Saving fake_images-0295.png
# Epoch [295/300], Step [200/600], d_loss: 0.9609, g_loss: 1.4087, D(x): 0.71, D(G(z)): 0.37
# Epoch [295/300], Step [400/600], d_loss: 0.7038, g_loss: 1.7033, D(x): 0.75, D(G(z)): 0.23
# Epoch [295/300], Step [600/600], d_loss: 0.7625, g_loss: 1.6621, D(x): 0.71, D(G(z)): 0.25
# Saving fake_images-0296.png
# Epoch [296/300], Step [200/600], d_loss: 1.0197, g_loss: 1.4969, D(x): 0.78, D(G(z)): 0.44
# Epoch [296/300], Step [400/600], d_loss: 1.0212, g_loss: 1.6180, D(x): 0.68, D(G(z)): 0.30
# Epoch [296/300], Step [600/600], d_loss: 1.1033, g_loss: 1.7695, D(x): 0.61, D(G(z)): 0.29
# Saving fake_images-0297.png
# Epoch [297/300], Step [200/600], d_loss: 0.8708, g_loss: 1.6380, D(x): 0.69, D(G(z)): 0.28
# Epoch [297/300], Step [400/600], d_loss: 0.9366, g_loss: 1.3173, D(x): 0.65, D(G(z)): 0.26
# Epoch [297/300], Step [600/600], d_loss: 1.0253, g_loss: 1.6592, D(x): 0.67, D(G(z)): 0.30
# Saving fake_images-0298.png
# Epoch [298/300], Step [200/600], d_loss: 0.8536, g_loss: 1.6028, D(x): 0.66, D(G(z)): 0.25
# Epoch [298/300], Step [400/600], d_loss: 0.8255, g_loss: 1.7233, D(x): 0.72, D(G(z)): 0.27
# Epoch [298/300], Step [600/600], d_loss: 0.8419, g_loss: 1.0626, D(x): 0.78, D(G(z)): 0.34
# Saving fake_images-0299.png
# Epoch [299/300], Step [200/600], d_loss: 0.9980, g_loss: 1.4538, D(x): 0.62, D(G(z)): 0.25
# Epoch [299/300], Step [400/600], d_loss: 0.7702, g_loss: 1.9484, D(x): 0.71, D(G(z)): 0.24
# Epoch [299/300], Step [600/600], d_loss: 0.8682, g_loss: 1.5117, D(x): 0.73, D(G(z)): 0.32
# Saving fake_images-0300.png
# CPU times: user 52min 59s, sys: 26.9 s, total: 53min 26s
# Wall time: 53min 22s

# %% [markdown]
# Now that we have trained the models, we can save checkpoints.

# %%
# Save the model checkpoints 
torch.save(G.state_dict(), 'G.ckpt')
torch.save(D.state_dict(), 'D.ckpt')

# %% [markdown]
# Here's how the generated images look, after the 10th, 50th, 100th and 300th epochs of training.

# %%
Image('./samples/fake_images-0010.png')

# %%
Image('./samples/fake_images-0050.png')

# %%
Image('./samples/fake_images-0100.png')

# %%
Image('./samples/fake_images-0300.png')

# %% [markdown]
# We can visualize the training process by combining the sample images generated after each epoch into a video using OpenCV.

# %%
import cv2
import os
from IPython.display import FileLink

vid_fname = 'gans_training.avi'

files = [os.path.join(sample_dir, f) for f in os.listdir(sample_dir) if 'fake_images' in f]
files.sort()

out = cv2.VideoWriter(vid_fname,cv2.VideoWriter_fourcc(*'MP4V'), 8, (302,302))
[out.write(cv2.imread(fname)) for fname in files]
out.release()
FileLink('gans_training.avi')
# Out:
# /content/gans_training.avi

# %%
plt.plot(d_losses, '-')
plt.plot(g_losses, '-')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['Discriminator', 'Generator'])
plt.title('Losses');

# %%
plt.plot(real_scores, '-')
plt.plot(fake_scores, '-')
plt.xlabel('epoch')
plt.ylabel('score')
plt.legend(['Real Score', 'Fake score'])
plt.title('Scores');
