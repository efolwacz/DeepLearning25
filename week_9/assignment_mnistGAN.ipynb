# %% [markdown]
# # Asignemnt: MNIST GAN
# ## Load the Data
#
# We begin by downloading and importing the data as a PyTorch dataset using the `MNIST` helper class from `torchvision.datasets`.

# %%
import torch
import torchvision
from torchvision.transforms import ToTensor, Normalize, Compose
from torchvision.datasets import MNIST

mnist = MNIST(root='data',
              train=True,
              download=True,
              transform=Compose([ToTensor(), Normalize(mean=(0.5,), std=(0.5,))]))

# %% [markdown]
# Note that we are are transforming the pixel values from the range `[0, 1]` to the range `[-1, 1]`. Makes generation easier...

# %%
img, label = mnist[0]
print('Label: ', label)
print(img[:,10:15,10:15])
torch.min(img), torch.max(img)
# Out:
# Label:  5
# tensor([[[-0.9922,  0.2078,  0.9843, -0.2941, -1.0000],
#          [-1.0000,  0.0902,  0.9843,  0.4902, -0.9843],
#          [-1.0000, -0.9137,  0.4902,  0.9843, -0.4510],
#          [-1.0000, -1.0000, -0.7255,  0.8902,  0.7647],
#          [-1.0000, -1.0000, -1.0000, -0.3647,  0.8824]]])
# (tensor(-1.), tensor(1.))

# %% [markdown]
# As expected, the pixel values range from -1 to 1. Let's define a helper to denormalize and view the images. This function will also be useful for viewing the generated images.

# %%
def denorm(x):
    out = (x + 1) / 2
    return out.clamp(0, 1)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

img_norm = denorm(img)
plt.imshow(img_norm[0], cmap='gray')
print('Label:', label)
# Out:
# Label: 5

# %% [markdown]
# Finally, let's create a dataloader to load the images in batches.

# %%
from torch.utils.data import DataLoader

batch_size = 100
data_loader = DataLoader(mnist, batch_size, shuffle=True)

# %%
for img_batch, label_batch in data_loader:
    print('first batch')
    print(img_batch.shape)
    plt.imshow(img_batch[0][0], cmap='gray')
    print(label_batch)
    break
# Out:
# first batch
# torch.Size([100, 1, 28, 28])
# tensor([4, 5, 0, 3, 0, 7, 5, 2, 7, 2, 0, 7, 9, 5, 1, 2, 2, 3, 6, 6, 4, 8, 7, 2,
#         0, 3, 9, 6, 9, 5, 2, 8, 6, 9, 9, 5, 2, 6, 9, 7, 0, 2, 1, 1, 5, 1, 8, 9,
#         4, 6, 1, 0, 9, 7, 4, 5, 0, 2, 8, 2, 4, 6, 2, 8, 3, 0, 8, 1, 3, 0, 0, 1,
#         3, 0, 5, 0, 1, 0, 6, 7, 7, 0, 8, 1, 2, 0, 2, 7, 3, 3, 2, 0, 6, 1, 6, 5,
#         8, 6, 8, 8])

# %%
# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
device
# Out:
# device(type='cuda')

# %% [markdown]
# ## 1. Discriminator Network
#
# The discriminator takes an image as input, and tries to classify it as "real" or "generated". In this sense, it's like any other neural network. While we can use a CNN for the discriminator, we'll use a simple feedforward network with 3 linear layers to keep things since. We'll treat each 28x28 image as a vector of size 784.

# %%
image_size = 784
hidden_size = 256

# %%
import torch.nn as nn

D = nn.Sequential(
    nn.Linear(image_size, hidden_size),
    nn.ReLU(),
    nn.Linear(hidden_size, hidden_size),
    nn.ReLU(),
    nn.Linear(hidden_size, 1),
    nn.Sigmoid()
)

# %%
D.to(device);

# %% [markdown]
# ## 2. Build Generator Network
#
# The input to the generator is typically a vector or a matrix which is used as a seed for generating an image. Once again, to keep things simple, we'll use a feedfoward neural network with 3 layers, and the output will be a vector of size 784, which can be transformed to a 28x28 px image.

# %% [markdown]
# We use the TanH activation function for the output layer of the generator.
#
# <img src="https://nic.schraudolph.org/teach/NNcourse/figs/tanh.gif" width="420" >
#
# > "The ReLU activation (Nair & Hinton, 2010) is used in the generator with the exception of the output layer which uses the Tanh function. We observed that using a bounded activation allowed the model to learn more quickly to saturate and cover the color space of the training distribution. Within the discriminator we found the leaky rectified activation (Maas et al., 2013) (Xu et al., 2015) to work well, especially for higher resolution modeling." - [Source](https://stackoverflow.com/questions/41489907/generative-adversarial-networks-tanh)
#
#
# Note that since the outputs of the TanH activation lie in the range `[-1,1]`, we have applied the same transformation to the images in the training dataset. Let's generate an output vector using the generator and view it as an image by transforming and denormalizing the output.

# %%
latent_size = 64

# %%
G = nn.Sequential(
    nn.Linear(64, hidden_size),
    nn.ReLU(True),
    nn.Linear(hidden_size, hidden_size),
    nn.ReLU(True),
    nn.Linear(hidden_size, 784),
    nn.Tanh())

# %%
G.to(device);

# %% [markdown]
# ## 3. Train the Model
#
# * train the model
# * save samples of generated images after each epoch -> use the ``denorm()`` function

# %%
import torch.optim as optim

# %%
#setup training
criterion = nn.BCELoss()

# setup optimizer
optimizerD = optim.Adam(D.parameters(), lr=0.0002, betas=(0.5, 0.999))
optimizerG = optim.Adam(G.parameters(), lr=0.0004, betas=(0.5, 0.999))

fixed_noise = torch.randn(128, 64, device=device) # Corrected shape
real_label = 1
fake_label = 0

niter = 25
g_loss = []
d_loss = []

# %%
import torchvision.utils as vutils

# %%
for epoch in range(niter):
    for i, data in enumerate(data_loader, 0):
        ############################
        # (1) Update D network: maximize log(D(x)) + log(1 - D(G(z)))
        ###########################
        # train with real
        D.zero_grad()
        real_cpu = data[0].to(device)
        batch_size = real_cpu.size(0)
        # Flatten das Bild auf (batch_size, 784)
        real_cpu = real_cpu.view(batch_size, -1)
        label = torch.full((batch_size, 1), real_label, device=device, dtype=torch.float)

        output = D(real_cpu)
        errD_real = criterion(output, label)
        errD_real.backward()
        D_x = output.mean().item()

        # train with fake
        # KEINE extra Dimensionen! Nur (batch_size, nz)
        noise = torch.randn(batch_size, 64, device=device)
        fake = G(noise)
        label.fill_(fake_label)
        output = D(fake.detach())
        errD_fake = criterion(output, label)
        errD_fake.backward()
        D_G_z1 = output.mean().item()
        errD = errD_real + errD_fake
        optimizerD.step()

        ############################
        # (2) Update G network: maximize log(D(G(z)))
        ###########################
        G.zero_grad()
        label.fill_(real_label)  # fake labels are real for generator cost
        output = D(fake)
        errG = criterion(output, label)
        errG.backward()
        D_G_z2 = output.mean().item()
        optimizerG.step()

        print('[%d/%d][%d/%d] Loss_D: %.4f Loss_G: %.4f D(x): %.4f D(G(z)): %.4f / %.4f' % (
            epoch, niter, i, len(data_loader), errD.item(), errG.item(), D_x, D_G_z1, D_G_z2))

        #save the output
        if i % 100 == 0:
            print('saving the output')
            # Nur die ersten 64 Bilder anzeigen
            vutils.save_image(real_cpu.view(batch_size, 1, 28, 28)[:64], 'real_samples.png', normalize=True, nrow=8)
            # fixed_noise muss (N, nz) sein!
            fake = G(fixed_noise).view(-1, 1, 28, 28)
            vutils.save_image(fake.detach()[:64], 'fake_samples_epoch_%03d.png' % (epoch), normalize=True, nrow=8)

    # Check pointing for every epoch
    torch.save(G.state_dict(), 'netG_epoch_%d.pth' % (epoch))
    torch.save(D.state_dict(), 'netD_epoch_%d.pth' % (epoch))
# Out:
# Die letzten 5000 Zeilen der Streamingausgabe wurden abgeschnitten.
# [16/25][443/600] Loss_D: 0.9531 Loss_G: 1.7401 D(x): 0.7165 D(G(z)): 0.3214 / 0.2269
# [16/25][444/600] Loss_D: 0.9095 Loss_G: 1.6625 D(x): 0.7007 D(G(z)): 0.3071 / 0.2348
# [16/25][445/600] Loss_D: 0.8548 Loss_G: 1.4404 D(x): 0.6673 D(G(z)): 0.2460 / 0.2706
# [16/25][446/600] Loss_D: 0.7610 Loss_G: 1.7024 D(x): 0.7506 D(G(z)): 0.2886 / 0.2210
# [16/25][447/600] Loss_D: 0.8046 Loss_G: 1.7223 D(x): 0.7196 D(G(z)): 0.2878 / 0.2183
# [16/25][448/600] Loss_D: 0.8023 Loss_G: 1.6683 D(x): 0.7368 D(G(z)): 0.2849 / 0.2387
# [16/25][449/600] Loss_D: 0.7945 Loss_G: 1.4536 D(x): 0.7093 D(G(z)): 0.2716 / 0.2755
# [16/25][450/600] Loss_D: 0.8120 Loss_G: 1.7277 D(x): 0.7566 D(G(z)): 0.3066 / 0.2170
# [16/25][451/600] Loss_D: 0.8539 Loss_G: 1.5626 D(x): 0.6926 D(G(z)): 0.2836 / 0.2642
# [16/25][452/600] Loss_D: 0.8293 Loss_G: 1.5695 D(x): 0.7084 D(G(z)): 0.2889 / 0.2538
# [16/25][453/600] Loss_D: 0.7105 Loss_G: 1.9413 D(x): 0.7743 D(G(z)): 0.2828 / 0.1875
# [16/25][454/600] Loss_D: 0.8497 Loss_G: 1.6606 D(x): 0.7035 D(G(z)): 0.2796 / 0.2403
# [16/25][455/600] Loss_D: 1.0540 Loss_G: 1.8599 D(x): 0.6945 D(G(z)): 0.3072 / 0.2094
# [16/25][456/600] Loss_D: 1.0541 Loss_G: 1.0261 D(x): 0.5790 D(G(z)): 0.2494 / 0.4094
# [16/25][457/600] Loss_D: 0.8902 Loss_G: 1.8514 D(x): 0.8153 D(G(z)): 0.4204 / 0.1947
# [16/25][458/600] Loss_D: 0.8698 Loss_G: 1.7117 D(x): 0.6706 D(G(z)): 0.2606 / 0.2186
# [16/25][459/600] Loss_D: 0.9229 Loss_G: 1.2688 D(x): 0.6433 D(G(z)): 0.2488 / 0.3317
# [16/25][460/600] Loss_D: 0.7801 Loss_G: 2.0112 D(x): 0.8329 D(G(z)): 0.3745 / 0.1618
# [16/25][461/600] Loss_D: 0.9461 Loss_G: 1.5399 D(x): 0.6200 D(G(z)): 0.2239 / 0.2549
# [16/25][462/600] Loss_D: 0.8041 Loss_G: 1.5656 D(x): 0.7060 D(G(z)): 0.2803 / 0.2522
# [16/25][463/600] Loss_D: 0.8512 Loss_G: 1.7505 D(x): 0.7360 D(G(z)): 0.3233 / 0.2082
# [16/25][464/600] Loss_D: 0.7308 Loss_G: 1.7182 D(x): 0.7407 D(G(z)): 0.2590 / 0.2188
# [16/25][465/600] Loss_D: 0.7848 Loss_G: 1.5510 D(x): 0.7214 D(G(z)): 0.2563 / 0.2554
# [16/25][466/600] Loss_D: 0.7670 Loss_G: 2.0426 D(x): 0.7617 D(G(z)): 0.3038 / 0.1580
# [16/25][467/600] Loss_D: 0.8376 Loss_G: 1.2637 D(x): 0.6526 D(G(z)): 0.1971 / 0.3192
# [16/25][468/600] Loss_D: 0.9309 Loss_G: 1.6613 D(x): 0.7818 D(G(z)): 0.4025 / 0.2279
# [16/25][469/600] Loss_D: 0.7660 Loss_G: 1.7046 D(x): 0.6953 D(G(z)): 0.2355 / 0.2293
# [16/25][470/600] Loss_D: 0.7578 Loss_G: 1.5956 D(x): 0.7421 D(G(z)): 0.2922 / 0.2525
# [16/25][471/600] Loss_D: 0.9054 Loss_G: 1.6368 D(x): 0.7114 D(G(z)): 0.3205 / 0.2307
# [16/25][472/600] Loss_D: 0.9049 Loss_G: 1.5003 D(x): 0.6783 D(G(z)): 0.2794 / 0.2678
# [16/25][473/600] Loss_D: 0.8800 Loss_G: 2.0059 D(x): 0.7352 D(G(z)): 0.3439 / 0.1625
# [16/25][474/600] Loss_D: 1.0911 Loss_G: 1.2403 D(x): 0.5429 D(G(z)): 0.2046 / 0.3597
# [16/25][475/600] Loss_D: 0.8830 Loss_G: 2.2308 D(x): 0.8109 D(G(z)): 0.4117 / 0.1395
# [16/25][476/600] Loss_D: 0.8930 Loss_G: 1.6180 D(x): 0.6238 D(G(z)): 0.2060 / 0.2502
# [16/25][477/600] Loss_D: 0.7630 Loss_G: 1.4830 D(x): 0.7580 D(G(z)): 0.3003 / 0.2717
# [16/25][478/600] Loss_D: 0.7824 Loss_G: 1.6573 D(x): 0.7211 D(G(z)): 0.2681 / 0.2292
# [16/25][479/600] Loss_D: 0.8220 Loss_G: 1.7861 D(x): 0.7381 D(G(z)): 0.3162 / 0.2085
# [16/25][480/600] Loss_D: 0.8692 Loss_G: 1.2577 D(x): 0.6551 D(G(z)): 0.2531 / 0.3191
# [16/25][481/600] Loss_D: 0.9652 Loss_G: 1.7931 D(x): 0.7827 D(G(z)): 0.4101 / 0.2036
# [16/25][482/600] Loss_D: 0.8105 Loss_G: 1.5680 D(x): 0.6664 D(G(z)): 0.2341 / 0.2561
# [16/25][483/600] Loss_D: 0.8132 Loss_G: 1.4485 D(x): 0.7066 D(G(z)): 0.2844 / 0.2807
# [16/25][484/600] Loss_D: 0.8177 Loss_G: 1.6773 D(x): 0.7601 D(G(z)): 0.3191 / 0.2166
# [16/25][485/600] Loss_D: 0.7733 Loss_G: 1.8162 D(x): 0.7171 D(G(z)): 0.2536 / 0.1916
# [16/25][486/600] Loss_D: 0.8120 Loss_G: 1.5465 D(x): 0.6992 D(G(z)): 0.2595 / 0.2539
# [16/25][487/600] Loss_D: 0.6724 Loss_G: 1.7859 D(x): 0.7761 D(G(z)): 0.2741 / 0.2029
# [16/25][488/600] Loss_D: 0.8482 Loss_G: 1.5995 D(x): 0.6946 D(G(z)): 0.2424 / 0.2497
# [16/25][489/600] Loss_D: 0.8292 Loss_G: 1.9019 D(x): 0.7694 D(G(z)): 0.3280 / 0.1864
# [16/25][490/600] Loss_D: 0.9214 Loss_G: 1.3223 D(x): 0.6129 D(G(z)): 0.2142 / 0.3144
# [16/25][491/600] Loss_D: 0.7872 Loss_G: 1.6436 D(x): 0.7948 D(G(z)): 0.3505 / 0.2315
# [16/25][492/600] Loss_D: 0.8652 Loss_G: 1.7870 D(x): 0.6909 D(G(z)): 0.2806 / 0.2097
# [16/25][493/600] Loss_D: 0.7530 Loss_G: 1.5954 D(x): 0.7373 D(G(z)): 0.2739 / 0.2477
# [16/25][494/600] Loss_D: 0.9904 Loss_G: 1.8412 D(x): 0.6936 D(G(z)): 0.3362 / 0.1971
# [16/25][495/600] Loss_D: 0.9112 Loss_G: 1.4091 D(x): 0.6642 D(G(z)): 0.2615 / 0.2882
# [16/25][496/600] Loss_D: 0.9690 Loss_G: 1.4214 D(x): 0.6867 D(G(z)): 0.3167 / 0.2885
# [16/25][497/600] Loss_D: 0.9199 Loss_G: 1.7130 D(x): 0.7316 D(G(z)): 0.3372 / 0.2228
# [16/25][498/600] Loss_D: 0.8008 Loss_G: 1.7524 D(x): 0.7156 D(G(z)): 0.2640 / 0.2118
# [16/25][499/600] Loss_D: 0.7527 Loss_G: 1.6305 D(x): 0.7156 D(G(z)): 0.2393 / 0.2331
# [16/25][500/600] Loss_D: 0.8226 Loss_G: 1.2788 D(x): 0.6626 D(G(z)): 0.2461 / 0.3283
# saving the output
# [16/25][501/600] Loss_D: 0.9416 Loss_G: 1.7981 D(x): 0.7850 D(G(z)): 0.3797 / 0.2136
# [16/25][502/600] Loss_D: 0.8025 Loss_G: 1.6446 D(x): 0.6820 D(G(z)): 0.2379 / 0.2321
# [16/25][503/600] Loss_D: 0.8729 Loss_G: 1.3459 D(x): 0.6678 D(G(z)): 0.2656 / 0.3056
# [16/25][504/600] Loss_D: 0.9026 Loss_G: 1.3919 D(x): 0.7355 D(G(z)): 0.3632 / 0.2849
# [16/25][505/600] Loss_D: 0.7586 Loss_G: 1.7588 D(x): 0.7741 D(G(z)): 0.3252 / 0.2079
# [16/25][506/600] Loss_D: 0.9577 Loss_G: 1.4217 D(x): 0.6381 D(G(z)): 0.2714 / 0.2830
# [16/25][507/600] Loss_D: 0.7694 Loss_G: 1.4684 D(x): 0.7449 D(G(z)): 0.2900 / 0.2682
# [16/25][508/600] Loss_D: 0.7634 Loss_G: 1.6716 D(x): 0.7671 D(G(z)): 0.3066 / 0.2262
# [16/25][509/600] Loss_D: 0.9073 Loss_G: 1.6953 D(x): 0.6999 D(G(z)): 0.3046 / 0.2284
# [16/25][510/600] Loss_D: 0.7642 Loss_G: 1.6683 D(x): 0.7033 D(G(z)): 0.2296 / 0.2302
# [16/25][511/600] Loss_D: 0.8611 Loss_G: 1.6855 D(x): 0.7257 D(G(z)): 0.3089 / 0.2273
# [16/25][512/600] Loss_D: 0.8883 Loss_G: 1.4376 D(x): 0.6649 D(G(z)): 0.2669 / 0.2831
# [16/25][513/600] Loss_D: 0.9540 Loss_G: 1.3454 D(x): 0.6778 D(G(z)): 0.3243 / 0.3089
# [16/25][514/600] Loss_D: 0.9044 Loss_G: 1.4378 D(x): 0.7230 D(G(z)): 0.3375 / 0.2787
# [16/25][515/600] Loss_D: 0.7709 Loss_G: 1.8544 D(x): 0.7677 D(G(z)): 0.3087 / 0.1879
# [16/25][516/600] Loss_D: 0.8426 Loss_G: 1.4394 D(x): 0.6702 D(G(z)): 0.2462 / 0.2831
# [16/25][517/600] Loss_D: 0.9154 Loss_G: 1.6062 D(x): 0.7052 D(G(z)): 0.3010 / 0.2627
# [16/25][518/600] Loss_D: 0.7856 Loss_G: 1.8725 D(x): 0.7489 D(G(z)): 0.3003 / 0.1894
# [16/25][519/600] Loss_D: 0.8272 Loss_G: 1.4854 D(x): 0.6800 D(G(z)): 0.2451 / 0.2672
# [16/25][520/600] Loss_D: 0.8466 Loss_G: 1.6394 D(x): 0.7222 D(G(z)): 0.3056 / 0.2485
# [16/25][521/600] Loss_D: 0.6873 Loss_G: 2.2278 D(x): 0.7954 D(G(z)): 0.2834 / 0.1432
# [16/25][522/600] Loss_D: 0.9911 Loss_G: 1.4503 D(x): 0.6037 D(G(z)): 0.2285 / 0.3101
# [16/25][523/600] Loss_D: 0.9091 Loss_G: 1.6048 D(x): 0.7223 D(G(z)): 0.3506 / 0.2421
# [16/25][524/600] Loss_D: 0.9020 Loss_G: 1.4666 D(x): 0.6877 D(G(z)): 0.2911 / 0.2750
# [16/25][525/600] Loss_D: 0.9409 Loss_G: 1.6604 D(x): 0.7131 D(G(z)): 0.3526 / 0.2358
# [16/25][526/600] Loss_D: 0.8190 Loss_G: 1.5655 D(x): 0.6733 D(G(z)): 0.2357 / 0.2516
# [16/25][527/600] Loss_D: 0.8368 Loss_G: 2.1392 D(x): 0.7868 D(G(z)): 0.3521 / 0.1475
# [16/25][528/600] Loss_D: 0.8795 Loss_G: 1.2707 D(x): 0.6090 D(G(z)): 0.1785 / 0.3323
# [16/25][529/600] Loss_D: 0.9091 Loss_G: 1.4636 D(x): 0.7419 D(G(z)): 0.3730 / 0.2756
# [16/25][530/600] Loss_D: 0.8661 Loss_G: 2.0145 D(x): 0.7437 D(G(z)): 0.3287 / 0.1704
# [16/25][531/600] Loss_D: 0.9988 Loss_G: 1.4248 D(x): 0.6103 D(G(z)): 0.2453 / 0.2908
# [16/25][532/600] Loss_D: 0.8460 Loss_G: 1.4430 D(x): 0.7380 D(G(z)): 0.3192 / 0.2773
# [16/25][533/600] Loss_D: 0.7183 Loss_G: 1.7610 D(x): 0.7918 D(G(z)): 0.3198 / 0.2216
# [16/25][534/600] Loss_D: 0.8563 Loss_G: 1.6170 D(x): 0.6868 D(G(z)): 0.2647 / 0.2482
# [16/25][535/600] Loss_D: 0.7113 Loss_G: 1.6748 D(x): 0.7685 D(G(z)): 0.2942 / 0.2226
# [16/25][536/600] Loss_D: 0.9534 Loss_G: 1.7250 D(x): 0.6820 D(G(z)): 0.2932 / 0.2225
# [16/25][537/600] Loss_D: 0.7744 Loss_G: 1.6803 D(x): 0.7233 D(G(z)): 0.2672 / 0.2376
# [16/25][538/600] Loss_D: 0.9587 Loss_G: 1.5063 D(x): 0.6904 D(G(z)): 0.3069 / 0.2695
# [16/25][539/600] Loss_D: 0.8265 Loss_G: 1.8021 D(x): 0.7226 D(G(z)): 0.2892 / 0.2033
# [16/25][540/600] Loss_D: 0.8210 Loss_G: 1.3504 D(x): 0.6873 D(G(z)): 0.2622 / 0.3036
# [16/25][541/600] Loss_D: 0.9172 Loss_G: 1.6308 D(x): 0.7280 D(G(z)): 0.3499 / 0.2432
# [16/25][542/600] Loss_D: 0.7486 Loss_G: 1.7246 D(x): 0.7434 D(G(z)): 0.2757 / 0.2209
# [16/25][543/600] Loss_D: 0.8927 Loss_G: 1.4410 D(x): 0.6631 D(G(z)): 0.2635 / 0.2753
# [16/25][544/600] Loss_D: 0.9153 Loss_G: 2.0374 D(x): 0.7775 D(G(z)): 0.3563 / 0.1714
# [16/25][545/600] Loss_D: 0.8721 Loss_G: 1.3162 D(x): 0.6238 D(G(z)): 0.2011 / 0.3141
# [16/25][546/600] Loss_D: 0.8375 Loss_G: 1.4918 D(x): 0.7686 D(G(z)): 0.3578 / 0.2602
# [16/25][547/600] Loss_D: 0.6974 Loss_G: 1.6146 D(x): 0.7351 D(G(z)): 0.2567 / 0.2346
# [16/25][548/600] Loss_D: 0.8911 Loss_G: 1.7221 D(x): 0.7182 D(G(z)): 0.3292 / 0.2152
# [16/25][549/600] Loss_D: 0.8594 Loss_G: 1.6094 D(x): 0.6574 D(G(z)): 0.2435 / 0.2533
# [16/25][550/600] Loss_D: 0.8195 Loss_G: 1.7423 D(x): 0.7642 D(G(z)): 0.3137 / 0.2200
# [16/25][551/600] Loss_D: 0.8767 Loss_G: 1.4677 D(x): 0.6719 D(G(z)): 0.2452 / 0.2679
# [16/25][552/600] Loss_D: 0.8133 Loss_G: 2.0395 D(x): 0.7782 D(G(z)): 0.3207 / 0.1754
# [16/25][553/600] Loss_D: 0.7806 Loss_G: 1.5084 D(x): 0.7023 D(G(z)): 0.2364 / 0.2648
# [16/25][554/600] Loss_D: 0.8733 Loss_G: 1.3873 D(x): 0.7051 D(G(z)): 0.2996 / 0.2928
# [16/25][555/600] Loss_D: 0.8555 Loss_G: 1.7422 D(x): 0.7347 D(G(z)): 0.3348 / 0.2011
# [16/25][556/600] Loss_D: 0.8824 Loss_G: 1.3039 D(x): 0.6727 D(G(z)): 0.2648 / 0.3199
# [16/25][557/600] Loss_D: 1.0768 Loss_G: 1.9767 D(x): 0.7617 D(G(z)): 0.4097 / 0.1834
# [16/25][558/600] Loss_D: 0.8463 Loss_G: 1.6714 D(x): 0.6538 D(G(z)): 0.2209 / 0.2383
# [16/25][559/600] Loss_D: 0.8851 Loss_G: 1.2986 D(x): 0.6718 D(G(z)): 0.2660 / 0.3135
# [16/25][560/600] Loss_D: 0.8661 Loss_G: 1.6321 D(x): 0.7764 D(G(z)): 0.3737 / 0.2449
# [16/25][561/600] Loss_D: 0.8140 Loss_G: 1.6616 D(x): 0.7042 D(G(z)): 0.2689 / 0.2280
# [16/25][562/600] Loss_D: 0.9653 Loss_G: 1.5114 D(x): 0.6693 D(G(z)): 0.2971 / 0.2667
# [16/25][563/600] Loss_D: 0.7722 Loss_G: 1.8048 D(x): 0.7754 D(G(z)): 0.3061 / 0.2032
# [16/25][564/600] Loss_D: 0.8823 Loss_G: 1.3467 D(x): 0.6689 D(G(z)): 0.2602 / 0.3000
# [16/25][565/600] Loss_D: 0.8611 Loss_G: 1.3321 D(x): 0.7034 D(G(z)): 0.3031 / 0.3114
# [16/25][566/600] Loss_D: 0.9593 Loss_G: 1.9054 D(x): 0.7654 D(G(z)): 0.3792 / 0.1854
# [16/25][567/600] Loss_D: 0.8517 Loss_G: 1.6015 D(x): 0.6490 D(G(z)): 0.2164 / 0.2373
# [16/25][568/600] Loss_D: 0.7407 Loss_G: 1.3297 D(x): 0.7269 D(G(z)): 0.2526 / 0.2988
# [16/25][569/600] Loss_D: 0.8543 Loss_G: 1.4476 D(x): 0.7381 D(G(z)): 0.3385 / 0.2717
# [16/25][570/600] Loss_D: 0.7715 Loss_G: 1.7346 D(x): 0.7672 D(G(z)): 0.3252 / 0.2096
# [16/25][571/600] Loss_D: 0.9087 Loss_G: 1.7804 D(x): 0.6898 D(G(z)): 0.2790 / 0.2092
# [16/25][572/600] Loss_D: 0.9620 Loss_G: 1.4946 D(x): 0.6300 D(G(z)): 0.2464 / 0.2660
# [16/25][573/600] Loss_D: 0.7835 Loss_G: 1.3784 D(x): 0.7167 D(G(z)): 0.2715 / 0.2900
# [16/25][574/600] Loss_D: 0.7913 Loss_G: 1.6364 D(x): 0.7570 D(G(z)): 0.3140 / 0.2303
# [16/25][575/600] Loss_D: 0.8556 Loss_G: 1.5092 D(x): 0.7034 D(G(z)): 0.2867 / 0.2558
# [16/25][576/600] Loss_D: 0.7993 Loss_G: 1.5851 D(x): 0.7524 D(G(z)): 0.3130 / 0.2399
# [16/25][577/600] Loss_D: 0.9073 Loss_G: 1.2769 D(x): 0.6560 D(G(z)): 0.2666 / 0.3202
# [16/25][578/600] Loss_D: 0.8031 Loss_G: 1.9551 D(x): 0.8159 D(G(z)): 0.3639 / 0.1776
# [16/25][579/600] Loss_D: 0.8351 Loss_G: 1.7453 D(x): 0.6787 D(G(z)): 0.2261 / 0.2158
# [16/25][580/600] Loss_D: 0.9047 Loss_G: 1.4442 D(x): 0.6908 D(G(z)): 0.2864 / 0.2764
# [16/25][581/600] Loss_D: 0.8720 Loss_G: 1.5139 D(x): 0.7101 D(G(z)): 0.3224 / 0.2647
# [16/25][582/600] Loss_D: 0.8857 Loss_G: 1.4287 D(x): 0.6674 D(G(z)): 0.2670 / 0.2787
# [16/25][583/600] Loss_D: 0.8982 Loss_G: 1.8319 D(x): 0.7487 D(G(z)): 0.3660 / 0.2000
# [16/25][584/600] Loss_D: 1.0002 Loss_G: 1.3042 D(x): 0.6092 D(G(z)): 0.2588 / 0.3192
# [16/25][585/600] Loss_D: 0.8634 Loss_G: 1.3164 D(x): 0.7015 D(G(z)): 0.3092 / 0.3146
# [16/25][586/600] Loss_D: 0.8997 Loss_G: 2.3469 D(x): 0.8164 D(G(z)): 0.4078 / 0.1176
# [16/25][587/600] Loss_D: 0.9379 Loss_G: 1.5204 D(x): 0.5764 D(G(z)): 0.1380 / 0.2573
# [16/25][588/600] Loss_D: 0.8439 Loss_G: 1.3411 D(x): 0.7260 D(G(z)): 0.3073 / 0.3042
# [16/25][589/600] Loss_D: 0.8620 Loss_G: 1.8002 D(x): 0.7638 D(G(z)): 0.3369 / 0.2105
# [16/25][590/600] Loss_D: 0.8666 Loss_G: 1.4885 D(x): 0.6729 D(G(z)): 0.2463 / 0.2631
# [16/25][591/600] Loss_D: 0.8161 Loss_G: 1.4809 D(x): 0.7206 D(G(z)): 0.2929 / 0.2581
# [16/25][592/600] Loss_D: 0.8859 Loss_G: 1.7010 D(x): 0.7164 D(G(z)): 0.3297 / 0.2187
# [16/25][593/600] Loss_D: 0.8655 Loss_G: 1.6894 D(x): 0.6876 D(G(z)): 0.2808 / 0.2287
# [16/25][594/600] Loss_D: 0.7978 Loss_G: 1.6803 D(x): 0.7413 D(G(z)): 0.2959 / 0.2258
# [16/25][595/600] Loss_D: 0.8509 Loss_G: 1.3642 D(x): 0.6748 D(G(z)): 0.2411 / 0.3068
# [16/25][596/600] Loss_D: 0.8459 Loss_G: 1.6872 D(x): 0.7568 D(G(z)): 0.3483 / 0.2211
# [16/25][597/600] Loss_D: 0.8013 Loss_G: 1.6946 D(x): 0.7124 D(G(z)): 0.2555 / 0.2194
# [16/25][598/600] Loss_D: 0.8025 Loss_G: 1.5841 D(x): 0.7086 D(G(z)): 0.2657 / 0.2563
# [16/25][599/600] Loss_D: 0.7508 Loss_G: 1.8792 D(x): 0.7544 D(G(z)): 0.2900 / 0.1917
# [17/25][0/600] Loss_D: 0.8955 Loss_G: 1.7726 D(x): 0.6805 D(G(z)): 0.2699 / 0.2218
# saving the output
# [17/25][1/600] Loss_D: 0.9985 Loss_G: 1.4021 D(x): 0.6370 D(G(z)): 0.2893 / 0.3011
# [17/25][2/600] Loss_D: 0.9237 Loss_G: 1.5711 D(x): 0.7509 D(G(z)): 0.3781 / 0.2490
# [17/25][3/600] Loss_D: 0.8382 Loss_G: 1.7247 D(x): 0.7150 D(G(z)): 0.2958 / 0.2204
# [17/25][4/600] Loss_D: 0.8860 Loss_G: 1.4241 D(x): 0.6252 D(G(z)): 0.2236 / 0.3027
# [17/25][5/600] Loss_D: 0.9205 Loss_G: 1.2936 D(x): 0.7044 D(G(z)): 0.3528 / 0.3168
# [17/25][6/600] Loss_D: 0.9568 Loss_G: 1.5389 D(x): 0.7163 D(G(z)): 0.3754 / 0.2514
# [17/25][7/600] Loss_D: 0.9102 Loss_G: 1.4636 D(x): 0.6673 D(G(z)): 0.2929 / 0.2761
# [17/25][8/600] Loss_D: 0.8576 Loss_G: 1.3053 D(x): 0.6905 D(G(z)): 0.2959 / 0.3125
# [17/25][9/600] Loss_D: 0.8600 Loss_G: 1.8123 D(x): 0.7603 D(G(z)): 0.3515 / 0.2004
# [17/25][10/600] Loss_D: 0.8623 Loss_G: 1.4033 D(x): 0.6506 D(G(z)): 0.2433 / 0.2790
# [17/25][11/600] Loss_D: 0.8299 Loss_G: 1.6043 D(x): 0.7623 D(G(z)): 0.3265 / 0.2513
# [17/25][12/600] Loss_D: 0.8725 Loss_G: 1.5328 D(x): 0.7066 D(G(z)): 0.3033 / 0.2496
# [17/25][13/600] Loss_D: 0.9606 Loss_G: 1.4478 D(x): 0.6657 D(G(z)): 0.3068 / 0.2819
# [17/25][14/600] Loss_D: 0.8610 Loss_G: 1.6271 D(x): 0.7230 D(G(z)): 0.3088 / 0.2372
# [17/25][15/600] Loss_D: 0.8366 Loss_G: 1.6181 D(x): 0.6892 D(G(z)): 0.2654 / 0.2383
# [17/25][16/600] Loss_D: 0.7934 Loss_G: 1.9096 D(x): 0.7503 D(G(z)): 0.3034 / 0.1808
# [17/25][17/600] Loss_D: 0.7836 Loss_G: 1.6342 D(x): 0.6943 D(G(z)): 0.2350 / 0.2334
# [17/25][18/600] Loss_D: 0.8086 Loss_G: 1.5127 D(x): 0.7262 D(G(z)): 0.2992 / 0.2631
# [17/25][19/600] Loss_D: 0.7637 Loss_G: 1.6833 D(x): 0.7514 D(G(z)): 0.2919 / 0.2286
# [17/25][20/600] Loss_D: 0.7241 Loss_G: 1.9380 D(x): 0.7550 D(G(z)): 0.2752 / 0.1745
# [17/25][21/600] Loss_D: 0.9039 Loss_G: 1.3505 D(x): 0.6576 D(G(z)): 0.2488 / 0.3049
# [17/25][22/600] Loss_D: 0.8282 Loss_G: 1.7008 D(x): 0.7497 D(G(z)): 0.3227 / 0.2225
# [17/25][23/600] Loss_D: 0.8978 Loss_G: 1.8595 D(x): 0.7092 D(G(z)): 0.3105 / 0.1959
# [17/25][24/600] Loss_D: 0.7701 Loss_G: 1.7340 D(x): 0.7073 D(G(z)): 0.2159 / 0.2408
# [17/25][25/600] Loss_D: 0.7952 Loss_G: 1.3508 D(x): 0.7239 D(G(z)): 0.2901 / 0.2928
# [17/25][26/600] Loss_D: 0.9909 Loss_G: 1.8410 D(x): 0.7252 D(G(z)): 0.3761 / 0.1970
# [17/25][27/600] Loss_D: 0.8957 Loss_G: 1.4161 D(x): 0.6394 D(G(z)): 0.2390 / 0.2813
# [17/25][28/600] Loss_D: 0.8639 Loss_G: 1.6918 D(x): 0.7536 D(G(z)): 0.3537 / 0.2248
# [17/25][29/600] Loss_D: 0.7751 Loss_G: 1.5693 D(x): 0.6974 D(G(z)): 0.2421 / 0.2391
# [17/25][30/600] Loss_D: 0.8203 Loss_G: 1.6709 D(x): 0.7372 D(G(z)): 0.2994 / 0.2249
# [17/25][31/600] Loss_D: 0.7711 Loss_G: 1.5464 D(x): 0.7086 D(G(z)): 0.2407 / 0.2537
# [17/25][32/600] Loss_D: 0.9007 Loss_G: 1.9057 D(x): 0.7399 D(G(z)): 0.3538 / 0.1879
# [17/25][33/600] Loss_D: 0.9257 Loss_G: 1.4753 D(x): 0.6330 D(G(z)): 0.2298 / 0.2740
# [17/25][34/600] Loss_D: 0.8498 Loss_G: 1.7736 D(x): 0.7693 D(G(z)): 0.3280 / 0.2181
# [17/25][35/600] Loss_D: 0.8816 Loss_G: 1.8140 D(x): 0.6774 D(G(z)): 0.2658 / 0.2073
# [17/25][36/600] Loss_D: 0.8664 Loss_G: 1.2324 D(x): 0.6709 D(G(z)): 0.2388 / 0.3392
# [17/25][37/600] Loss_D: 0.9822 Loss_G: 1.9811 D(x): 0.7909 D(G(z)): 0.4102 / 0.1739
# [17/25][38/600] Loss_D: 0.9853 Loss_G: 1.1634 D(x): 0.5653 D(G(z)): 0.1854 / 0.3563
# [17/25][39/600] Loss_D: 0.8712 Loss_G: 1.2703 D(x): 0.7361 D(G(z)): 0.3502 / 0.3142
# [17/25][40/600] Loss_D: 0.9431 Loss_G: 2.1411 D(x): 0.8065 D(G(z)): 0.4139 / 0.1468
# [17/25][41/600] Loss_D: 0.9800 Loss_G: 1.1383 D(x): 0.5558 D(G(z)): 0.1759 / 0.3631
# [17/25][42/600] Loss_D: 0.8037 Loss_G: 1.4045 D(x): 0.7965 D(G(z)): 0.3740 / 0.2820
# [17/25][43/600] Loss_D: 0.8701 Loss_G: 1.7240 D(x): 0.7201 D(G(z)): 0.3313 / 0.2062
# [17/25][44/600] Loss_D: 0.8133 Loss_G: 1.5329 D(x): 0.6720 D(G(z)): 0.2343 / 0.2543
# [17/25][45/600] Loss_D: 0.9258 Loss_G: 1.5545 D(x): 0.7172 D(G(z)): 0.3514 / 0.2561
# [17/25][46/600] Loss_D: 0.8919 Loss_G: 1.5078 D(x): 0.7027 D(G(z)): 0.3165 / 0.2702
# [17/25][47/600] Loss_D: 0.9773 Loss_G: 1.1468 D(x): 0.6052 D(G(z)): 0.2644 / 0.3626
# [17/25][48/600] Loss_D: 0.8721 Loss_G: 1.7584 D(x): 0.8165 D(G(z)): 0.3991 / 0.2166
# [17/25][49/600] Loss_D: 0.7337 Loss_G: 1.7269 D(x): 0.7167 D(G(z)): 0.2416 / 0.2031
# [17/25][50/600] Loss_D: 0.9293 Loss_G: 1.3568 D(x): 0.6336 D(G(z)): 0.2484 / 0.3059
# [17/25][51/600] Loss_D: 0.8870 Loss_G: 1.5039 D(x): 0.7512 D(G(z)): 0.3588 / 0.2600
# [17/25][52/600] Loss_D: 0.8557 Loss_G: 1.9999 D(x): 0.7476 D(G(z)): 0.3096 / 0.1680
# [17/25][53/600] Loss_D: 0.8948 Loss_G: 1.3655 D(x): 0.6219 D(G(z)): 0.2092 / 0.2951
# [17/25][54/600] Loss_D: 0.9001 Loss_G: 1.5167 D(x): 0.7296 D(G(z)): 0.3302 / 0.2637
# [17/25][55/600] Loss_D: 0.7412 Loss_G: 2.0307 D(x): 0.7998 D(G(z)): 0.3250 / 0.1639
# [17/25][56/600] Loss_D: 0.9167 Loss_G: 1.3205 D(x): 0.5976 D(G(z)): 0.1877 / 0.3132
# [17/25][57/600] Loss_D: 0.8125 Loss_G: 1.6028 D(x): 0.7661 D(G(z)): 0.3370 / 0.2431
# [17/25][58/600] Loss_D: 0.7916 Loss_G: 1.9471 D(x): 0.7515 D(G(z)): 0.3103 / 0.1754
# [17/25][59/600] Loss_D: 0.9574 Loss_G: 1.2285 D(x): 0.6124 D(G(z)): 0.2299 / 0.3398
# [17/25][60/600] Loss_D: 0.7816 Loss_G: 1.6903 D(x): 0.7956 D(G(z)): 0.3297 / 0.2251
# [17/25][61/600] Loss_D: 0.9132 Loss_G: 2.0520 D(x): 0.7217 D(G(z)): 0.3217 / 0.1661
# [17/25][62/600] Loss_D: 0.8891 Loss_G: 1.4213 D(x): 0.6375 D(G(z)): 0.2073 / 0.2988
# [17/25][63/600] Loss_D: 0.9564 Loss_G: 1.4892 D(x): 0.7127 D(G(z)): 0.3479 / 0.2619
# [17/25][64/600] Loss_D: 0.7738 Loss_G: 1.7768 D(x): 0.7566 D(G(z)): 0.3005 / 0.2131
# [17/25][65/600] Loss_D: 0.8787 Loss_G: 1.4105 D(x): 0.6425 D(G(z)): 0.2186 / 0.2877
# [17/25][66/600] Loss_D: 0.8429 Loss_G: 1.7812 D(x): 0.7957 D(G(z)): 0.3829 / 0.1990
# [17/25][67/600] Loss_D: 0.9279 Loss_G: 1.5500 D(x): 0.6387 D(G(z)): 0.2391 / 0.2586
# [17/25][68/600] Loss_D: 0.8672 Loss_G: 1.4130 D(x): 0.7098 D(G(z)): 0.3052 / 0.2962
# [17/25][69/600] Loss_D: 0.8781 Loss_G: 1.6501 D(x): 0.7338 D(G(z)): 0.3384 / 0.2312
# [17/25][70/600] Loss_D: 0.8093 Loss_G: 1.5861 D(x): 0.6898 D(G(z)): 0.2540 / 0.2516
# [17/25][71/600] Loss_D: 0.8819 Loss_G: 1.5454 D(x): 0.7165 D(G(z)): 0.3236 / 0.2578
# [17/25][72/600] Loss_D: 0.7156 Loss_G: 1.6330 D(x): 0.7487 D(G(z)): 0.2736 / 0.2204
# [17/25][73/600] Loss_D: 0.9251 Loss_G: 1.4759 D(x): 0.6693 D(G(z)): 0.2868 / 0.2594
# [17/25][74/600] Loss_D: 0.8732 Loss_G: 1.5878 D(x): 0.7063 D(G(z)): 0.2887 / 0.2492
# [17/25][75/600] Loss_D: 0.8660 Loss_G: 1.4837 D(x): 0.7086 D(G(z)): 0.2923 / 0.2700
# [17/25][76/600] Loss_D: 0.8559 Loss_G: 1.8187 D(x): 0.7401 D(G(z)): 0.3045 / 0.2170
# [17/25][77/600] Loss_D: 0.8912 Loss_G: 1.3284 D(x): 0.6521 D(G(z)): 0.2580 / 0.3085
# [17/25][78/600] Loss_D: 0.8063 Loss_G: 1.7727 D(x): 0.7543 D(G(z)): 0.3175 / 0.1988
# [17/25][79/600] Loss_D: 0.9182 Loss_G: 1.5706 D(x): 0.6587 D(G(z)): 0.2565 / 0.2573
# [17/25][80/600] Loss_D: 0.8492 Loss_G: 1.4235 D(x): 0.7151 D(G(z)): 0.3134 / 0.2860
# [17/25][81/600] Loss_D: 0.8158 Loss_G: 1.6466 D(x): 0.7544 D(G(z)): 0.3274 / 0.2299
# [17/25][82/600] Loss_D: 0.9190 Loss_G: 1.3835 D(x): 0.6621 D(G(z)): 0.2555 / 0.2845
# [17/25][83/600] Loss_D: 0.7967 Loss_G: 1.6576 D(x): 0.7597 D(G(z)): 0.3261 / 0.2356
# [17/25][84/600] Loss_D: 0.8600 Loss_G: 1.6613 D(x): 0.7019 D(G(z)): 0.2793 / 0.2339
# [17/25][85/600] Loss_D: 0.9919 Loss_G: 1.6062 D(x): 0.6654 D(G(z)): 0.3090 / 0.2411
# [17/25][86/600] Loss_D: 0.8681 Loss_G: 1.2853 D(x): 0.6431 D(G(z)): 0.2372 / 0.3284
# [17/25][87/600] Loss_D: 0.9215 Loss_G: 1.4991 D(x): 0.7404 D(G(z)): 0.3808 / 0.2637
# [17/25][88/600] Loss_D: 0.9162 Loss_G: 1.7079 D(x): 0.7263 D(G(z)): 0.3405 / 0.2205
# [17/25][89/600] Loss_D: 0.8499 Loss_G: 1.4332 D(x): 0.6562 D(G(z)): 0.2450 / 0.2865
# [17/25][90/600] Loss_D: 0.9291 Loss_G: 1.4587 D(x): 0.7329 D(G(z)): 0.3697 / 0.2749
# [17/25][91/600] Loss_D: 0.8285 Loss_G: 1.8665 D(x): 0.7209 D(G(z)): 0.2871 / 0.1983
# [17/25][92/600] Loss_D: 0.9567 Loss_G: 1.2412 D(x): 0.6157 D(G(z)): 0.2431 / 0.3362
# [17/25][93/600] Loss_D: 0.8582 Loss_G: 1.7257 D(x): 0.7925 D(G(z)): 0.3661 / 0.2307
# [17/25][94/600] Loss_D: 0.7429 Loss_G: 1.7432 D(x): 0.7134 D(G(z)): 0.2481 / 0.2079
# [17/25][95/600] Loss_D: 0.8334 Loss_G: 1.5624 D(x): 0.6925 D(G(z)): 0.2726 / 0.2535
# [17/25][96/600] Loss_D: 0.9395 Loss_G: 1.6075 D(x): 0.7003 D(G(z)): 0.3152 / 0.2482
# [17/25][97/600] Loss_D: 0.8872 Loss_G: 1.6320 D(x): 0.7002 D(G(z)): 0.2994 / 0.2384
# [17/25][98/600] Loss_D: 1.0604 Loss_G: 1.3606 D(x): 0.6112 D(G(z)): 0.2780 / 0.3018
# [17/25][99/600] Loss_D: 0.9451 Loss_G: 1.5833 D(x): 0.7308 D(G(z)): 0.3498 / 0.2470
# [17/25][100/600] Loss_D: 0.9195 Loss_G: 1.4898 D(x): 0.6839 D(G(z)): 0.2916 / 0.2643
# saving the output
# [17/25][101/600] Loss_D: 0.9363 Loss_G: 1.2912 D(x): 0.6645 D(G(z)): 0.2964 / 0.3190
# [17/25][102/600] Loss_D: 0.8816 Loss_G: 1.5871 D(x): 0.7156 D(G(z)): 0.3218 / 0.2465
# [17/25][103/600] Loss_D: 0.8830 Loss_G: 1.4945 D(x): 0.6964 D(G(z)): 0.3153 / 0.2608
# [17/25][104/600] Loss_D: 0.8506 Loss_G: 1.4619 D(x): 0.6941 D(G(z)): 0.2858 / 0.2799
# [17/25][105/600] Loss_D: 0.9811 Loss_G: 1.3685 D(x): 0.6856 D(G(z)): 0.3581 / 0.3051
# [17/25][106/600] Loss_D: 0.7917 Loss_G: 1.8536 D(x): 0.7484 D(G(z)): 0.3013 / 0.1936
# [17/25][107/600] Loss_D: 0.8767 Loss_G: 1.6971 D(x): 0.6762 D(G(z)): 0.2606 / 0.2249
# [17/25][108/600] Loss_D: 0.7741 Loss_G: 1.3683 D(x): 0.6998 D(G(z)): 0.2304 / 0.3055
# [17/25][109/600] Loss_D: 0.8362 Loss_G: 1.6489 D(x): 0.7813 D(G(z)): 0.3602 / 0.2291
# [17/25][110/600] Loss_D: 0.8535 Loss_G: 1.8456 D(x): 0.6995 D(G(z)): 0.2660 / 0.2002
# [17/25][111/600] Loss_D: 0.9637 Loss_G: 1.3190 D(x): 0.6160 D(G(z)): 0.2408 / 0.3131
# [17/25][112/600] Loss_D: 0.9045 Loss_G: 1.5492 D(x): 0.7581 D(G(z)): 0.3688 / 0.2534
# [17/25][113/600] Loss_D: 0.8475 Loss_G: 1.4014 D(x): 0.6776 D(G(z)): 0.2741 / 0.2862
# [17/25][114/600] Loss_D: 0.8733 Loss_G: 1.7480 D(x): 0.7308 D(G(z)): 0.3266 / 0.2244
# [17/25][115/600] Loss_D: 0.8925 Loss_G: 1.2993 D(x): 0.6736 D(G(z)): 0.2837 / 0.3051
# [17/25][116/600] Loss_D: 0.8681 Loss_G: 1.6765 D(x): 0.7376 D(G(z)): 0.3164 / 0.2415
# [17/25][117/600] Loss_D: 0.8556 Loss_G: 1.4429 D(x): 0.6922 D(G(z)): 0.2832 / 0.2741
# [17/25][118/600] Loss_D: 0.8535 Loss_G: 1.5878 D(x): 0.7161 D(G(z)): 0.3040 / 0.2473
# [17/25][119/600] Loss_D: 0.8748 Loss_G: 1.7251 D(x): 0.7185 D(G(z)): 0.2988 / 0.2149
# [17/25][120/600] Loss_D: 0.8498 Loss_G: 1.4959 D(x): 0.6687 D(G(z)): 0.2505 / 0.2648
# [17/25][121/600] Loss_D: 0.8171 Loss_G: 1.3479 D(x): 0.7071 D(G(z)): 0.2722 / 0.3019
# [17/25][122/600] Loss_D: 0.9156 Loss_G: 2.1381 D(x): 0.7939 D(G(z)): 0.3938 / 0.1634
# [17/25][123/600] Loss_D: 0.8518 Loss_G: 1.3107 D(x): 0.6212 D(G(z)): 0.1910 / 0.3172
# [17/25][124/600] Loss_D: 0.8880 Loss_G: 1.8907 D(x): 0.7947 D(G(z)): 0.3727 / 0.1953
# [17/25][125/600] Loss_D: 0.8961 Loss_G: 1.4352 D(x): 0.6598 D(G(z)): 0.2361 / 0.2769
# [17/25][126/600] Loss_D: 0.7992 Loss_G: 1.4734 D(x): 0.7417 D(G(z)): 0.3045 / 0.2697
# [17/25][127/600] Loss_D: 0.8025 Loss_G: 1.8694 D(x): 0.7802 D(G(z)): 0.3329 / 0.1918
# [17/25][128/600] Loss_D: 0.9752 Loss_G: 1.2477 D(x): 0.6022 D(G(z)): 0.2229 / 0.3316
# [17/25][129/600] Loss_D: 0.7941 Loss_G: 1.5893 D(x): 0.7806 D(G(z)): 0.3372 / 0.2491
# [17/25][130/600] Loss_D: 0.7314 Loss_G: 1.7414 D(x): 0.7536 D(G(z)): 0.2737 / 0.2041
# [17/25][131/600] Loss_D: 0.9981 Loss_G: 1.7886 D(x): 0.6694 D(G(z)): 0.2992 / 0.2126
# [17/25][132/600] Loss_D: 0.8426 Loss_G: 1.3493 D(x): 0.6452 D(G(z)): 0.2234 / 0.2987
# [17/25][133/600] Loss_D: 1.0293 Loss_G: 1.2993 D(x): 0.6951 D(G(z)): 0.3748 / 0.3186
# [17/25][134/600] Loss_D: 0.9877 Loss_G: 1.6017 D(x): 0.6948 D(G(z)): 0.3460 / 0.2467
# [17/25][135/600] Loss_D: 0.8382 Loss_G: 1.6199 D(x): 0.6879 D(G(z)): 0.2663 / 0.2534
# [17/25][136/600] Loss_D: 0.9005 Loss_G: 1.7431 D(x): 0.7365 D(G(z)): 0.3365 / 0.2237
# [17/25][137/600] Loss_D: 0.7727 Loss_G: 1.7568 D(x): 0.7158 D(G(z)): 0.2543 / 0.2276
# [17/25][138/600] Loss_D: 0.8984 Loss_G: 1.2627 D(x): 0.6576 D(G(z)): 0.2608 / 0.3240
# [17/25][139/600] Loss_D: 0.7724 Loss_G: 1.7090 D(x): 0.7929 D(G(z)): 0.3483 / 0.2114
# [17/25][140/600] Loss_D: 0.8102 Loss_G: 1.8428 D(x): 0.7189 D(G(z)): 0.2755 / 0.2097
# [17/25][141/600] Loss_D: 0.9437 Loss_G: 1.4508 D(x): 0.6447 D(G(z)): 0.2581 / 0.2843
# [17/25][142/600] Loss_D: 0.7682 Loss_G: 1.4825 D(x): 0.7279 D(G(z)): 0.2834 / 0.2647
# [17/25][143/600] Loss_D: 0.8453 Loss_G: 1.8264 D(x): 0.7520 D(G(z)): 0.3257 / 0.1889
# [17/25][144/600] Loss_D: 0.8521 Loss_G: 1.5068 D(x): 0.6673 D(G(z)): 0.2379 / 0.2637
# [17/25][145/600] Loss_D: 0.8765 Loss_G: 1.9073 D(x): 0.7771 D(G(z)): 0.3579 / 0.1806
# [17/25][146/600] Loss_D: 0.8727 Loss_G: 1.4520 D(x): 0.6235 D(G(z)): 0.1772 / 0.2701
# [17/25][147/600] Loss_D: 0.8785 Loss_G: 1.3290 D(x): 0.7180 D(G(z)): 0.3229 / 0.3075
# [17/25][148/600] Loss_D: 0.8415 Loss_G: 1.7866 D(x): 0.7724 D(G(z)): 0.3477 / 0.2100
# [17/25][149/600] Loss_D: 0.8781 Loss_G: 1.5070 D(x): 0.6936 D(G(z)): 0.2773 / 0.2581
# [17/25][150/600] Loss_D: 0.8962 Loss_G: 1.5065 D(x): 0.6894 D(G(z)): 0.2945 / 0.2654
# [17/25][151/600] Loss_D: 0.8865 Loss_G: 1.8483 D(x): 0.7479 D(G(z)): 0.3281 / 0.1996
# [17/25][152/600] Loss_D: 0.8107 Loss_G: 1.5747 D(x): 0.6796 D(G(z)): 0.2135 / 0.2535
# [17/25][153/600] Loss_D: 0.7546 Loss_G: 1.7141 D(x): 0.7410 D(G(z)): 0.2759 / 0.2233
# [17/25][154/600] Loss_D: 0.7664 Loss_G: 1.9375 D(x): 0.7864 D(G(z)): 0.3073 / 0.1855
# [17/25][155/600] Loss_D: 0.9204 Loss_G: 1.3354 D(x): 0.6091 D(G(z)): 0.2127 / 0.3165
# [17/25][156/600] Loss_D: 0.9175 Loss_G: 1.5423 D(x): 0.7605 D(G(z)): 0.3690 / 0.2707
# [17/25][157/600] Loss_D: 0.8118 Loss_G: 1.8245 D(x): 0.7331 D(G(z)): 0.2980 / 0.2000
# [17/25][158/600] Loss_D: 0.7467 Loss_G: 1.6138 D(x): 0.7250 D(G(z)): 0.2521 / 0.2478
# [17/25][159/600] Loss_D: 0.9898 Loss_G: 1.6070 D(x): 0.7046 D(G(z)): 0.3134 / 0.2583
# [17/25][160/600] Loss_D: 0.8191 Loss_G: 1.5556 D(x): 0.7125 D(G(z)): 0.2809 / 0.2556
# [17/25][161/600] Loss_D: 0.8132 Loss_G: 1.6275 D(x): 0.7380 D(G(z)): 0.3015 / 0.2317
# [17/25][162/600] Loss_D: 0.8430 Loss_G: 1.7618 D(x): 0.7184 D(G(z)): 0.2746 / 0.2112
# [17/25][163/600] Loss_D: 0.8172 Loss_G: 1.6306 D(x): 0.6993 D(G(z)): 0.2604 / 0.2351
# [17/25][164/600] Loss_D: 0.8084 Loss_G: 1.4539 D(x): 0.7172 D(G(z)): 0.2803 / 0.2797
# [17/25][165/600] Loss_D: 0.8850 Loss_G: 1.8867 D(x): 0.7467 D(G(z)): 0.3359 / 0.2083
# [17/25][166/600] Loss_D: 0.8371 Loss_G: 1.6849 D(x): 0.6873 D(G(z)): 0.2659 / 0.2311
# [17/25][167/600] Loss_D: 0.8192 Loss_G: 1.3679 D(x): 0.7047 D(G(z)): 0.2779 / 0.3033
# [17/25][168/600] Loss_D: 0.9203 Loss_G: 1.8465 D(x): 0.7228 D(G(z)): 0.3512 / 0.1940
# [17/25][169/600] Loss_D: 0.8027 Loss_G: 1.7190 D(x): 0.7013 D(G(z)): 0.2522 / 0.2275
# [17/25][170/600] Loss_D: 0.8540 Loss_G: 1.3839 D(x): 0.6720 D(G(z)): 0.2583 / 0.2956
# [17/25][171/600] Loss_D: 0.9200 Loss_G: 1.8669 D(x): 0.7488 D(G(z)): 0.3438 / 0.1914
# [17/25][172/600] Loss_D: 0.9279 Loss_G: 1.4092 D(x): 0.6208 D(G(z)): 0.2389 / 0.2869
# [17/25][173/600] Loss_D: 0.9402 Loss_G: 1.6174 D(x): 0.7126 D(G(z)): 0.3305 / 0.2497
# [17/25][174/600] Loss_D: 0.8814 Loss_G: 1.9583 D(x): 0.7458 D(G(z)): 0.3557 / 0.1750
# [17/25][175/600] Loss_D: 0.7982 Loss_G: 1.5064 D(x): 0.6747 D(G(z)): 0.1917 / 0.2696
# [17/25][176/600] Loss_D: 0.8864 Loss_G: 1.5114 D(x): 0.7380 D(G(z)): 0.3379 / 0.2624
# [17/25][177/600] Loss_D: 0.7526 Loss_G: 1.9233 D(x): 0.7856 D(G(z)): 0.3131 / 0.1857
# [17/25][178/600] Loss_D: 0.8632 Loss_G: 1.5018 D(x): 0.6645 D(G(z)): 0.2233 / 0.2612
# [17/25][179/600] Loss_D: 0.7154 Loss_G: 1.6235 D(x): 0.7586 D(G(z)): 0.2609 / 0.2390
# [17/25][180/600] Loss_D: 0.7486 Loss_G: 1.8676 D(x): 0.7995 D(G(z)): 0.3126 / 0.1875
# [17/25][181/600] Loss_D: 0.8033 Loss_G: 1.6640 D(x): 0.6873 D(G(z)): 0.2142 / 0.2320
# [17/25][182/600] Loss_D: 0.9691 Loss_G: 1.3622 D(x): 0.6519 D(G(z)): 0.2627 / 0.3088
# [17/25][183/600] Loss_D: 0.8289 Loss_G: 1.9740 D(x): 0.8076 D(G(z)): 0.3642 / 0.1747
# [17/25][184/600] Loss_D: 0.9223 Loss_G: 1.5905 D(x): 0.6413 D(G(z)): 0.2562 / 0.2551
# [17/25][185/600] Loss_D: 0.9101 Loss_G: 1.1267 D(x): 0.6562 D(G(z)): 0.2653 / 0.3782
# [17/25][186/600] Loss_D: 0.9013 Loss_G: 2.2018 D(x): 0.8303 D(G(z)): 0.3993 / 0.1490
# [17/25][187/600] Loss_D: 0.8694 Loss_G: 1.5849 D(x): 0.6377 D(G(z)): 0.1912 / 0.2420
# [17/25][188/600] Loss_D: 0.8559 Loss_G: 1.1911 D(x): 0.6766 D(G(z)): 0.2645 / 0.3575
# [17/25][189/600] Loss_D: 0.7786 Loss_G: 2.0972 D(x): 0.8397 D(G(z)): 0.3806 / 0.1563
# [17/25][190/600] Loss_D: 0.9051 Loss_G: 1.6062 D(x): 0.6497 D(G(z)): 0.2292 / 0.2522
# [17/25][191/600] Loss_D: 0.7560 Loss_G: 1.6790 D(x): 0.7408 D(G(z)): 0.2646 / 0.2404
# [17/25][192/600] Loss_D: 0.8576 Loss_G: 1.5240 D(x): 0.7135 D(G(z)): 0.3002 / 0.2470
# [17/25][193/600] Loss_D: 0.8816 Loss_G: 1.8460 D(x): 0.7150 D(G(z)): 0.3101 / 0.2049
# [17/25][194/600] Loss_D: 0.8079 Loss_G: 1.7205 D(x): 0.7225 D(G(z)): 0.2740 / 0.2227
# [17/25][195/600] Loss_D: 0.8886 Loss_G: 1.2382 D(x): 0.6585 D(G(z)): 0.2446 / 0.3394
# [17/25][196/600] Loss_D: 0.8514 Loss_G: 1.9277 D(x): 0.8005 D(G(z)): 0.3755 / 0.1748
# [17/25][197/600] Loss_D: 0.8203 Loss_G: 1.6240 D(x): 0.6758 D(G(z)): 0.2417 / 0.2349
# [17/25][198/600] Loss_D: 0.7602 Loss_G: 1.7058 D(x): 0.7357 D(G(z)): 0.2594 / 0.2253
# [17/25][199/600] Loss_D: 0.8802 Loss_G: 1.4353 D(x): 0.6771 D(G(z)): 0.2724 / 0.2858
# [17/25][200/600] Loss_D: 0.7029 Loss_G: 1.7452 D(x): 0.8023 D(G(z)): 0.3057 / 0.2049
# saving the output
# [17/25][201/600] Loss_D: 0.7847 Loss_G: 1.7494 D(x): 0.7099 D(G(z)): 0.2458 / 0.2087
# [17/25][202/600] Loss_D: 0.8891 Loss_G: 1.5597 D(x): 0.6833 D(G(z)): 0.2636 / 0.2552
# [17/25][203/600] Loss_D: 0.7971 Loss_G: 1.4211 D(x): 0.7220 D(G(z)): 0.2737 / 0.2984
# [17/25][204/600] Loss_D: 0.8464 Loss_G: 1.6311 D(x): 0.7653 D(G(z)): 0.3388 / 0.2309
# [17/25][205/600] Loss_D: 0.7525 Loss_G: 1.7608 D(x): 0.7345 D(G(z)): 0.2761 / 0.2104
# [17/25][206/600] Loss_D: 0.8842 Loss_G: 1.5574 D(x): 0.6773 D(G(z)): 0.2747 / 0.2503
# [17/25][207/600] Loss_D: 0.7516 Loss_G: 1.4158 D(x): 0.7203 D(G(z)): 0.2525 / 0.2854
# [17/25][208/600] Loss_D: 0.8790 Loss_G: 1.6843 D(x): 0.7532 D(G(z)): 0.3410 / 0.2256
# [17/25][209/600] Loss_D: 0.9305 Loss_G: 1.5764 D(x): 0.6792 D(G(z)): 0.2743 / 0.2399
# [17/25][210/600] Loss_D: 0.9737 Loss_G: 1.4269 D(x): 0.6516 D(G(z)): 0.2722 / 0.2858
# [17/25][211/600] Loss_D: 0.9200 Loss_G: 1.4385 D(x): 0.6776 D(G(z)): 0.2992 / 0.2739
# [17/25][212/600] Loss_D: 0.9053 Loss_G: 1.7548 D(x): 0.7352 D(G(z)): 0.3365 / 0.2163
# [17/25][213/600] Loss_D: 0.8166 Loss_G: 1.7597 D(x): 0.7051 D(G(z)): 0.2792 / 0.2166
# [17/25][214/600] Loss_D: 0.9454 Loss_G: 1.3038 D(x): 0.6508 D(G(z)): 0.2751 / 0.3207
# [17/25][215/600] Loss_D: 0.9759 Loss_G: 1.7370 D(x): 0.7375 D(G(z)): 0.3729 / 0.2253
# [17/25][216/600] Loss_D: 0.8929 Loss_G: 1.5417 D(x): 0.6629 D(G(z)): 0.2482 / 0.2551
# [17/25][217/600] Loss_D: 0.8375 Loss_G: 1.8449 D(x): 0.7354 D(G(z)): 0.2996 / 0.2072
# [17/25][218/600] Loss_D: 0.7536 Loss_G: 1.4829 D(x): 0.7041 D(G(z)): 0.2363 / 0.2642
# [17/25][219/600] Loss_D: 0.8563 Loss_G: 1.7764 D(x): 0.7595 D(G(z)): 0.3324 / 0.2177
# [17/25][220/600] Loss_D: 0.9608 Loss_G: 1.5213 D(x): 0.6610 D(G(z)): 0.2789 / 0.2679
# [17/25][221/600] Loss_D: 0.8898 Loss_G: 1.4087 D(x): 0.6762 D(G(z)): 0.2708 / 0.2917
# [17/25][222/600] Loss_D: 0.7486 Loss_G: 1.5885 D(x): 0.7587 D(G(z)): 0.3103 / 0.2393
# [17/25][223/600] Loss_D: 0.8428 Loss_G: 1.5717 D(x): 0.7132 D(G(z)): 0.2837 / 0.2523
# [17/25][224/600] Loss_D: 0.7612 Loss_G: 1.4730 D(x): 0.7260 D(G(z)): 0.2705 / 0.2665
# [17/25][225/600] Loss_D: 0.8328 Loss_G: 1.7159 D(x): 0.7475 D(G(z)): 0.3313 / 0.2215
# [17/25][226/600] Loss_D: 0.7697 Loss_G: 1.9852 D(x): 0.7516 D(G(z)): 0.2857 / 0.1737
# [17/25][227/600] Loss_D: 0.8977 Loss_G: 1.2595 D(x): 0.6273 D(G(z)): 0.1987 / 0.3257
# [17/25][228/600] Loss_D: 0.8453 Loss_G: 1.8528 D(x): 0.8064 D(G(z)): 0.3648 / 0.1870
# [17/25][229/600] Loss_D: 0.9066 Loss_G: 1.4881 D(x): 0.6174 D(G(z)): 0.2091 / 0.2707
# [17/25][230/600] Loss_D: 0.7703 Loss_G: 1.4163 D(x): 0.7658 D(G(z)): 0.3167 / 0.2756
# [17/25][231/600] Loss_D: 0.8427 Loss_G: 1.8992 D(x): 0.7828 D(G(z)): 0.3253 / 0.1984
# [17/25][232/600] Loss_D: 0.8734 Loss_G: 1.4397 D(x): 0.6648 D(G(z)): 0.2398 / 0.2700
# [17/25][233/600] Loss_D: 0.7387 Loss_G: 1.5865 D(x): 0.7750 D(G(z)): 0.2842 / 0.2471
# [17/25][234/600] Loss_D: 0.7137 Loss_G: 1.4830 D(x): 0.7362 D(G(z)): 0.2533 / 0.2634
# [17/25][235/600] Loss_D: 0.8769 Loss_G: 1.8744 D(x): 0.7836 D(G(z)): 0.3437 / 0.1937
# [17/25][236/600] Loss_D: 0.8927 Loss_G: 1.6004 D(x): 0.6440 D(G(z)): 0.2209 / 0.2497
# [17/25][237/600] Loss_D: 0.9053 Loss_G: 1.2352 D(x): 0.6934 D(G(z)): 0.2680 / 0.3334
# [17/25][238/600] Loss_D: 0.8783 Loss_G: 1.8344 D(x): 0.8164 D(G(z)): 0.3885 / 0.1978
# [17/25][239/600] Loss_D: 0.8902 Loss_G: 1.7641 D(x): 0.6648 D(G(z)): 0.2331 / 0.2097
# [17/25][240/600] Loss_D: 0.8899 Loss_G: 1.5420 D(x): 0.6762 D(G(z)): 0.2445 / 0.2494
# [17/25][241/600] Loss_D: 0.8504 Loss_G: 1.6781 D(x): 0.7327 D(G(z)): 0.3052 / 0.2383
# [17/25][242/600] Loss_D: 0.9643 Loss_G: 1.6256 D(x): 0.6964 D(G(z)): 0.3219 / 0.2472
# [17/25][243/600] Loss_D: 0.7946 Loss_G: 1.4317 D(x): 0.6783 D(G(z)): 0.2330 / 0.2841
# [17/25][244/600] Loss_D: 0.9243 Loss_G: 1.6243 D(x): 0.7511 D(G(z)): 0.3409 / 0.2494
# [17/25][245/600] Loss_D: 0.7809 Loss_G: 1.4250 D(x): 0.6973 D(G(z)): 0.2426 / 0.2841
# [17/25][246/600] Loss_D: 0.8737 Loss_G: 1.5332 D(x): 0.7198 D(G(z)): 0.3302 / 0.2633
# [17/25][247/600] Loss_D: 0.8752 Loss_G: 1.7792 D(x): 0.7405 D(G(z)): 0.3454 / 0.2058
# [17/25][248/600] Loss_D: 0.8394 Loss_G: 1.4098 D(x): 0.6539 D(G(z)): 0.2215 / 0.2980
# [17/25][249/600] Loss_D: 0.9618 Loss_G: 1.5459 D(x): 0.7204 D(G(z)): 0.3669 / 0.2560
# [17/25][250/600] Loss_D: 0.8221 Loss_G: 1.7730 D(x): 0.7062 D(G(z)): 0.2842 / 0.2181
# [17/25][251/600] Loss_D: 0.8623 Loss_G: 1.4405 D(x): 0.6927 D(G(z)): 0.2857 / 0.2820
# [17/25][252/600] Loss_D: 0.7919 Loss_G: 1.5629 D(x): 0.7268 D(G(z)): 0.2850 / 0.2455
# [17/25][253/600] Loss_D: 0.8487 Loss_G: 1.4911 D(x): 0.7137 D(G(z)): 0.3096 / 0.2584
# [17/25][254/600] Loss_D: 0.8681 Loss_G: 1.5775 D(x): 0.7234 D(G(z)): 0.3118 / 0.2448
# [17/25][255/600] Loss_D: 0.8093 Loss_G: 1.5886 D(x): 0.7154 D(G(z)): 0.2632 / 0.2398
# [17/25][256/600] Loss_D: 0.8442 Loss_G: 1.5039 D(x): 0.7093 D(G(z)): 0.2988 / 0.2609
# [17/25][257/600] Loss_D: 0.8630 Loss_G: 1.8379 D(x): 0.7048 D(G(z)): 0.2766 / 0.2024
# [17/25][258/600] Loss_D: 0.8790 Loss_G: 1.5795 D(x): 0.6642 D(G(z)): 0.2588 / 0.2519
# [17/25][259/600] Loss_D: 0.8967 Loss_G: 1.4403 D(x): 0.7076 D(G(z)): 0.3339 / 0.2764
# [17/25][260/600] Loss_D: 0.8466 Loss_G: 1.4436 D(x): 0.6886 D(G(z)): 0.2772 / 0.2760
# [17/25][261/600] Loss_D: 0.8871 Loss_G: 1.6112 D(x): 0.7448 D(G(z)): 0.3412 / 0.2435
# [17/25][262/600] Loss_D: 0.8699 Loss_G: 1.4481 D(x): 0.6482 D(G(z)): 0.2338 / 0.2797
# [17/25][263/600] Loss_D: 0.8283 Loss_G: 1.5874 D(x): 0.7478 D(G(z)): 0.3285 / 0.2411
# [17/25][264/600] Loss_D: 1.0138 Loss_G: 1.4107 D(x): 0.6514 D(G(z)): 0.3193 / 0.2869
# [17/25][265/600] Loss_D: 0.8381 Loss_G: 1.6246 D(x): 0.7033 D(G(z)): 0.2894 / 0.2383
# [17/25][266/600] Loss_D: 0.7779 Loss_G: 1.6501 D(x): 0.7361 D(G(z)): 0.2899 / 0.2246
# [17/25][267/600] Loss_D: 0.8426 Loss_G: 1.6961 D(x): 0.7088 D(G(z)): 0.2783 / 0.2281
# [17/25][268/600] Loss_D: 0.9712 Loss_G: 1.5634 D(x): 0.6841 D(G(z)): 0.3075 / 0.2618
# [17/25][269/600] Loss_D: 0.8989 Loss_G: 1.8038 D(x): 0.7082 D(G(z)): 0.3193 / 0.2103
# [17/25][270/600] Loss_D: 0.8818 Loss_G: 1.3531 D(x): 0.6457 D(G(z)): 0.2245 / 0.3079
# [17/25][271/600] Loss_D: 0.7815 Loss_G: 1.8220 D(x): 0.8004 D(G(z)): 0.3546 / 0.2005
# [17/25][272/600] Loss_D: 0.8085 Loss_G: 1.9529 D(x): 0.7372 D(G(z)): 0.2864 / 0.1799
# [17/25][273/600] Loss_D: 0.9769 Loss_G: 1.2644 D(x): 0.6361 D(G(z)): 0.2327 / 0.3375
# [17/25][274/600] Loss_D: 0.9035 Loss_G: 1.5999 D(x): 0.7433 D(G(z)): 0.3642 / 0.2435
# [17/25][275/600] Loss_D: 0.9841 Loss_G: 1.6195 D(x): 0.6699 D(G(z)): 0.3092 / 0.2424
# [17/25][276/600] Loss_D: 0.7084 Loss_G: 1.7753 D(x): 0.7413 D(G(z)): 0.2612 / 0.2119
# [17/25][277/600] Loss_D: 0.9126 Loss_G: 1.4522 D(x): 0.6655 D(G(z)): 0.2727 / 0.2940
# [17/25][278/600] Loss_D: 0.8142 Loss_G: 1.4855 D(x): 0.7396 D(G(z)): 0.3064 / 0.2718
# [17/25][279/600] Loss_D: 0.8027 Loss_G: 1.8098 D(x): 0.7872 D(G(z)): 0.3341 / 0.2092
# [17/25][280/600] Loss_D: 0.8189 Loss_G: 1.7506 D(x): 0.6859 D(G(z)): 0.2377 / 0.2154
# [17/25][281/600] Loss_D: 0.9018 Loss_G: 1.4033 D(x): 0.6591 D(G(z)): 0.2726 / 0.2961
# [17/25][282/600] Loss_D: 0.7653 Loss_G: 1.6140 D(x): 0.7697 D(G(z)): 0.3196 / 0.2365
# [17/25][283/600] Loss_D: 0.9360 Loss_G: 1.5493 D(x): 0.6683 D(G(z)): 0.2977 / 0.2540
# [17/25][284/600] Loss_D: 0.8683 Loss_G: 1.4657 D(x): 0.6984 D(G(z)): 0.2967 / 0.2740
# [17/25][285/600] Loss_D: 0.9262 Loss_G: 1.4422 D(x): 0.6749 D(G(z)): 0.2854 / 0.2883
# [17/25][286/600] Loss_D: 0.9980 Loss_G: 2.2611 D(x): 0.7670 D(G(z)): 0.3912 / 0.1394
# [17/25][287/600] Loss_D: 1.0526 Loss_G: 1.1195 D(x): 0.5412 D(G(z)): 0.1939 / 0.3670
# [17/25][288/600] Loss_D: 0.9292 Loss_G: 1.4514 D(x): 0.7808 D(G(z)): 0.4201 / 0.2683
# [17/25][289/600] Loss_D: 0.8913 Loss_G: 1.6766 D(x): 0.6743 D(G(z)): 0.2886 / 0.2269
# [17/25][290/600] Loss_D: 0.9487 Loss_G: 1.1542 D(x): 0.6302 D(G(z)): 0.2691 / 0.3656
# [17/25][291/600] Loss_D: 1.0138 Loss_G: 1.6267 D(x): 0.7764 D(G(z)): 0.4311 / 0.2391
# [17/25][292/600] Loss_D: 0.7852 Loss_G: 1.7110 D(x): 0.6995 D(G(z)): 0.2328 / 0.2162
# [17/25][293/600] Loss_D: 0.8679 Loss_G: 1.5695 D(x): 0.6978 D(G(z)): 0.2720 / 0.2562
# [17/25][294/600] Loss_D: 0.8951 Loss_G: 1.7133 D(x): 0.7243 D(G(z)): 0.3090 / 0.2220
# [17/25][295/600] Loss_D: 1.0560 Loss_G: 1.5311 D(x): 0.6405 D(G(z)): 0.3117 / 0.2642
# [17/25][296/600] Loss_D: 0.8725 Loss_G: 1.3545 D(x): 0.6802 D(G(z)): 0.2706 / 0.2974
# [17/25][297/600] Loss_D: 0.8906 Loss_G: 1.4545 D(x): 0.7158 D(G(z)): 0.3507 / 0.2787
# [17/25][298/600] Loss_D: 0.8014 Loss_G: 1.6430 D(x): 0.6973 D(G(z)): 0.2647 / 0.2425
# [17/25][299/600] Loss_D: 0.7909 Loss_G: 1.8600 D(x): 0.7549 D(G(z)): 0.3098 / 0.1944
# [17/25][300/600] Loss_D: 0.9772 Loss_G: 1.4418 D(x): 0.6486 D(G(z)): 0.2848 / 0.2948
# saving the output
# [17/25][301/600] Loss_D: 0.8412 Loss_G: 1.5915 D(x): 0.7119 D(G(z)): 0.3054 / 0.2603
# [17/25][302/600] Loss_D: 0.9551 Loss_G: 1.6815 D(x): 0.7123 D(G(z)): 0.3468 / 0.2248
# [17/25][303/600] Loss_D: 1.0629 Loss_G: 1.4795 D(x): 0.6435 D(G(z)): 0.3157 / 0.2823
# [17/25][304/600] Loss_D: 0.8957 Loss_G: 1.5271 D(x): 0.7007 D(G(z)): 0.3123 / 0.2666
# [17/25][305/600] Loss_D: 0.9366 Loss_G: 1.8195 D(x): 0.7032 D(G(z)): 0.3183 / 0.2050
# [17/25][306/600] Loss_D: 0.9655 Loss_G: 1.4903 D(x): 0.6557 D(G(z)): 0.2784 / 0.2765
# [17/25][307/600] Loss_D: 0.8393 Loss_G: 2.0802 D(x): 0.7766 D(G(z)): 0.3490 / 0.1700
# [17/25][308/600] Loss_D: 1.0288 Loss_G: 1.0013 D(x): 0.5590 D(G(z)): 0.2089 / 0.4209
# [17/25][309/600] Loss_D: 1.0166 Loss_G: 1.9822 D(x): 0.8359 D(G(z)): 0.4672 / 0.1741
# [17/25][310/600] Loss_D: 0.9284 Loss_G: 1.4464 D(x): 0.6271 D(G(z)): 0.2359 / 0.2761
# [17/25][311/600] Loss_D: 0.7185 Loss_G: 1.5307 D(x): 0.7550 D(G(z)): 0.2603 / 0.2628
# [17/25][312/600] Loss_D: 0.9386 Loss_G: 1.9882 D(x): 0.7435 D(G(z)): 0.3668 / 0.1693
# [17/25][313/600] Loss_D: 1.0033 Loss_G: 1.3817 D(x): 0.6060 D(G(z)): 0.2585 / 0.2934
# [17/25][314/600] Loss_D: 0.8499 Loss_G: 1.3609 D(x): 0.7067 D(G(z)): 0.2774 / 0.2990
# [17/25][315/600] Loss_D: 0.8783 Loss_G: 1.7756 D(x): 0.7569 D(G(z)): 0.3608 / 0.2129
# [17/25][316/600] Loss_D: 0.8702 Loss_G: 1.5349 D(x): 0.6551 D(G(z)): 0.2338 / 0.2602
# [17/25][317/600] Loss_D: 0.8197 Loss_G: 1.4527 D(x): 0.7121 D(G(z)): 0.2884 / 0.2727
# [17/25][318/600] Loss_D: 0.8422 Loss_G: 2.0832 D(x): 0.7765 D(G(z)): 0.3396 / 0.1576
# [17/25][319/600] Loss_D: 0.8410 Loss_G: 1.5035 D(x): 0.6502 D(G(z)): 0.1904 / 0.2634
# [17/25][320/600] Loss_D: 0.9944 Loss_G: 1.5809 D(x): 0.7254 D(G(z)): 0.3720 / 0.2549
# [17/25][321/600] Loss_D: 0.8458 Loss_G: 1.9486 D(x): 0.7330 D(G(z)): 0.3040 / 0.1809
# [17/25][322/600] Loss_D: 0.9492 Loss_G: 1.1814 D(x): 0.6183 D(G(z)): 0.2412 / 0.3656
# [17/25][323/600] Loss_D: 0.9641 Loss_G: 1.9588 D(x): 0.8207 D(G(z)): 0.4441 / 0.1722
# [17/25][324/600] Loss_D: 0.9253 Loss_G: 1.5769 D(x): 0.6156 D(G(z)): 0.2152 / 0.2448
# [17/25][325/600] Loss_D: 0.8923 Loss_G: 1.4486 D(x): 0.7199 D(G(z)): 0.3094 / 0.2922
# [17/25][326/600] Loss_D: 0.7276 Loss_G: 1.7974 D(x): 0.7817 D(G(z)): 0.2943 / 0.2092
# [17/25][327/600] Loss_D: 0.8695 Loss_G: 1.5970 D(x): 0.6903 D(G(z)): 0.2919 / 0.2401
# [17/25][328/600] Loss_D: 0.8469 Loss_G: 1.5497 D(x): 0.6738 D(G(z)): 0.2441 / 0.2569
# [17/25][329/600] Loss_D: 0.9374 Loss_G: 1.8307 D(x): 0.7227 D(G(z)): 0.3399 / 0.2020
# [17/25][330/600] Loss_D: 0.9462 Loss_G: 1.7164 D(x): 0.6768 D(G(z)): 0.2933 / 0.2207
# [17/25][331/600] Loss_D: 0.9733 Loss_G: 1.3184 D(x): 0.6329 D(G(z)): 0.2717 / 0.3209
# [17/25][332/600] Loss_D: 0.8358 Loss_G: 1.7953 D(x): 0.8010 D(G(z)): 0.3856 / 0.2049
# [17/25][333/600] Loss_D: 0.8822 Loss_G: 1.6264 D(x): 0.6647 D(G(z)): 0.2420 / 0.2398
# [17/25][334/600] Loss_D: 0.8831 Loss_G: 1.7014 D(x): 0.7088 D(G(z)): 0.3065 / 0.2219
# [17/25][335/600] Loss_D: 0.8418 Loss_G: 1.7235 D(x): 0.6900 D(G(z)): 0.2591 / 0.2245
# [17/25][336/600] Loss_D: 0.8174 Loss_G: 1.2617 D(x): 0.6727 D(G(z)): 0.2421 / 0.3301
# [17/25][337/600] Loss_D: 0.9548 Loss_G: 1.9749 D(x): 0.7665 D(G(z)): 0.3959 / 0.1918
# [17/25][338/600] Loss_D: 0.8362 Loss_G: 1.6451 D(x): 0.6857 D(G(z)): 0.2741 / 0.2484
# [17/25][339/600] Loss_D: 0.8496 Loss_G: 1.3462 D(x): 0.6941 D(G(z)): 0.2940 / 0.2990
# [17/25][340/600] Loss_D: 0.8636 Loss_G: 1.7117 D(x): 0.7632 D(G(z)): 0.3530 / 0.2219
# [17/25][341/600] Loss_D: 1.0312 Loss_G: 1.5291 D(x): 0.6424 D(G(z)): 0.2760 / 0.2679
# [17/25][342/600] Loss_D: 0.9356 Loss_G: 1.3854 D(x): 0.6754 D(G(z)): 0.3076 / 0.2847
# [17/25][343/600] Loss_D: 0.8689 Loss_G: 1.7535 D(x): 0.7198 D(G(z)): 0.3228 / 0.2248
# [17/25][344/600] Loss_D: 0.8385 Loss_G: 1.4151 D(x): 0.6744 D(G(z)): 0.2404 / 0.2824
# [17/25][345/600] Loss_D: 0.8958 Loss_G: 1.6782 D(x): 0.7327 D(G(z)): 0.3528 / 0.2341
# [17/25][346/600] Loss_D: 0.8774 Loss_G: 1.5654 D(x): 0.6898 D(G(z)): 0.2864 / 0.2538
# [17/25][347/600] Loss_D: 0.7900 Loss_G: 1.6914 D(x): 0.7343 D(G(z)): 0.2790 / 0.2328
# [17/25][348/600] Loss_D: 0.9018 Loss_G: 1.4292 D(x): 0.6831 D(G(z)): 0.2816 / 0.2769
# [17/25][349/600] Loss_D: 0.9391 Loss_G: 1.3234 D(x): 0.6720 D(G(z)): 0.3026 / 0.3102
# [17/25][350/600] Loss_D: 0.7897 Loss_G: 1.7111 D(x): 0.7958 D(G(z)): 0.3485 / 0.2172
# [17/25][351/600] Loss_D: 1.0255 Loss_G: 1.4171 D(x): 0.6282 D(G(z)): 0.2647 / 0.2863
# [17/25][352/600] Loss_D: 0.9123 Loss_G: 1.4958 D(x): 0.7106 D(G(z)): 0.3230 / 0.2715
# [17/25][353/600] Loss_D: 0.7850 Loss_G: 1.6950 D(x): 0.7563 D(G(z)): 0.3018 / 0.2248
# [17/25][354/600] Loss_D: 0.7681 Loss_G: 1.8836 D(x): 0.7402 D(G(z)): 0.2815 / 0.1878
# [17/25][355/600] Loss_D: 0.9170 Loss_G: 1.6163 D(x): 0.6784 D(G(z)): 0.2744 / 0.2415
# [17/25][356/600] Loss_D: 0.9032 Loss_G: 1.3864 D(x): 0.6496 D(G(z)): 0.2407 / 0.3141
# [17/25][357/600] Loss_D: 0.8945 Loss_G: 1.8464 D(x): 0.7638 D(G(z)): 0.3730 / 0.1910
# [17/25][358/600] Loss_D: 0.7599 Loss_G: 1.6002 D(x): 0.7001 D(G(z)): 0.2223 / 0.2363
# [17/25][359/600] Loss_D: 0.8906 Loss_G: 1.5079 D(x): 0.7139 D(G(z)): 0.3080 / 0.2713
# [17/25][360/600] Loss_D: 1.0273 Loss_G: 1.5855 D(x): 0.6773 D(G(z)): 0.3594 / 0.2421
# [17/25][361/600] Loss_D: 0.9020 Loss_G: 1.6744 D(x): 0.7074 D(G(z)): 0.2961 / 0.2293
# [17/25][362/600] Loss_D: 0.8638 Loss_G: 1.2004 D(x): 0.6475 D(G(z)): 0.2342 / 0.3496
# [17/25][363/600] Loss_D: 0.9006 Loss_G: 1.6750 D(x): 0.7568 D(G(z)): 0.3760 / 0.2166
# [17/25][364/600] Loss_D: 0.7844 Loss_G: 2.0441 D(x): 0.7715 D(G(z)): 0.3133 / 0.1682
# [17/25][365/600] Loss_D: 0.8919 Loss_G: 1.2385 D(x): 0.6020 D(G(z)): 0.1748 / 0.3330
# [17/25][366/600] Loss_D: 0.7897 Loss_G: 1.6266 D(x): 0.8103 D(G(z)): 0.3694 / 0.2312
# [17/25][367/600] Loss_D: 0.6999 Loss_G: 2.0061 D(x): 0.7547 D(G(z)): 0.2660 / 0.1669
# [17/25][368/600] Loss_D: 0.8972 Loss_G: 1.6441 D(x): 0.6816 D(G(z)): 0.2567 / 0.2471
# [17/25][369/600] Loss_D: 0.8952 Loss_G: 1.2093 D(x): 0.6753 D(G(z)): 0.2546 / 0.3485
# [17/25][370/600] Loss_D: 0.9468 Loss_G: 1.8106 D(x): 0.7886 D(G(z)): 0.4149 / 0.1988
# [17/25][371/600] Loss_D: 0.8295 Loss_G: 1.7863 D(x): 0.6854 D(G(z)): 0.2575 / 0.2044
# [17/25][372/600] Loss_D: 0.7723 Loss_G: 1.5277 D(x): 0.6898 D(G(z)): 0.2280 / 0.2604
# [17/25][373/600] Loss_D: 0.7477 Loss_G: 1.5884 D(x): 0.7400 D(G(z)): 0.2641 / 0.2502
# [17/25][374/600] Loss_D: 0.9888 Loss_G: 1.5864 D(x): 0.6832 D(G(z)): 0.3498 / 0.2505
# [17/25][375/600] Loss_D: 0.9143 Loss_G: 1.4063 D(x): 0.6618 D(G(z)): 0.2754 / 0.2939
# [17/25][376/600] Loss_D: 0.7762 Loss_G: 1.6521 D(x): 0.7512 D(G(z)): 0.3076 / 0.2367
# [17/25][377/600] Loss_D: 0.8414 Loss_G: 1.5487 D(x): 0.7126 D(G(z)): 0.3236 / 0.2465
# [17/25][378/600] Loss_D: 0.8709 Loss_G: 1.5201 D(x): 0.7068 D(G(z)): 0.2962 / 0.2579
# [17/25][379/600] Loss_D: 0.7425 Loss_G: 1.7978 D(x): 0.7694 D(G(z)): 0.2955 / 0.2013
# [17/25][380/600] Loss_D: 0.8246 Loss_G: 1.6478 D(x): 0.6989 D(G(z)): 0.2516 / 0.2368
# [17/25][381/600] Loss_D: 0.8234 Loss_G: 1.7121 D(x): 0.7192 D(G(z)): 0.2776 / 0.2176
# [17/25][382/600] Loss_D: 0.9220 Loss_G: 1.4040 D(x): 0.6667 D(G(z)): 0.2863 / 0.2871
# [17/25][383/600] Loss_D: 0.8753 Loss_G: 1.6276 D(x): 0.7225 D(G(z)): 0.3264 / 0.2289
# [17/25][384/600] Loss_D: 0.8230 Loss_G: 1.5280 D(x): 0.7107 D(G(z)): 0.2684 / 0.2551
# [17/25][385/600] Loss_D: 0.7816 Loss_G: 1.5125 D(x): 0.7290 D(G(z)): 0.2855 / 0.2585
# [17/25][386/600] Loss_D: 0.9514 Loss_G: 1.8555 D(x): 0.7157 D(G(z)): 0.3413 / 0.1959
# [17/25][387/600] Loss_D: 0.8702 Loss_G: 1.3734 D(x): 0.6555 D(G(z)): 0.2424 / 0.2973
# [17/25][388/600] Loss_D: 0.7992 Loss_G: 1.5333 D(x): 0.7694 D(G(z)): 0.3323 / 0.2553
# [17/25][389/600] Loss_D: 0.8715 Loss_G: 1.8546 D(x): 0.7235 D(G(z)): 0.3135 / 0.1956
# [17/25][390/600] Loss_D: 1.0007 Loss_G: 1.1766 D(x): 0.5770 D(G(z)): 0.2139 / 0.3635
# [17/25][391/600] Loss_D: 0.9346 Loss_G: 1.7698 D(x): 0.7940 D(G(z)): 0.4189 / 0.2139
# [17/25][392/600] Loss_D: 0.8504 Loss_G: 1.5517 D(x): 0.6515 D(G(z)): 0.2206 / 0.2492
# [17/25][393/600] Loss_D: 0.8828 Loss_G: 1.5164 D(x): 0.7098 D(G(z)): 0.3041 / 0.2551
# [17/25][394/600] Loss_D: 0.9100 Loss_G: 1.5154 D(x): 0.6957 D(G(z)): 0.3141 / 0.2653
# [17/25][395/600] Loss_D: 0.9629 Loss_G: 1.6554 D(x): 0.6821 D(G(z)): 0.3200 / 0.2350
# [17/25][396/600] Loss_D: 0.9514 Loss_G: 1.4765 D(x): 0.6578 D(G(z)): 0.2796 / 0.2759
# [17/25][397/600] Loss_D: 0.7575 Loss_G: 1.7343 D(x): 0.7602 D(G(z)): 0.3021 / 0.2195
# [17/25][398/600] Loss_D: 0.9121 Loss_G: 1.4305 D(x): 0.6378 D(G(z)): 0.2486 / 0.2865
# [17/25][399/600] Loss_D: 0.8992 Loss_G: 1.7889 D(x): 0.7486 D(G(z)): 0.3703 / 0.2112
# [17/25][400/600] Loss_D: 0.7688 Loss_G: 1.6801 D(x): 0.7023 D(G(z)): 0.2589 / 0.2281
# saving the output
# [17/25][401/600] Loss_D: 0.9129 Loss_G: 1.1984 D(x): 0.6453 D(G(z)): 0.2519 / 0.3588
# [17/25][402/600] Loss_D: 0.9551 Loss_G: 1.6799 D(x): 0.7656 D(G(z)): 0.4082 / 0.2293
# [17/25][403/600] Loss_D: 0.8903 Loss_G: 1.7479 D(x): 0.6836 D(G(z)): 0.2923 / 0.2292
# [17/25][404/600] Loss_D: 0.8141 Loss_G: 1.2845 D(x): 0.6808 D(G(z)): 0.2323 / 0.3197
# [17/25][405/600] Loss_D: 0.9492 Loss_G: 1.5813 D(x): 0.7353 D(G(z)): 0.3803 / 0.2448
# ...
# [24/25][412/600] Loss_D: 0.9620 Loss_G: 1.7527 D(x): 0.7262 D(G(z)): 0.3464 / 0.2151
# [24/25][413/600] Loss_D: 0.9483 Loss_G: 1.3065 D(x): 0.6333 D(G(z)): 0.2493 / 0.3139
# [24/25][414/600] Loss_D: 0.8611 Loss_G: 1.5803 D(x): 0.7346 D(G(z)): 0.3435 / 0.2566
# [24/25][415/600] Loss_D: 0.8940 Loss_G: 1.7981 D(x): 0.7363 D(G(z)): 0.3489 / 0.2121
# [24/25][416/600] Loss_D: 0.9721 Loss_G: 1.3170 D(x): 0.6018 D(G(z)): 0.2415 / 0.3181
# [24/25][417/600] Loss_D: 0.8168 Loss_G: 1.4469 D(x): 0.7726 D(G(z)): 0.3355 / 0.2779
# [24/25][418/600] Loss_D: 0.8432 Loss_G: 1.7875 D(x): 0.7435 D(G(z)): 0.3301 / 0.2139
# [24/25][419/600] Loss_D: 0.8364 Loss_G: 1.7273 D(x): 0.7091 D(G(z)): 0.2533 / 0.2275
# [24/25][420/600] Loss_D: 0.8926 Loss_G: 1.3352 D(x): 0.6640 D(G(z)): 0.2592 / 0.3132
# [24/25][421/600] Loss_D: 0.8244 Loss_G: 1.7612 D(x): 0.7849 D(G(z)): 0.3501 / 0.2151
# [24/25][422/600] Loss_D: 0.8651 Loss_G: 1.6489 D(x): 0.6932 D(G(z)): 0.2772 / 0.2443
# [24/25][423/600] Loss_D: 0.8688 Loss_G: 1.4719 D(x): 0.6939 D(G(z)): 0.2677 / 0.2798
# [24/25][424/600] Loss_D: 0.8307 Loss_G: 1.6552 D(x): 0.7380 D(G(z)): 0.3136 / 0.2334
# [24/25][425/600] Loss_D: 0.8866 Loss_G: 1.7220 D(x): 0.6990 D(G(z)): 0.2990 / 0.2188
# [24/25][426/600] Loss_D: 1.0053 Loss_G: 1.1518 D(x): 0.6071 D(G(z)): 0.2631 / 0.3608
# [24/25][427/600] Loss_D: 0.8465 Loss_G: 1.7303 D(x): 0.8022 D(G(z)): 0.3646 / 0.2255
# [24/25][428/600] Loss_D: 0.7206 Loss_G: 1.7765 D(x): 0.7557 D(G(z)): 0.2736 / 0.2050
# [24/25][429/600] Loss_D: 0.9241 Loss_G: 1.5470 D(x): 0.6539 D(G(z)): 0.2557 / 0.2641
# [24/25][430/600] Loss_D: 1.0073 Loss_G: 1.3355 D(x): 0.6569 D(G(z)): 0.2940 / 0.3191
# [24/25][431/600] Loss_D: 0.8779 Loss_G: 1.6741 D(x): 0.7577 D(G(z)): 0.3540 / 0.2237
# [24/25][432/600] Loss_D: 0.9168 Loss_G: 1.5920 D(x): 0.6741 D(G(z)): 0.2827 / 0.2482
# [24/25][433/600] Loss_D: 0.8924 Loss_G: 1.4082 D(x): 0.6759 D(G(z)): 0.2703 / 0.3056
# [24/25][434/600] Loss_D: 0.8503 Loss_G: 1.6785 D(x): 0.7475 D(G(z)): 0.3453 / 0.2204
# [24/25][435/600] Loss_D: 0.7238 Loss_G: 1.5922 D(x): 0.7188 D(G(z)): 0.2453 / 0.2397
# [24/25][436/600] Loss_D: 1.0533 Loss_G: 1.5224 D(x): 0.6437 D(G(z)): 0.3143 / 0.2542
# [24/25][437/600] Loss_D: 0.7949 Loss_G: 1.7641 D(x): 0.7472 D(G(z)): 0.3162 / 0.2275
# [24/25][438/600] Loss_D: 0.9297 Loss_G: 1.4323 D(x): 0.6724 D(G(z)): 0.2881 / 0.2848
# [24/25][439/600] Loss_D: 0.7629 Loss_G: 1.5099 D(x): 0.7361 D(G(z)): 0.2783 / 0.2670
# [24/25][440/600] Loss_D: 0.8330 Loss_G: 1.8488 D(x): 0.7826 D(G(z)): 0.3472 / 0.1981
# [24/25][441/600] Loss_D: 0.8598 Loss_G: 1.6346 D(x): 0.6732 D(G(z)): 0.2225 / 0.2396
# [24/25][442/600] Loss_D: 0.9399 Loss_G: 1.4317 D(x): 0.6689 D(G(z)): 0.2902 / 0.2857
# [24/25][443/600] Loss_D: 0.9399 Loss_G: 1.7401 D(x): 0.7534 D(G(z)): 0.3609 / 0.2204
# [24/25][444/600] Loss_D: 0.8485 Loss_G: 1.4724 D(x): 0.6416 D(G(z)): 0.2178 / 0.2800
# [24/25][445/600] Loss_D: 0.8920 Loss_G: 1.2613 D(x): 0.6840 D(G(z)): 0.3018 / 0.3350
# [24/25][446/600] Loss_D: 0.8284 Loss_G: 1.7346 D(x): 0.8159 D(G(z)): 0.3772 / 0.2156
# [24/25][447/600] Loss_D: 0.8479 Loss_G: 1.4756 D(x): 0.6514 D(G(z)): 0.1973 / 0.2700
# [24/25][448/600] Loss_D: 0.7952 Loss_G: 1.7213 D(x): 0.7759 D(G(z)): 0.3319 / 0.2267
# [24/25][449/600] Loss_D: 0.8706 Loss_G: 1.5070 D(x): 0.6834 D(G(z)): 0.2739 / 0.2645
# [24/25][450/600] Loss_D: 0.9430 Loss_G: 1.7461 D(x): 0.7206 D(G(z)): 0.3331 / 0.2189
# [24/25][451/600] Loss_D: 0.8994 Loss_G: 1.5387 D(x): 0.6667 D(G(z)): 0.2359 / 0.2561
# [24/25][452/600] Loss_D: 0.9264 Loss_G: 1.3380 D(x): 0.6884 D(G(z)): 0.3039 / 0.3128
# [24/25][453/600] Loss_D: 0.9444 Loss_G: 1.8075 D(x): 0.7473 D(G(z)): 0.3631 / 0.2073
# [24/25][454/600] Loss_D: 0.9661 Loss_G: 1.4997 D(x): 0.6311 D(G(z)): 0.2560 / 0.2651
# [24/25][455/600] Loss_D: 0.8032 Loss_G: 1.7287 D(x): 0.7424 D(G(z)): 0.3031 / 0.2281
# [24/25][456/600] Loss_D: 0.8656 Loss_G: 1.4310 D(x): 0.6674 D(G(z)): 0.2655 / 0.2806
# [24/25][457/600] Loss_D: 0.8723 Loss_G: 1.7136 D(x): 0.7288 D(G(z)): 0.3277 / 0.2313
# [24/25][458/600] Loss_D: 0.7367 Loss_G: 1.7030 D(x): 0.7326 D(G(z)): 0.2531 / 0.2283
# [24/25][459/600] Loss_D: 0.6857 Loss_G: 1.5367 D(x): 0.7245 D(G(z)): 0.2324 / 0.2463
# [24/25][460/600] Loss_D: 0.8055 Loss_G: 1.6034 D(x): 0.7515 D(G(z)): 0.3207 / 0.2397
# [24/25][461/600] Loss_D: 0.9655 Loss_G: 1.8109 D(x): 0.7044 D(G(z)): 0.3301 / 0.2064
# [24/25][462/600] Loss_D: 0.8706 Loss_G: 1.4587 D(x): 0.6805 D(G(z)): 0.2540 / 0.2805
# [24/25][463/600] Loss_D: 0.8629 Loss_G: 1.5204 D(x): 0.7152 D(G(z)): 0.3058 / 0.2647
# [24/25][464/600] Loss_D: 0.8645 Loss_G: 1.5969 D(x): 0.7328 D(G(z)): 0.3049 / 0.2515
# [24/25][465/600] Loss_D: 0.7133 Loss_G: 1.6576 D(x): 0.7554 D(G(z)): 0.2698 / 0.2277
# [24/25][466/600] Loss_D: 1.0073 Loss_G: 1.4395 D(x): 0.6352 D(G(z)): 0.2837 / 0.2828
# [24/25][467/600] Loss_D: 0.8669 Loss_G: 1.7865 D(x): 0.7357 D(G(z)): 0.3252 / 0.2186
# [24/25][468/600] Loss_D: 0.9257 Loss_G: 1.8217 D(x): 0.6963 D(G(z)): 0.2998 / 0.2059
# [24/25][469/600] Loss_D: 0.8202 Loss_G: 1.3937 D(x): 0.6651 D(G(z)): 0.2126 / 0.2912
# [24/25][470/600] Loss_D: 0.9421 Loss_G: 1.2306 D(x): 0.7052 D(G(z)): 0.3364 / 0.3352
# [24/25][471/600] Loss_D: 0.9072 Loss_G: 1.7423 D(x): 0.7703 D(G(z)): 0.3804 / 0.2257
# [24/25][472/600] Loss_D: 0.9268 Loss_G: 1.6503 D(x): 0.6458 D(G(z)): 0.2819 / 0.2347
# [24/25][473/600] Loss_D: 0.9054 Loss_G: 1.2990 D(x): 0.6557 D(G(z)): 0.2691 / 0.3251
# [24/25][474/600] Loss_D: 0.9096 Loss_G: 1.5353 D(x): 0.7372 D(G(z)): 0.3494 / 0.2546
# [24/25][475/600] Loss_D: 0.8301 Loss_G: 1.5795 D(x): 0.6966 D(G(z)): 0.2860 / 0.2395
# [24/25][476/600] Loss_D: 0.8097 Loss_G: 1.3884 D(x): 0.7069 D(G(z)): 0.2583 / 0.2858
# [24/25][477/600] Loss_D: 0.8159 Loss_G: 1.6826 D(x): 0.7762 D(G(z)): 0.3521 / 0.2204
# [24/25][478/600] Loss_D: 0.8098 Loss_G: 1.5943 D(x): 0.6984 D(G(z)): 0.2623 / 0.2383
# [24/25][479/600] Loss_D: 0.9044 Loss_G: 1.3427 D(x): 0.6741 D(G(z)): 0.2746 / 0.3073
# [24/25][480/600] Loss_D: 0.7976 Loss_G: 1.8769 D(x): 0.7940 D(G(z)): 0.3238 / 0.1938
# [24/25][481/600] Loss_D: 0.8205 Loss_G: 1.8045 D(x): 0.6936 D(G(z)): 0.2374 / 0.2030
# [24/25][482/600] Loss_D: 0.8435 Loss_G: 1.5567 D(x): 0.6860 D(G(z)): 0.2488 / 0.2559
# [24/25][483/600] Loss_D: 0.8766 Loss_G: 1.6224 D(x): 0.7220 D(G(z)): 0.3141 / 0.2311
# [24/25][484/600] Loss_D: 0.8867 Loss_G: 1.5991 D(x): 0.6748 D(G(z)): 0.2588 / 0.2507
# [24/25][485/600] Loss_D: 0.9119 Loss_G: 1.4992 D(x): 0.6972 D(G(z)): 0.3205 / 0.2632
# [24/25][486/600] Loss_D: 0.8671 Loss_G: 1.6651 D(x): 0.7028 D(G(z)): 0.2760 / 0.2480
# [24/25][487/600] Loss_D: 1.0029 Loss_G: 1.3522 D(x): 0.6704 D(G(z)): 0.3419 / 0.2918
# [24/25][488/600] Loss_D: 0.8816 Loss_G: 1.6391 D(x): 0.7052 D(G(z)): 0.3201 / 0.2327
# [24/25][489/600] Loss_D: 0.8560 Loss_G: 1.5466 D(x): 0.6790 D(G(z)): 0.2800 / 0.2657
# [24/25][490/600] Loss_D: 0.8142 Loss_G: 1.7620 D(x): 0.7611 D(G(z)): 0.3304 / 0.2088
# [24/25][491/600] Loss_D: 0.9050 Loss_G: 1.5252 D(x): 0.6662 D(G(z)): 0.2664 / 0.2649
# [24/25][492/600] Loss_D: 0.9455 Loss_G: 1.4959 D(x): 0.7063 D(G(z)): 0.3355 / 0.2662
# [24/25][493/600] Loss_D: 0.8828 Loss_G: 1.5364 D(x): 0.6804 D(G(z)): 0.2767 / 0.2656
# [24/25][494/600] Loss_D: 0.8526 Loss_G: 1.7638 D(x): 0.7081 D(G(z)): 0.3028 / 0.2086
# [24/25][495/600] Loss_D: 0.8476 Loss_G: 1.5882 D(x): 0.6931 D(G(z)): 0.2818 / 0.2522
# [24/25][496/600] Loss_D: 0.9754 Loss_G: 1.6576 D(x): 0.6781 D(G(z)): 0.3163 / 0.2351
# [24/25][497/600] Loss_D: 0.8188 Loss_G: 1.4335 D(x): 0.6889 D(G(z)): 0.2666 / 0.2773
# [24/25][498/600] Loss_D: 0.7740 Loss_G: 1.4937 D(x): 0.7489 D(G(z)): 0.3069 / 0.2713
# [24/25][499/600] Loss_D: 0.8875 Loss_G: 1.9751 D(x): 0.7557 D(G(z)): 0.3396 / 0.1909
# [24/25][500/600] Loss_D: 0.9194 Loss_G: 1.3946 D(x): 0.6384 D(G(z)): 0.2407 / 0.2992
# saving the output
# [24/25][501/600] Loss_D: 0.9667 Loss_G: 1.5373 D(x): 0.7027 D(G(z)): 0.3547 / 0.2616
# [24/25][502/600] Loss_D: 0.8371 Loss_G: 1.7987 D(x): 0.7563 D(G(z)): 0.3155 / 0.2097
# [24/25][503/600] Loss_D: 0.9087 Loss_G: 1.2525 D(x): 0.6483 D(G(z)): 0.2479 / 0.3358
# [24/25][504/600] Loss_D: 1.0785 Loss_G: 1.7164 D(x): 0.7408 D(G(z)): 0.4245 / 0.2140
# [24/25][505/600] Loss_D: 0.8725 Loss_G: 1.8218 D(x): 0.7070 D(G(z)): 0.2614 / 0.1987
# [24/25][506/600] Loss_D: 1.0346 Loss_G: 1.2641 D(x): 0.5919 D(G(z)): 0.2332 / 0.3350
# [24/25][507/600] Loss_D: 0.8959 Loss_G: 1.7048 D(x): 0.7824 D(G(z)): 0.3582 / 0.2448
# [24/25][508/600] Loss_D: 0.8795 Loss_G: 1.6483 D(x): 0.7007 D(G(z)): 0.3079 / 0.2356
# [24/25][509/600] Loss_D: 0.8758 Loss_G: 1.5370 D(x): 0.6934 D(G(z)): 0.2904 / 0.2574
# [24/25][510/600] Loss_D: 0.7120 Loss_G: 1.6687 D(x): 0.7369 D(G(z)): 0.2270 / 0.2334
# [24/25][511/600] Loss_D: 1.0339 Loss_G: 1.4728 D(x): 0.6539 D(G(z)): 0.3322 / 0.2737
# [24/25][512/600] Loss_D: 0.7770 Loss_G: 1.5894 D(x): 0.7077 D(G(z)): 0.2711 / 0.2384
# [24/25][513/600] Loss_D: 0.8410 Loss_G: 1.5685 D(x): 0.7166 D(G(z)): 0.2966 / 0.2482
# [24/25][514/600] Loss_D: 0.8807 Loss_G: 1.7117 D(x): 0.7405 D(G(z)): 0.3041 / 0.2274
# [24/25][515/600] Loss_D: 0.8273 Loss_G: 1.5937 D(x): 0.6790 D(G(z)): 0.2461 / 0.2480
# [24/25][516/600] Loss_D: 0.8963 Loss_G: 1.5710 D(x): 0.7109 D(G(z)): 0.3144 / 0.2453
# [24/25][517/600] Loss_D: 0.9240 Loss_G: 1.4100 D(x): 0.6861 D(G(z)): 0.2961 / 0.2840
# [24/25][518/600] Loss_D: 1.0976 Loss_G: 1.3428 D(x): 0.6328 D(G(z)): 0.3604 / 0.3120
# [24/25][519/600] Loss_D: 0.8726 Loss_G: 1.6882 D(x): 0.7331 D(G(z)): 0.3494 / 0.2275
# [24/25][520/600] Loss_D: 0.8019 Loss_G: 1.6226 D(x): 0.6869 D(G(z)): 0.2609 / 0.2408
# [24/25][521/600] Loss_D: 0.9318 Loss_G: 1.3600 D(x): 0.6744 D(G(z)): 0.3050 / 0.3097
# [24/25][522/600] Loss_D: 0.7785 Loss_G: 2.0243 D(x): 0.7801 D(G(z)): 0.3410 / 0.1639
# [24/25][523/600] Loss_D: 0.9091 Loss_G: 1.3042 D(x): 0.6221 D(G(z)): 0.2237 / 0.3254
# [24/25][524/600] Loss_D: 0.9388 Loss_G: 2.1742 D(x): 0.7960 D(G(z)): 0.4156 / 0.1445
# [24/25][525/600] Loss_D: 0.9866 Loss_G: 1.2913 D(x): 0.5767 D(G(z)): 0.1901 / 0.3203
# [24/25][526/600] Loss_D: 0.9718 Loss_G: 1.3688 D(x): 0.7263 D(G(z)): 0.3664 / 0.3023
# [24/25][527/600] Loss_D: 0.8538 Loss_G: 1.6719 D(x): 0.7289 D(G(z)): 0.3244 / 0.2303
# [24/25][528/600] Loss_D: 0.8416 Loss_G: 1.8182 D(x): 0.7142 D(G(z)): 0.2839 / 0.2149
# [24/25][529/600] Loss_D: 0.8718 Loss_G: 1.4487 D(x): 0.6710 D(G(z)): 0.2581 / 0.2932
# [24/25][530/600] Loss_D: 0.9379 Loss_G: 1.3613 D(x): 0.6821 D(G(z)): 0.3220 / 0.3007
# [24/25][531/600] Loss_D: 0.8684 Loss_G: 1.6329 D(x): 0.7330 D(G(z)): 0.3383 / 0.2258
# [24/25][532/600] Loss_D: 0.7705 Loss_G: 1.6145 D(x): 0.7036 D(G(z)): 0.2580 / 0.2360
# [24/25][533/600] Loss_D: 0.9488 Loss_G: 2.1007 D(x): 0.7139 D(G(z)): 0.3323 / 0.1714
# [24/25][534/600] Loss_D: 1.0554 Loss_G: 1.0936 D(x): 0.5975 D(G(z)): 0.2745 / 0.3882
# [24/25][535/600] Loss_D: 1.0154 Loss_G: 1.6782 D(x): 0.7535 D(G(z)): 0.4077 / 0.2406
# [24/25][536/600] Loss_D: 0.8262 Loss_G: 1.7439 D(x): 0.6973 D(G(z)): 0.2607 / 0.2199
# [24/25][537/600] Loss_D: 0.7925 Loss_G: 1.3635 D(x): 0.6958 D(G(z)): 0.2611 / 0.2968
# [24/25][538/600] Loss_D: 0.7638 Loss_G: 1.7926 D(x): 0.7838 D(G(z)): 0.3312 / 0.1975
# [24/25][539/600] Loss_D: 0.8893 Loss_G: 1.8162 D(x): 0.7118 D(G(z)): 0.3105 / 0.1949
# [24/25][540/600] Loss_D: 0.8273 Loss_G: 1.4198 D(x): 0.6649 D(G(z)): 0.2060 / 0.2968
# [24/25][541/600] Loss_D: 0.9393 Loss_G: 1.7787 D(x): 0.7742 D(G(z)): 0.3744 / 0.2147
# [24/25][542/600] Loss_D: 0.8018 Loss_G: 1.8400 D(x): 0.7002 D(G(z)): 0.2545 / 0.1938
# [24/25][543/600] Loss_D: 0.7263 Loss_G: 1.6993 D(x): 0.7428 D(G(z)): 0.2474 / 0.2285
# [24/25][544/600] Loss_D: 0.8874 Loss_G: 1.5307 D(x): 0.6840 D(G(z)): 0.2631 / 0.2633
# [24/25][545/600] Loss_D: 0.8454 Loss_G: 1.8535 D(x): 0.7840 D(G(z)): 0.3420 / 0.2006
# [24/25][546/600] Loss_D: 0.8593 Loss_G: 1.4961 D(x): 0.6533 D(G(z)): 0.2221 / 0.2748
# [24/25][547/600] Loss_D: 0.8581 Loss_G: 1.5317 D(x): 0.7317 D(G(z)): 0.3110 / 0.2597
# [24/25][548/600] Loss_D: 0.8476 Loss_G: 2.0319 D(x): 0.7496 D(G(z)): 0.3128 / 0.1667
# [24/25][549/600] Loss_D: 0.8400 Loss_G: 1.6157 D(x): 0.6730 D(G(z)): 0.2191 / 0.2487
# [24/25][550/600] Loss_D: 0.7915 Loss_G: 1.6063 D(x): 0.7345 D(G(z)): 0.2797 / 0.2493
# [24/25][551/600] Loss_D: 0.8440 Loss_G: 1.5147 D(x): 0.6982 D(G(z)): 0.2857 / 0.2630
# [24/25][552/600] Loss_D: 0.7843 Loss_G: 1.9491 D(x): 0.8085 D(G(z)): 0.3563 / 0.1714
# [24/25][553/600] Loss_D: 0.9680 Loss_G: 1.3038 D(x): 0.6077 D(G(z)): 0.2160 / 0.3232
# [24/25][554/600] Loss_D: 0.9043 Loss_G: 1.4570 D(x): 0.7396 D(G(z)): 0.3559 / 0.2679
# [24/25][555/600] Loss_D: 1.0181 Loss_G: 1.7762 D(x): 0.6742 D(G(z)): 0.3347 / 0.2102
# [24/25][556/600] Loss_D: 0.9786 Loss_G: 1.7594 D(x): 0.6588 D(G(z)): 0.2960 / 0.2165
# [24/25][557/600] Loss_D: 0.9693 Loss_G: 1.2600 D(x): 0.6294 D(G(z)): 0.2774 / 0.3295
# [24/25][558/600] Loss_D: 0.8465 Loss_G: 1.5065 D(x): 0.7527 D(G(z)): 0.3508 / 0.2613
# [24/25][559/600] Loss_D: 1.1299 Loss_G: 1.5828 D(x): 0.6467 D(G(z)): 0.3624 / 0.2486
# [24/25][560/600] Loss_D: 0.7877 Loss_G: 1.5874 D(x): 0.6841 D(G(z)): 0.2420 / 0.2565
# [24/25][561/600] Loss_D: 0.8603 Loss_G: 1.3657 D(x): 0.7221 D(G(z)): 0.3094 / 0.3060
# [24/25][562/600] Loss_D: 0.9726 Loss_G: 1.5209 D(x): 0.7028 D(G(z)): 0.3592 / 0.2585
# [24/25][563/600] Loss_D: 0.8771 Loss_G: 1.7911 D(x): 0.7047 D(G(z)): 0.3004 / 0.2162
# [24/25][564/600] Loss_D: 0.9983 Loss_G: 1.4203 D(x): 0.6465 D(G(z)): 0.2914 / 0.2795
# [24/25][565/600] Loss_D: 0.7253 Loss_G: 1.8659 D(x): 0.7771 D(G(z)): 0.2967 / 0.1866
# [24/25][566/600] Loss_D: 0.9997 Loss_G: 1.1767 D(x): 0.6208 D(G(z)): 0.2557 / 0.3608
# [24/25][567/600] Loss_D: 1.0106 Loss_G: 1.9144 D(x): 0.7637 D(G(z)): 0.4214 / 0.1807
# [24/25][568/600] Loss_D: 1.0000 Loss_G: 1.2429 D(x): 0.5805 D(G(z)): 0.2107 / 0.3304
# [24/25][569/600] Loss_D: 0.9005 Loss_G: 1.3759 D(x): 0.7639 D(G(z)): 0.3855 / 0.2963
# [24/25][570/600] Loss_D: 0.8728 Loss_G: 1.8701 D(x): 0.7275 D(G(z)): 0.3339 / 0.1928
# [24/25][571/600] Loss_D: 0.7490 Loss_G: 1.5799 D(x): 0.6921 D(G(z)): 0.2238 / 0.2529
# [24/25][572/600] Loss_D: 0.9141 Loss_G: 1.3665 D(x): 0.7089 D(G(z)): 0.3318 / 0.2967
# [24/25][573/600] Loss_D: 0.9637 Loss_G: 1.5881 D(x): 0.7108 D(G(z)): 0.3504 / 0.2439
# [24/25][574/600] Loss_D: 0.8227 Loss_G: 1.7637 D(x): 0.7190 D(G(z)): 0.2861 / 0.2175
# [24/25][575/600] Loss_D: 0.8306 Loss_G: 1.7105 D(x): 0.7216 D(G(z)): 0.2450 / 0.2187
# [24/25][576/600] Loss_D: 0.9389 Loss_G: 1.5487 D(x): 0.6787 D(G(z)): 0.2794 / 0.2618
# [24/25][577/600] Loss_D: 0.9639 Loss_G: 1.5459 D(x): 0.6626 D(G(z)): 0.2823 / 0.2460
# [24/25][578/600] Loss_D: 0.9220 Loss_G: 1.5011 D(x): 0.6611 D(G(z)): 0.2912 / 0.2757
# [24/25][579/600] Loss_D: 0.7926 Loss_G: 1.7428 D(x): 0.7479 D(G(z)): 0.3037 / 0.2162
# [24/25][580/600] Loss_D: 0.8714 Loss_G: 1.5368 D(x): 0.6963 D(G(z)): 0.2917 / 0.2699
# [24/25][581/600] Loss_D: 0.8020 Loss_G: 1.5644 D(x): 0.7309 D(G(z)): 0.2821 / 0.2546
# [24/25][582/600] Loss_D: 0.9229 Loss_G: 1.4899 D(x): 0.6722 D(G(z)): 0.2858 / 0.2684
# [24/25][583/600] Loss_D: 0.7088 Loss_G: 1.7215 D(x): 0.7972 D(G(z)): 0.3014 / 0.2111
# [24/25][584/600] Loss_D: 1.1033 Loss_G: 1.3553 D(x): 0.6110 D(G(z)): 0.3023 / 0.3028
# [24/25][585/600] Loss_D: 0.9879 Loss_G: 1.3618 D(x): 0.6764 D(G(z)): 0.3361 / 0.3161
# [24/25][586/600] Loss_D: 0.8517 Loss_G: 1.7102 D(x): 0.7329 D(G(z)): 0.3218 / 0.2226
# [24/25][587/600] Loss_D: 0.7577 Loss_G: 1.9467 D(x): 0.7534 D(G(z)): 0.2843 / 0.1834
# [24/25][588/600] Loss_D: 0.8848 Loss_G: 1.3126 D(x): 0.6438 D(G(z)): 0.2341 / 0.3175
# [24/25][589/600] Loss_D: 0.9065 Loss_G: 1.7047 D(x): 0.7442 D(G(z)): 0.3632 / 0.2253
# [24/25][590/600] Loss_D: 0.8995 Loss_G: 1.7366 D(x): 0.7030 D(G(z)): 0.3180 / 0.2152
# [24/25][591/600] Loss_D: 0.8583 Loss_G: 1.5009 D(x): 0.6606 D(G(z)): 0.2514 / 0.2741
# [24/25][592/600] Loss_D: 0.8615 Loss_G: 1.4025 D(x): 0.7083 D(G(z)): 0.3058 / 0.2826
# [24/25][593/600] Loss_D: 0.9702 Loss_G: 1.2799 D(x): 0.6660 D(G(z)): 0.3177 / 0.3217
# [24/25][594/600] Loss_D: 0.9382 Loss_G: 1.7648 D(x): 0.7510 D(G(z)): 0.3716 / 0.2023
# [24/25][595/600] Loss_D: 0.8896 Loss_G: 1.6157 D(x): 0.6722 D(G(z)): 0.2707 / 0.2321
# [24/25][596/600] Loss_D: 0.9139 Loss_G: 1.3307 D(x): 0.6610 D(G(z)): 0.2655 / 0.3084
# [24/25][597/600] Loss_D: 0.9522 Loss_G: 1.6457 D(x): 0.7311 D(G(z)): 0.3552 / 0.2340
# [24/25][598/600] Loss_D: 0.8096 Loss_G: 1.6463 D(x): 0.6862 D(G(z)): 0.2632 / 0.2266
# [24/25][599/600] Loss_D: 0.9623 Loss_G: 1.3664 D(x): 0.6703 D(G(z)): 0.3008 / 0.3039
